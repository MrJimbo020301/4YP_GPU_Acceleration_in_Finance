# %%
####################################################
# SUPER ADVANCED MOE SCRIPT (WITH ACTUAL & POLYNOMIALS)
####################################################

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import warnings
import os
import random
import torch
import torch.nn as nn
import torch.nn.functional as F
import joblib

from numpy.polynomial.polynomial import polyfit, polyval
from sklearn.preprocessing import MinMaxScaler
from sklearn.svm import SVR
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.multioutput import MultiOutputRegressor
from sklearn.metrics import mean_squared_error

warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=pd.errors.PerformanceWarning)
pd.options.mode.chained_assignment = None

# Global seeds & device
torch.manual_seed(0)
np.random.seed(0)
random.seed(0)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(0)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

BEST_MODELS_DIR = "."   # Where .pt/.pkl model files are stored
features = ["Price","Open","High","Low"]
WINDOW_SIZE = 35

############################################
# 1) Model Definitions & Loading
############################################
class BaseModel(nn.Module):
    def __init__(self, model_type="LSTM", window_width=35):
        super().__init__()
        self.model_type = model_type

        if model_type == "CNN":
            self.conv1 = nn.Conv1d(4, 64, 3)
            self.conv2 = nn.Conv1d(64, 128, 3)
            with torch.no_grad():
                dummy = torch.zeros(1, 4, window_width)
                outdummy = self.conv2(F.relu(self.conv1(dummy)))
                conv_output_size = outdummy.shape[1]*outdummy.shape[2]
            self.fc = nn.Linear(conv_output_size, 4)

        elif model_type == "LSTM":
            self.rnn = nn.LSTM(4, 128, num_layers=2, batch_first=True, dropout=0.05)
            self.fc = nn.Linear(128, 4)

        elif model_type == "GRU":
            self.rnn = nn.GRU(4, 128, num_layers=2, batch_first=True, dropout=0.05)
            self.fc = nn.Linear(128, 4)

        elif model_type == "RNN":
            self.rnn = nn.RNN(4, 128, num_layers=2, nonlinearity="relu", batch_first=True, dropout=0.05)
            self.fc = nn.Linear(128, 4)

        elif model_type == "EnhancedLSTM":
            self.rnn = nn.LSTM(4, 128, num_layers=3, batch_first=True, dropout=0.1)
            self.bn  = nn.BatchNorm1d(128)
            self.dropout = nn.Dropout(0.1)
            self.fc = nn.Linear(128, 4)

        elif model_type == "Transformer":
            self.input_linear = nn.Linear(4, 128)
            enc_layer = nn.TransformerEncoderLayer(d_model=128, nhead=8, dropout=0.05)
            self.transformer_encoder = nn.TransformerEncoder(enc_layer, num_layers=3)
            self.fc = nn.Linear(128,4)

        elif model_type in ["N-BEATS","N-HITS"]:
            self.input_size= window_width*4
            self.blocks= nn.ModuleList([nn.Sequential(
                nn.Linear(self.input_size,128),
                nn.ReLU(),
                nn.Linear(128,128),
                nn.ReLU(),
                nn.Linear(128,4)
            ) for _ in range(3)])
        else:
            raise ValueError(f"Invalid model_type: {model_type}")

    def forward(self, x):
        if self.model_type == "CNN":
            x = x.permute(0,2,1)
            x = F.relu(self.conv1(x))
            x = F.relu(self.conv2(x))
            x = x.view(x.size(0), -1)
            return self.fc(x)

        elif self.model_type in ["LSTM","GRU","RNN"]:
            out, _ = self.rnn(x)
            out = out[:,-1,:]
            return self.fc(out)

        elif self.model_type == "EnhancedLSTM":
            out, _= self.rnn(x)
            out = out[:,-1,:]
            out = self.bn(out)
            out = self.dropout(out)
            return self.fc(out)

        elif self.model_type == "Transformer":
            x = self.input_linear(x)
            x = x.permute(1,0,2)
            x = self.transformer_encoder(x)
            x = x[-1,:,:]
            return self.fc(x)

        elif self.model_type in ["N-BEATS","N-HITS"]:
            xflat = x.reshape(x.size(0), -1)
            forecast = 0
            for block in self.blocks:
                forecast += block(xflat)
            return forecast

        else:
            raise ValueError("Invalid model_type")

class SklearnWrapper:
    def __init__(self, model):
        self.model= model
    def forward(self, x):
        arr= x.cpu().numpy().reshape(1,-1)
        pred= self.model.predict(arr)
        return torch.from_numpy(pred).float().to(x.device)
    def eval(self): pass
    def __call__(self, x):
        return self.forward(x)

def load_torch_model(model_type, window_size, path):
    if not os.path.exists(path):
        raise FileNotFoundError(f"File not found: {path}")
    print(f"[PyTorch] Loading {model_type} from {path}")
    net= BaseModel(model_type, window_size).to(device)
    net.load_state_dict(torch.load(path, map_location=device))
    net.eval()
    return net

def load_sklearn_model(model_type, path):
    if not os.path.exists(path):
        raise FileNotFoundError(f"File not found: {path}")
    print(f"[sklearn] Loading {model_type} => {path}")
    loaded= joblib.load(path)
    return SklearnWrapper(loaded)

############################################
# 2) Load & Scale Data
############################################
def load_and_scale_data(train_csv="Silver Futures Historical Data.csv",
                        complete_csv="Silver Futures Historical Data_Complete.csv"):
    df_train = pd.read_csv(train_csv)
    df_train["Date"] = pd.to_datetime(df_train["Date"], errors="coerce")
    for col in ["Vol.","Change %"]:
        if col in df_train.columns:
            df_train.drop(columns=[col], errors="ignore", inplace=True)

    for feat in features:
        if feat not in df_train.columns:
            df_train[feat]= np.nan
        else:
            df_train[feat]= df_train[feat].astype(str).str.replace(",", "", regex=True)
            df_train[feat]= pd.to_numeric(df_train[feat], errors="coerce")

    df_train.sort_values("Date", inplace=True)
    df_train.reset_index(drop=True, inplace=True)

    train_cutoff= pd.to_datetime("2024-07-01")
    val_cutoff  = pd.to_datetime("2024-11-30")
    test_cutoff = pd.to_datetime("2024-12-01")

    df_trn= df_train[df_train["Date"]< train_cutoff].copy()
    df_val= df_train[(df_train["Date"]>= train_cutoff)&(df_train["Date"]<= val_cutoff)].copy()
    df_tst= df_train[df_train["Date"]>= test_cutoff].copy()

    df_trn_nonan= df_trn.dropna(subset=features)
    scaler= MinMaxScaler()
    scaler.fit(df_trn_nonan[features])

    df_trn_scaled= df_trn.copy()
    if not df_trn_nonan.empty:
        df_trn_scaled.loc[df_trn_nonan.index, features]= scaler.transform(df_trn_nonan[features])
    df_val_scaled= df_val.copy()
    val_no_nan= df_val_scaled.dropna(subset=features)
    if not val_no_nan.empty:
        df_val_scaled.loc[val_no_nan.index, features]= scaler.transform(val_no_nan[features])
    df_tst_scaled= df_tst.copy()
    trn_mins= df_trn_nonan[features].min()
    df_tst_filled= df_tst_scaled[features].fillna(trn_mins)
    df_tst_scaled.loc[:, features]= scaler.transform(df_tst_filled)

    df_scaled= pd.concat([df_trn_scaled, df_val_scaled, df_tst_scaled], ignore_index=True)

    # also load complete
    df_complete= pd.read_csv(complete_csv)
    df_complete["Date"]= pd.to_datetime(df_complete["Date"], errors="coerce")
    for col in ["Vol.","Change %"]:
        if col in df_complete.columns:
            df_complete.drop(columns=[col], errors="ignore", inplace=True)
    for feat in features:
        df_complete[feat]= df_complete[feat].astype(str).str.replace(",", "",regex=True).astype(float)
    df_complete.sort_values("Date", inplace=True)
    df_complete.reset_index(drop=True, inplace=True)

    return df_scaled, df_complete, scaler

############################################
# 3) Rolling Forecast
############################################
def get_latest_window(df_actual, current_date, window=35, scaler=None):
    mask= df_actual["Date"]< current_date
    sub= df_actual.loc[mask].copy()
    sub.sort_values("Date", inplace=True)
    if len(sub)< window:
        return None
    sub[features]= sub[features].fillna(method="ffill").fillna(method="bfill")
    arr= scaler.transform(sub[features].iloc[-window:].values)
    return arr

def forecast_n_days_from_date(model, df_actual, start_date, window=35, horizon=30,
                              device=None, scaler=None, noise_std=0.05):
    """
    Rolling forecast with mild random noise => more "volatility".
    """
    def add_noise_4d(prices, std=0.01):
        noise= np.random.normal(0.0, std, size=prices.shape)
        return np.clip(prices+noise, a_min=0, a_max=None)

    arr_window= get_latest_window(df_actual, start_date, window, scaler)
    if arr_window is None:
        return pd.DataFrame()

    rolling_buffer= np.copy(arr_window)
    forecast_records=[]
    cur_dt= pd.to_datetime(start_date)

    for i in range(horizon):
        X_in= torch.tensor(rolling_buffer,dtype=torch.float).unsqueeze(0).to(device)
        with torch.no_grad():
            out_scaled= model(X_in).cpu().numpy()[0]
        out_unscaled= scaler.inverse_transform(out_scaled.reshape(1,-1))[0]
        # add a little random noise => final to get more "volatile" predictions
        out_noisy= add_noise_4d(out_unscaled, noise_std)

        dayx= cur_dt+ pd.Timedelta(days=i)
        forecast_records.append({
            "ForecastDate": dayx,
            "Pred_Price_unscaled": out_noisy[0],
            "Pred_Open_unscaled":  out_noisy[1],
            "Pred_High_unscaled":  out_noisy[2],
            "Pred_Low_unscaled":   out_noisy[3]
        })

        out_noisy_scaled= scaler.transform(out_noisy.reshape(1,-1))[0]
        rolling_buffer= np.vstack([rolling_buffer[1:], out_noisy_scaled.reshape(1,-1)])

    return pd.DataFrame(forecast_records)

def rolling_train_validate_predict_moe(
    df_full, scaler_obj, model_types,
    start_train_cutoff=pd.to_datetime("2024-07-01"),
    start_val_cutoff=pd.to_datetime("2024-11-30"),
    start_pred=pd.to_datetime("2024-12-01"),
    end_pred=pd.to_datetime("2025-01-01"),
    horizon_days=30,
    do_daily_plots=False
):
    df_sorted= df_full.copy()
    df_sorted.sort_values("Date", inplace=True)

    date_rng= pd.date_range(start_pred, end_pred, freq="D")
    all_records=[]

    for i, day_i in enumerate(date_rng):
        train_cutoff_i= start_train_cutoff + pd.Timedelta(days=i)
        val_cutoff_i  = start_val_cutoff   + pd.Timedelta(days=i)

        print(f"\n=== Rolling Day {day_i.date()} ===")
        print(f"  train_cutoff={train_cutoff_i.date()}  val_cutoff={val_cutoff_i.date()}")
        print(f"  Forecast next {horizon_days} days from {day_i.date()} w/ noise => more volatility")

        # load each model
        model_dict={}
        for mt in model_types:
            out_file= f"best_{mt}_{day_i.strftime('%Y-%m-%d')}_V1"
            if mt in ["SVM","GPR","Boost"]:
                out_file+= ".pkl"
                net= load_sklearn_model(mt, os.path.join(BEST_MODELS_DIR, out_file))
            else:
                out_file+= ".pt"
                net= load_torch_model(mt, WINDOW_SIZE, os.path.join(BEST_MODELS_DIR, out_file))
            model_dict[mt]= net

        daily_fcst={}
        for mt, netobj in model_dict.items():
            df_fc= forecast_n_days_from_date(
                model=netobj,
                df_actual=df_sorted,
                start_date=day_i,
                window=WINDOW_SIZE,
                horizon=horizon_days,
                device=device,
                scaler=scaler_obj,
                noise_std=0.01   # control final volatility
            )
            if not df_fc.empty:
                df_fc["BaseDate"]= day_i
                df_fc["Model"]= mt
                daily_fcst[mt]= df_fc
                all_records.append(df_fc)
            else:
                daily_fcst[mt]= pd.DataFrame()

        # optional daily plots
        if do_daily_plots and (day_i== date_rng[-1]):
            pass

    df_all= pd.concat(all_records, ignore_index=True) if all_records else pd.DataFrame()
    df_all.sort_values(["Model","BaseDate","ForecastDate"], inplace=True)
    return df_all

############################################
# 4) Advanced MoE (Population Voting w/ mini-model approach)
############################################
def build_mini_models_table(final_rolling_fcst, df_actual):
    """
    For each (model, baseDate) => measure january performance => mae, slope alignment, volatility alignment
    """
    start_jan= pd.to_datetime("2024-12-01")
    end_jan=   pd.to_datetime("2025-01-01")
    df_jan= final_rolling_fcst[
        (final_rolling_fcst["ForecastDate"]>= start_jan)&
        (final_rolling_fcst["ForecastDate"]<= end_jan)
    ].copy()
    if df_jan.empty:
        return pd.DataFrame(), 0.01

    df_act_jan= df_actual[
        (df_actual["Date"]>= start_jan)&
        (df_actual["Date"]<= end_jan)
    ].copy()
    df_act_jan.rename(columns={"Date":"ForecastDate","Price":"ActualPrice"}, inplace=True)

    df_merge= pd.merge(
        df_jan[["Model","BaseDate","ForecastDate","Pred_Price_unscaled"]],
        df_act_jan[["ForecastDate","ActualPrice"]],
        on="ForecastDate",
        how="inner"
    )
    df_merge["AbsError"]= (df_merge["Pred_Price_unscaled"]- df_merge["ActualPrice"]).abs()

    # mae
    g_mae= df_merge.groupby(["Model","BaseDate"])["AbsError"].mean().reset_index()
    g_mae.rename(columns={"AbsError":"mae_jan"}, inplace=True)

    # slope alignment => quick polynomial fit
    def poly_slope_diff(sub):
        sub= sub.sort_values("ForecastDate")
        xvals= np.arange(len(sub))
        yvals= sub["Pred_Price_unscaled"].values
        if len(yvals)< 4:
            return 0.5
        coefs= polyfit(xvals,yvals,deg=2)
        y_pred= polyval(xvals, coefs)
        resid= yvals- y_pred
        sse= np.mean(resid**2)
        return float(np.exp(-sse))

    def group_slope_func(grp):
        grp["slopeAlign_jan"]= poly_slope_diff(grp)
        return grp

    df_slope= df_merge.groupby(["Model","BaseDate"], group_keys=False).apply(group_slope_func)
    df_slope_agg= df_slope.groupby(["Model","BaseDate"])["slopeAlign_jan"].mean().reset_index()

    # real vol
    df_act_jan_sorted= df_act_jan.drop_duplicates("ForecastDate").copy()
    df_act_jan_sorted.sort_values("ForecastDate", inplace=True)
    df_act_jan_sorted["DayChange"]= df_act_jan_sorted["ActualPrice"].diff()
    real_vol= df_act_jan_sorted["DayChange"].std(skipna=True)
    if pd.isna(real_vol) or real_vol< 1e-9:
        real_vol= 0.01

    # pred vol => stdev of dayChange
    def mini_volatility(sub):
        sub= sub.sort_values("ForecastDate")
        sub["DayChange"]= sub["Pred_Price_unscaled"].diff()
        vol_= sub["DayChange"].std(skipna=True)
        if pd.isna(vol_): vol_= 0.01
        return vol_

    g_vol= df_merge.groupby(["Model","BaseDate"]).apply(mini_volatility).reset_index()
    g_vol.rename(columns={0:"predVol_jan"}, inplace=True)
    def vol_align(v):
        ratio= v/ real_vol
        return np.exp(-abs(ratio-1.0))
    g_vol["volAlign_jan"]= g_vol["predVol_jan"].apply(vol_align)

    mini_models= pd.merge(g_mae, df_slope_agg, on=["Model","BaseDate"], how="left")
    mini_models= pd.merge(mini_models, g_vol[["Model","BaseDate","predVol_jan","volAlign_jan"]], on=["Model","BaseDate"], how="left")

    mae_min= mini_models["mae_jan"].min()
    mae_max= mini_models["mae_jan"].max()
    if np.isclose(mae_min, mae_max):
        mini_models["baseAcc"]= 1.0
    else:
        mini_models["baseAcc"]= 1.0- ((mini_models["mae_jan"]-mae_min)/(mae_max-mae_min))

    return mini_models, real_vol

def compute_super_advanced_moe(final_rolling_fcst, df_actual):
    """
    1) Build "mini-models" => (model, baseDate)
    2) Weighted sum => MoE
    3) population shift => up/down
    4) random noise => final volatility
    """
    print("\n=== SUPER ADVANCED MOE w/ Polynomials & Voting ===\n")
    mini_models, real_vol= build_mini_models_table(final_rolling_fcst, df_actual)
    if mini_models.empty:
        print("No january data => fallback => uniform daily average")
        return pd.DataFrame(columns=["ForecastDate","MOE_Price"])

    mm_dict={}
    for i,row in mini_models.iterrows():
        mm_dict[(row["Model"], row["BaseDate"])]= {
            "baseAcc": row["baseAcc"],
            "slopeAlign_jan": row["slopeAlign_jan"],
            "volAlign_jan": row["volAlign_jan"]
        }

    start_moe= pd.to_datetime("2025-01-02")
    end_moe=   pd.to_datetime("2025-01-31")
    all_days=  pd.date_range(start_moe, end_moe, freq="D")
    records=[]

    for d in all_days:
        df_d= final_rolling_fcst[ final_rolling_fcst["ForecastDate"]== d ].copy()
        if df_d.empty:
            continue

        d_prev= d - pd.Timedelta(days=1)
        ups=0
        downs=0
        total=0
        w_sums=0.0
        weighted_price=0.0

        for idx,row in df_d.iterrows():
            m= row["Model"]
            bD= row["BaseDate"]
            if (m,bD) not in mm_dict:
                continue
            baseAcc= mm_dict[(m,bD)]["baseAcc"]
            slopeA= mm_dict[(m,bD)]["slopeAlign_jan"]
            volA= mm_dict[(m,bD)]["volAlign_jan"]

            df_dprev= final_rolling_fcst[
                (final_rolling_fcst["Model"]==m)&
                (final_rolling_fcst["BaseDate"]==bD)&
                (final_rolling_fcst["ForecastDate"]==d_prev)
            ]
            if df_dprev.empty:
                dirFactor=1.0
            else:
                pd_today= row["Pred_Price_unscaled"]
                pd_yest= df_dprev["Pred_Price_unscaled"].values[0]
                if pd_today>pd_yest:
                    ups+=1
                    dirFactor=1.1
                elif pd_today< pd_yest:
                    downs+=1
                    dirFactor=0.9
                else:
                    dirFactor=1.0
                total+=1

            w= baseAcc* slopeA* volA* dirFactor
            w_sums+= w
            weighted_price+= w* row["Pred_Price_unscaled"]

        if np.isclose(w_sums,0.0):
            day_moe= df_d["Pred_Price_unscaled"].mean()
        else:
            day_moe= weighted_price/ w_sums

        if total>0:
            fraction_up= ups/ total
            fraction_down= downs/ total
            if fraction_up> 0.7:
                day_moe*= 1.01
            elif fraction_down> 0.7:
                day_moe*= 0.99

        day_moe+= np.random.normal(0, day_moe*0.002)
        records.append({"ForecastDate": d, "MOE_Price": day_moe})

    df_moe= pd.DataFrame(records)
    df_moe.sort_values("ForecastDate", inplace=True)
    return df_moe

def plot_super_advanced_moe_vs_models(final_rolling_fcst, df_moe,
                                      from_d=pd.to_datetime("2025-01-02"),
                                      to_d=pd.to_datetime("2025-01-31")):
    """
    Plots all 9 models + super advanced MoE in [from_d..to_d], no actual overlay.
    """
    df_sel= final_rolling_fcst[
        (final_rolling_fcst["ForecastDate"]>= from_d)&
        (final_rolling_fcst["ForecastDate"]<= to_d)
    ].copy()

    plt.figure(figsize=(12,6))
    color_map = {
        "LSTM":"red","GRU":"blue","RNN":"green","CNN":"orange","EnhancedLSTM":"magenta",
        "Transformer":"cyan","N-BEATS":"brown","N-HITS":"pink","SVM":"olive","GPR":"teal","Boost":"purple"
    }
    for m in df_sel["Model"].unique():
        df_m= df_sel[df_sel["Model"]== m].copy()
        df_m_agg= df_m.groupby("ForecastDate", as_index=False)["Pred_Price_unscaled"].mean()
        c= color_map.get(m,"gray")
        plt.plot(df_m_agg["ForecastDate"], df_m_agg["Pred_Price_unscaled"], color=c, alpha=0.6, label=m)

    df_moe_sub= df_moe[
        (df_moe["ForecastDate"]>= from_d)&
        (df_moe["ForecastDate"]<= to_d)
    ].copy()
    if not df_moe_sub.empty:
        plt.plot(df_moe_sub["ForecastDate"], df_moe_sub["MOE_Price"],
                 color="black",linestyle="--",lw=2, label="SuperAdvancedMoE")

    plt.title(f"SuperAdvancedMoE vs. Models\n({from_d.date()}..{to_d.date()}) (Volatile MOE)")
    plt.xlabel("Date")
    plt.ylabel("Price")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

############################################
# 5) Polynomial Fitting for BOTH Actual & MoE
############################################
def polynomial_fitting_actual_and_moe(
    df_moe,
    csv_actual="Silver Futures Historical Data_Final Pure Predictions.csv",
    max_degree=70
):
    """
    Similar to earlier "multi-column" approach:
      - Merge actual data & MoE data into 1 DataFrame
      - Fit polynomials (1..max_degree) for both "Actual" and "MOE_Price"
      - Plot best polynomial fits in a single figure
      - Plot derivative curves in a single figure
      - Print expressions for each
    """

    # -- A) Read actual data and merge with MoE
    df_actual = pd.read_csv(csv_actual)
    df_actual["Date"] = pd.to_datetime(df_actual["Date"], errors="coerce")
    for col in ["Vol.","Change %"]:
        if col in df_actual.columns:
            df_actual.drop(columns=[col], errors="ignore", inplace=True)
    if "Price" in df_actual.columns:
        df_actual["Price"] = df_actual["Price"].astype(str).str.replace(",", "", regex=True).astype(float)
    df_actual.sort_values("Date", inplace=True)
    df_actual.reset_index(drop=True, inplace=True)

    # rename MoE
    df_moe_rename = df_moe.rename(columns={"ForecastDate":"Date", "MOE_Price":"MoE"})
    df_moe_rename.sort_values("Date", inplace=True)
    df_moe_rename.reset_index(drop=True, inplace=True)

    # Merge => have columns: Date, MoE, Price
    # We'll rename Price -> Actual
    df_merge = pd.merge(
        df_moe_rename,
        df_actual[["Date","Price"]],
        on="Date", how="inner"
    ).rename(columns={"Price":"Actual"})

    if df_merge.empty:
        print("No overlapping dates between df_moe and actual data. Cannot do polynomial fitting.")
        return

    df_merge.sort_values("Date", inplace=True)
    df_merge.reset_index(drop=True, inplace=True)

    # We will do a train/val approach for each column (Actual, MoE).
    # One DataFrame with columns: ["Date", "Actual", "MoE"].
    # For train/val split, we use the even index => train, odd index => val (like before).
    # We'll store best polynomials for each column in a dict: best_poly_info[column].
    columns_to_fit = ["Actual", "MoE"]

    # Create numeric axis from Date
    df_merge["mdates_num"] = mdates.date2num(df_merge["Date"])
    n_points = len(df_merge)
    indices = np.arange(n_points)
    val_mask = (indices % 2 == 0)
    train_mask   = ~val_mask

    # For convenience in plotting train vs. val for "Actual," we do:
    #   "Actual" train => black circle,
    #   "Actual" val => black x,
    #   "MoE" train => red circle,
    #   "MoE" val => red x,
    color_map = {"Actual":"black", "MoE":"red"}

    best_poly_info = {}

    def format_poly(coeffs):
        terms=[]
        deg = len(coeffs)-1
        for i,c in enumerate(coeffs):
            p = deg - i
            if p>1:
                terms.append(f"{c:+.4e}*x^{p}")
            elif p==1:
                terms.append(f"{c:+.4e}*x")
            else:
                terms.append(f"{c:+.4e}")
        expr="".join(terms).replace("+-","-")
        if expr.startswith("+"):
            expr=expr[1:]
        return expr

    # ---------- Fit polynomials for each column ------------
    for col in columns_to_fit:
        x_train = df_merge.loc[train_mask, "mdates_num"].values
        y_train = df_merge.loc[train_mask, col].values

        x_val   = df_merge.loc[val_mask, "mdates_num"].values
        y_val   = df_merge.loc[val_mask, col].values

        best_deg=None
        best_mse=float("inf")
        best_coefs=None

        for deg_ in range(1, max_degree+1):
            coefs = np.polyfit(x_train, y_train, deg_)
            preds_val = np.polyval(coefs, x_val)
            val_mse = mean_squared_error(y_val, preds_val)
            if val_mse< best_mse:
                best_mse= val_mse
                best_deg= deg_
                best_coefs= coefs

        best_poly_info[col] = {
            "degree": best_deg,
            "mse": best_mse,
            "coeffs": best_coefs
        }

    # ---------- Plot best polynomial fits in one figure ------------
    plt.figure(figsize=(10,6))
    # Plot actual data points: train => black circle, val => black x
    plt.scatter(df_merge.loc[train_mask, "Date"], df_merge.loc[train_mask, "Actual"],
                color="black", marker="o", label="Actual Training Data")
    plt.scatter(df_merge.loc[val_mask, "Date"], df_merge.loc[val_mask, "Actual"],
                color="black", marker="x", label="Actual Validation Data")
    # Plot MoE data points: train => red circle, val => red x
    plt.scatter(df_merge.loc[train_mask, "Date"], df_merge.loc[train_mask, "MoE"],
                color="red", marker="o", label="MoE Training Data")
    plt.scatter(df_merge.loc[val_mask, "Date"], df_merge.loc[val_mask, "MoE"],
                color="red", marker="x", label="MoE Validation Data")

    # Create a dense x-axis for plotting polynomials
    x_dense = np.linspace(df_merge["mdates_num"].min(), df_merge["mdates_num"].max(), 300)
    x_dense_dates = [mdates.num2date(xx) for xx in x_dense]

    for col in columns_to_fit:
        info = best_poly_info[col]
        deg_ = info["degree"]
        coefs_ = info["coeffs"]
        color_ = color_map.get(col, "gray")
        y_dense = np.polyval(coefs_, x_dense)
        plt.plot(x_dense_dates, y_dense, color=color_,
                 linewidth=2, label=f"{col} Poly (Deg {deg_})")

    plt.title("Best Polynomial Fits (Test Window): Actual vs. MoE Predictions of Silver Futures")
    plt.xlabel("Date")
    plt.ylabel("Price")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    # ---------- Print out polynomial expressions ------------
    print("\n=== Best Polynomial Fitting Results ===")
    for col in columns_to_fit:
        deg_   = best_poly_info[col]["degree"]
        mse_   = best_poly_info[col]["mse"]
        coefs_ = best_poly_info[col]["coeffs"]
        expr_  = format_poly(coefs_)
        print(f"[{col}] => Degree={deg_}, Val MSE={mse_:.6f}")
        print(f"     y = {expr_}\n")

    # ---------- Derivative curves in a single figure ------------
    plt.figure(figsize=(10,6))

    for col in columns_to_fit:
        coefs_ = best_poly_info[col]["coeffs"]
        d_coefs_ = np.polyder(coefs_)
        d_expr_  = format_poly(d_coefs_)
        y_deriv  = np.polyval(d_coefs_, x_dense)

        color_ = color_map.get(col, "gray")
        plt.plot(x_dense_dates, y_deriv, color=color_, linewidth=2, label=f"{col} Derivative")

        print(f"=== Derivative for {col} (Degree {best_poly_info[col]['degree']} => {best_poly_info[col]['degree']-1}) ===")
        print(f"   d/dx of {col} = {d_expr_}\n")

    plt.title("Polynomial Derivative Curves (Test Window) for Actual vs. MoE")
    plt.xlabel("Date")
    plt.ylabel("d(Price)/d(Time)")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()


############################################
# 6) (Optional) "Super Advanced MoE vs. Models (With Actual...)" 
############################################
def load_feb_actual_data(csv_file="Silver Futures Historical Data_Final Pure Predictions.csv"):
    """
    Reads an extra CSV file that presumably contains actual price data
    from at least 2025-02-01 onward.
    Returns a DataFrame with columns: ["Date", "Price", ...].
    """
    df_feb = pd.read_csv(csv_file)
    df_feb["Date"] = pd.to_datetime(df_feb["Date"], errors="coerce")
    for col in ["Vol.", "Change %"]:
        if col in df_feb.columns:
            df_feb.drop(columns=[col], errors="ignore", inplace=True)
    if "Price" in df_feb.columns:
        df_feb["Price"] = df_feb["Price"].astype(str).str.replace(",", "", regex=True).astype(float)
    df_feb.sort_values("Date", inplace=True)
    df_feb.reset_index(drop=True, inplace=True)
    return df_feb

def plot_super_advanced_moe_with_feb_actual(
    final_rolling_fcst,
    df_moe,
    feb_actual_csv="Silver Futures Historical Data_Final Pure Predictions.csv",
    start_plot=pd.to_datetime("2025-01-02"),
    end_plot=pd.to_datetime("2025-01-31")
):
    """
    1) Loads the newly provided CSV file, presumably containing actual prices (like 2025-02..).
    2) Plots all 9 models' lines, the super advanced MoE line, plus the newly revealed actual data
       in [start_plot..end_plot].
    """
    df_feb_actual = load_feb_actual_data(feb_actual_csv)
    mask_feb = (df_feb_actual["Date"] >= start_plot) & (df_feb_actual["Date"] <= end_plot)
    df_feb_filtered = df_feb_actual.loc[mask_feb].copy()

    df_fc = final_rolling_fcst[
        (final_rolling_fcst["ForecastDate"] >= start_plot) &
        (final_rolling_fcst["ForecastDate"] <= end_plot)
    ].copy()

    plt.figure(figsize=(12,6))
    color_map = {
        "LSTM": "red",
        "GRU": "blue",
        "RNN": "green",
        "CNN": "orange",
        "EnhancedLSTM": "magenta",
        "Transformer": "cyan",
        "N-BEATS": "brown",
        "N-HITS": "pink",
        "SVM": "olive",
        "GPR": "teal",
        "Boost": "purple"
    }

    if not df_feb_filtered.empty and "Price" in df_feb_filtered.columns:
        plt.plot(
            df_feb_filtered["Date"], df_feb_filtered["Price"],
            color="black", linewidth=2, label="NewActual(Jan)"
        )

    for m in df_fc["Model"].unique():
        df_m = df_fc[df_fc["Model"] == m].copy()
        df_m_agg = df_m.groupby("ForecastDate", as_index=False)["Pred_Price_unscaled"].mean()
        c = color_map.get(m, "gray")
        plt.plot(
            df_m_agg["ForecastDate"], df_m_agg["Pred_Price_unscaled"],
            color=c, alpha=0.6, label=m
        )

    df_moe_sub = df_moe[
        (df_moe["ForecastDate"] >= start_plot) &
        (df_moe["ForecastDate"] <= end_plot)
    ].copy()
    if not df_moe_sub.empty:
        plt.plot(
            df_moe_sub["ForecastDate"], df_moe_sub["MOE_Price"],
            color="black", linestyle="--", linewidth=2, label="SuperAdvancedMoE"
        )

    plt.title(f"Super Advanced MoE vs. Models (With Actual)\n[{start_plot.date()} ~ {end_plot.date()}]")
    plt.xlabel("Date")
    plt.ylabel("Price")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

############################################
# 7) MAIN USAGE EXAMPLE
############################################
if __name__=="__main__":
    # 1) Load & scale
    df_scaled, df_complete_all, scaler= load_and_scale_data(
        "Silver Futures Historical Data.csv",
        "Silver Futures Historical Data_Complete.csv"
    )

    # 2) Rolling forecasts => final_rolling_fc
    final_rolling_fc= rolling_train_validate_predict_moe(
        df_full= df_complete_all,
        scaler_obj= scaler,
        model_types=["LSTM","GRU","RNN","CNN","Transformer","N-BEATS","N-HITS","SVM","Boost"],
        start_train_cutoff=pd.to_datetime("2024-07-01"),
        start_val_cutoff=pd.to_datetime("2024-11-30"),
        start_pred=pd.to_datetime("2024-12-01"),
        end_pred=pd.to_datetime("2025-01-02"),
        horizon_days=30,
        do_daily_plots=False
    )
    print("\n=== HEAD of final_rolling_fc ===")
    print(final_rolling_fc.head(40))

    # 3) Build "super advanced" mixture-of-experts
    df_moe= compute_super_advanced_moe(final_rolling_fc, df_complete_all)

    # 4) Plot => from 2025-01-02..2025-01-31 => models vs MoE
    plot_super_advanced_moe_vs_models(
        final_rolling_fc,
        df_moe,
        from_d=pd.to_datetime("2025-01-02"),
        to_d=pd.to_datetime("2025-01-31")
    )

    # 5) (Optional) overlay newly revealed actual data:
    plot_super_advanced_moe_with_feb_actual(
        final_rolling_fcst=final_rolling_fc,
        df_moe=df_moe,
        feb_actual_csv="Silver Futures Historical Data_Final Pure Predictions.csv",
        start_plot=pd.to_datetime("2025-01-02"),
        end_plot=pd.to_datetime("2025-01-31")
    )

    # 6) Fit polynomials (up to degree=70) for both Actual & MoE, then plot & print results
    polynomial_fitting_actual_and_moe(
        df_moe,
        csv_actual="Silver Futures Historical Data_Final Pure Predictions.csv",
        max_degree=70
    )

    print("\nAll done with MoE + polynomial fittings for both Actual and MoE!")
# Out:
# === Rolling Day 2024-12-01 ===
#   train_cutoff=2024-07-01  val_cutoff=2024-11-30
#   Forecast next 30 days from 2024-12-01 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-01_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-01_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-01_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-01_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-01_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-01_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-01_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-01_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-01_V1.pkl
#
# === Rolling Day 2024-12-02 ===
#   train_cutoff=2024-07-02  val_cutoff=2024-12-01
#   Forecast next 30 days from 2024-12-02 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-02_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-02_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-02_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-02_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-02_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-02_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-02_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-02_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-02_V1.pkl
#
# === Rolling Day 2024-12-03 ===
#   train_cutoff=2024-07-03  val_cutoff=2024-12-02
#   Forecast next 30 days from 2024-12-03 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-03_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-03_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-03_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-03_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-03_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-03_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-03_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-03_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-03_V1.pkl
#
# === Rolling Day 2024-12-04 ===
#   train_cutoff=2024-07-04  val_cutoff=2024-12-03
#   Forecast next 30 days from 2024-12-04 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-04_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-04_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-04_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-04_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-04_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-04_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-04_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-04_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-04_V1.pkl
#
# === Rolling Day 2024-12-05 ===
#   train_cutoff=2024-07-05  val_cutoff=2024-12-04
#   Forecast next 30 days from 2024-12-05 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-05_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-05_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-05_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-05_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-05_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-05_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-05_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-05_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-05_V1.pkl
#
# === Rolling Day 2024-12-06 ===
#   train_cutoff=2024-07-06  val_cutoff=2024-12-05
#   Forecast next 30 days from 2024-12-06 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-06_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-06_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-06_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-06_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-06_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-06_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-06_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-06_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-06_V1.pkl
#
# === Rolling Day 2024-12-07 ===
#   train_cutoff=2024-07-07  val_cutoff=2024-12-06
#   Forecast next 30 days from 2024-12-07 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-07_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-07_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-07_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-07_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-07_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-07_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-07_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-07_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-07_V1.pkl
#
# === Rolling Day 2024-12-08 ===
#   train_cutoff=2024-07-08  val_cutoff=2024-12-07
#   Forecast next 30 days from 2024-12-08 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-08_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-08_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-08_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-08_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-08_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-08_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-08_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-08_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-08_V1.pkl
#
# === Rolling Day 2024-12-09 ===
#   train_cutoff=2024-07-09  val_cutoff=2024-12-08
#   Forecast next 30 days from 2024-12-09 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-09_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-09_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-09_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-09_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-09_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-09_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-09_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-09_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-09_V1.pkl
#
# === Rolling Day 2024-12-10 ===
#   train_cutoff=2024-07-10  val_cutoff=2024-12-09
#   Forecast next 30 days from 2024-12-10 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-10_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-10_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-10_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-10_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-10_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-10_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-10_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-10_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-10_V1.pkl
#
# === Rolling Day 2024-12-11 ===
#   train_cutoff=2024-07-11  val_cutoff=2024-12-10
#   Forecast next 30 days from 2024-12-11 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-11_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-11_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-11_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-11_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-11_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-11_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-11_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-11_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-11_V1.pkl
#
# === Rolling Day 2024-12-12 ===
#   train_cutoff=2024-07-12  val_cutoff=2024-12-11
#   Forecast next 30 days from 2024-12-12 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-12_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-12_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-12_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-12_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-12_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-12_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-12_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-12_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-12_V1.pkl
#
# === Rolling Day 2024-12-13 ===
#   train_cutoff=2024-07-13  val_cutoff=2024-12-12
#   Forecast next 30 days from 2024-12-13 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-13_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-13_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-13_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-13_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-13_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-13_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-13_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-13_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-13_V1.pkl
#
# === Rolling Day 2024-12-14 ===
#   train_cutoff=2024-07-14  val_cutoff=2024-12-13
#   Forecast next 30 days from 2024-12-14 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-14_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-14_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-14_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-14_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-14_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-14_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-14_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-14_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-14_V1.pkl
#
# === Rolling Day 2024-12-15 ===
#   train_cutoff=2024-07-15  val_cutoff=2024-12-14
#   Forecast next 30 days from 2024-12-15 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-15_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-15_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-15_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-15_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-15_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-15_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-15_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-15_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-15_V1.pkl
#
# === Rolling Day 2024-12-16 ===
#   train_cutoff=2024-07-16  val_cutoff=2024-12-15
#   Forecast next 30 days from 2024-12-16 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-16_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-16_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-16_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-16_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-16_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-16_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-16_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-16_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-16_V1.pkl
#
# === Rolling Day 2024-12-17 ===
#   train_cutoff=2024-07-17  val_cutoff=2024-12-16
#   Forecast next 30 days from 2024-12-17 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-17_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-17_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-17_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-17_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-17_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-17_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-17_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-17_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-17_V1.pkl
#
# === Rolling Day 2024-12-18 ===
#   train_cutoff=2024-07-18  val_cutoff=2024-12-17
#   Forecast next 30 days from 2024-12-18 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-18_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-18_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-18_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-18_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-18_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-18_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-18_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-18_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-18_V1.pkl
#
# === Rolling Day 2024-12-19 ===
#   train_cutoff=2024-07-19  val_cutoff=2024-12-18
#   Forecast next 30 days from 2024-12-19 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-19_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-19_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-19_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-19_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-19_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-19_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-19_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-19_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-19_V1.pkl
#
# === Rolling Day 2024-12-20 ===
#   train_cutoff=2024-07-20  val_cutoff=2024-12-19
#   Forecast next 30 days from 2024-12-20 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-20_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-20_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-20_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-20_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-20_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-20_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-20_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-20_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-20_V1.pkl
#
# === Rolling Day 2024-12-21 ===
#   train_cutoff=2024-07-21  val_cutoff=2024-12-20
#   Forecast next 30 days from 2024-12-21 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-21_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-21_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-21_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-21_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-21_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-21_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-21_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-21_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-21_V1.pkl
#
# === Rolling Day 2024-12-22 ===
#   train_cutoff=2024-07-22  val_cutoff=2024-12-21
#   Forecast next 30 days from 2024-12-22 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-22_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-22_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-22_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-22_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-22_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-22_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-22_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-22_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-22_V1.pkl
#
# === Rolling Day 2024-12-23 ===
#   train_cutoff=2024-07-23  val_cutoff=2024-12-22
#   Forecast next 30 days from 2024-12-23 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-23_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-23_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-23_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-23_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-23_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-23_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-23_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-23_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-23_V1.pkl
#
# === Rolling Day 2024-12-24 ===
#   train_cutoff=2024-07-24  val_cutoff=2024-12-23
#   Forecast next 30 days from 2024-12-24 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-24_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-24_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-24_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-24_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-24_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-24_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-24_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-24_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-24_V1.pkl
#
# === Rolling Day 2024-12-25 ===
#   train_cutoff=2024-07-25  val_cutoff=2024-12-24
#   Forecast next 30 days from 2024-12-25 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-25_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-25_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-25_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-25_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-25_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-25_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-25_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-25_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-25_V1.pkl
#
# === Rolling Day 2024-12-26 ===
#   train_cutoff=2024-07-26  val_cutoff=2024-12-25
#   Forecast next 30 days from 2024-12-26 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-26_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-26_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-26_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-26_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-26_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-26_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-26_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-26_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-26_V1.pkl
#
# === Rolling Day 2024-12-27 ===
#   train_cutoff=2024-07-27  val_cutoff=2024-12-26
#   Forecast next 30 days from 2024-12-27 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-27_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-27_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-27_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-27_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-27_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-27_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-27_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-27_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-27_V1.pkl
#
# === Rolling Day 2024-12-28 ===
#   train_cutoff=2024-07-28  val_cutoff=2024-12-27
#   Forecast next 30 days from 2024-12-28 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-28_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-28_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-28_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-28_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-28_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-28_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-28_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-28_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-28_V1.pkl
#
# === Rolling Day 2024-12-29 ===
#   train_cutoff=2024-07-29  val_cutoff=2024-12-28
#   Forecast next 30 days from 2024-12-29 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-29_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-29_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-29_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-29_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-29_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-29_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-29_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-29_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-29_V1.pkl
#
# === Rolling Day 2024-12-30 ===
#   train_cutoff=2024-07-30  val_cutoff=2024-12-29
#   Forecast next 30 days from 2024-12-30 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-30_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-30_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-30_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-30_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-30_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-30_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-30_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-30_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-30_V1.pkl
#
# === Rolling Day 2024-12-31 ===
#   train_cutoff=2024-07-31  val_cutoff=2024-12-30
#   Forecast next 30 days from 2024-12-31 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-31_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-31_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-31_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-31_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-31_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-31_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-31_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-31_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-31_V1.pkl
#
# === Rolling Day 2025-01-01 ===
#   train_cutoff=2024-08-01  val_cutoff=2024-12-31
#   Forecast next 30 days from 2025-01-01 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2025-01-01_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2025-01-01_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2025-01-01_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2025-01-01_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2025-01-01_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2025-01-01_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2025-01-01_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2025-01-01_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2025-01-01_V1.pkl
#
# === Rolling Day 2025-01-02 ===
#   train_cutoff=2024-08-02  val_cutoff=2025-01-01
#   Forecast next 30 days from 2025-01-02 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2025-01-02_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2025-01-02_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2025-01-02_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2025-01-02_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2025-01-02_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2025-01-02_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2025-01-02_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2025-01-02_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2025-01-02_V1.pkl
#
# === HEAD of final_rolling_fc ===
#     ForecastDate  Pred_Price_unscaled  Pred_Open_unscaled  Pred_High_unscaled  \
# 240   2024-12-01            31.141379           30.405074           30.493824
# 241   2024-12-02            31.045956           29.658617           30.215023
# 242   2024-12-03            31.662073           29.312402           29.424846
# 243   2024-12-04            31.191013           29.191437           29.585954
# 244   2024-12-05            31.106886           29.205841           29.379925
# 245   2024-12-06            32.111337           29.301693           29.095980
# 246   2024-12-07            32.070207           28.965967           29.002302
# 247   2024-12-08            32.138059           28.974586           28.800263
# 248   2024-12-09            31.722576           28.798373           28.751911
# 249   2024-12-10            30.831747           28.730396           29.018601
# 250   2024-12-11            31.040233           29.082705           29.249878
# 251   2024-12-12            30.739759           29.042424           29.247960
# 252   2024-12-13            29.938905           29.017538           29.232549
# 253   2024-12-14            29.373447           29.053892           29.286029
# 254   2024-12-15            29.749715           29.253631           29.466106
# 255   2024-12-16            30.389992           29.008685           29.443423
# 256   2024-12-17            30.435332           29.026459           29.478488
# 257   2024-12-18            30.442705           29.075725           29.187238
# 258   2024-12-19            30.185633           29.239067           29.535706
# 259   2024-12-20            29.748552           29.265592           29.532192
# 260   2024-12-21            29.010734           29.217553           29.526547
# 261   2024-12-22            29.049795           29.425304           29.524821
# 262   2024-12-23            29.030719           29.319383           29.513266
# 263   2024-12-24            29.028828           29.345244           29.527706
# 264   2024-12-25            28.788934           29.272734           29.492989
# 265   2024-12-26            28.788176           29.303380           29.454085
# 266   2024-12-27            28.532049           29.144767           29.477005
# 267   2024-12-28            28.364696           28.982223           29.466015
# 268   2024-12-29            28.785461           29.159287           29.477205
# 269   2024-12-30            28.792149           29.139321           29.491285
# 510   2024-12-02            31.136275           30.371556           30.297289
# 511   2024-12-03            31.133609           29.490202           29.887918
# 512   2024-12-04            31.534354           29.183312           29.057954
# 513   2024-12-05            31.141474           28.618820           29.177884
# 514   2024-12-06            31.140126           28.420712           28.628152
# 515   2024-12-07            32.123602           27.903735           28.083136
# 516   2024-12-08            32.005652           27.645354           27.476072
# 517   2024-12-09            32.135413           27.039514           26.981918
# 518   2024-12-10            31.830288           26.486084           26.388618
# 519   2024-12-11            30.832166           25.922599           26.258877
#
#      Pred_Low_unscaled   BaseDate  Model
# 240          29.461850 2024-12-01  Boost
# 241          28.929095 2024-12-01  Boost
# 242          28.329650 2024-12-01  Boost
# 243          28.336038 2024-12-01  Boost
# 244          28.262161 2024-12-01  Boost
# 245          28.410012 2024-12-01  Boost
# 246          28.178716 2024-12-01  Boost
# 247          28.177148 2024-12-01  Boost
# 248          28.157653 2024-12-01  Boost
# 249          27.863395 2024-12-01  Boost
# 250          27.982740 2024-12-01  Boost
# 251          27.963512 2024-12-01  Boost
# 252          28.202834 2024-12-01  Boost
# 253          28.532202 2024-12-01  Boost
# 254          28.381345 2024-12-01  Boost
# 255          28.392233 2024-12-01  Boost
# 256          28.290816 2024-12-01  Boost
# 257          28.586319 2024-12-01  Boost
# 258          28.666466 2024-12-01  Boost
# 259          28.392523 2024-12-01  Boost
# 260          28.542651 2024-12-01  Boost
# 261          28.621442 2024-12-01  Boost
# 262          28.651478 2024-12-01  Boost
# 263          28.636127 2024-12-01  Boost
# 264          28.582503 2024-12-01  Boost
# 265          28.572515 2024-12-01  Boost
# 266          28.373584 2024-12-01  Boost
# 267          28.546804 2024-12-01  Boost
# 268          28.665319 2024-12-01  Boost
# 269          28.446503 2024-12-01  Boost
# 510          29.400756 2024-12-02  Boost
# 511          28.875543 2024-12-02  Boost
# 512          28.306627 2024-12-02  Boost
# 513          27.792993 2024-12-02  Boost
# 514          27.400294 2024-12-02  Boost
# 515          27.295409 2024-12-02  Boost
# 516          26.954796 2024-12-02  Boost
# 517          26.071076 2024-12-02  Boost
# 518          25.596033 2024-12-02  Boost
# 519          25.211508 2024-12-02  Boost
#
# === SUPER ADVANCED MOE w/ Polynomials & Voting ===
# === Best Polynomial Fitting Results ===
# [Actual] => Degree=5, Val MSE=0.250633
#      y = 1.1582e-09*x^5-6.9896e-05*x^4+9.4023e-01*x^3+1.8688e+04*x^2-5.6564e+08*x+3.7931e+12
#
# [MoE] => Degree=5, Val MSE=0.019848
#      y = -5.8177e-10*x^5+3.5113e-05*x^4-4.7237e-01*x^3-9.3882e+03*x^2+2.8418e+08*x-1.9057e+12
#
# === Derivative for Actual (Degree 5 => 4) ===
#    d/dx of Actual = 5.7908e-09*x^4-2.7959e-04*x^3+2.8207e+00*x^2+3.7377e+04*x-5.6564e+08
#
# === Derivative for MoE (Degree 5 => 4) ===
#    d/dx of MoE = -2.9088e-09*x^4+1.4045e-04*x^3-1.4171e+00*x^2-1.8776e+04*x+2.8418e+08
# All done with MoE + polynomial fittings for both Actual and MoE!

# %%
####################################################
# SUPER ADVANCED MOE SCRIPT (WITH ACTUAL & POLYNOMIALS)
# + UPDATED: Returns df_merge, best_poly_info 
#   and Adds Confidence-Based Trading On MoE
####################################################

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import warnings
import os
import random
import torch
import torch.nn as nn
import torch.nn.functional as F
import joblib

from numpy.polynomial.polynomial import polyfit, polyval
from sklearn.preprocessing import MinMaxScaler
from sklearn.svm import SVR
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.multioutput import MultiOutputRegressor
from sklearn.metrics import mean_squared_error
from matplotlib.lines import Line2D  # for custom legends

warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=pd.errors.PerformanceWarning)
pd.options.mode.chained_assignment = None

# Global seeds & device
torch.manual_seed(0)
np.random.seed(0)
random.seed(0)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(0)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

BEST_MODELS_DIR = "."   # Where .pt/.pkl model files are stored
features = ["Price","Open","High","Low"]
WINDOW_SIZE = 35

############################################
# 1) Model Definitions & Loading
############################################
class BaseModel(nn.Module):
    def __init__(self, model_type="LSTM", window_width=35):
        super().__init__()
        self.model_type = model_type

        if model_type == "CNN":
            self.conv1 = nn.Conv1d(4, 64, 3)
            self.conv2 = nn.Conv1d(64, 128, 3)
            with torch.no_grad():
                dummy = torch.zeros(1, 4, window_width)
                outdummy = self.conv2(F.relu(self.conv1(dummy)))
                conv_output_size = outdummy.shape[1]*outdummy.shape[2]
            self.fc = nn.Linear(conv_output_size, 4)

        elif model_type == "LSTM":
            self.rnn = nn.LSTM(4, 128, num_layers=2, batch_first=True, dropout=0.05)
            self.fc = nn.Linear(128, 4)

        elif model_type == "GRU":
            self.rnn = nn.GRU(4, 128, num_layers=2, batch_first=True, dropout=0.05)
            self.fc = nn.Linear(128, 4)

        elif model_type == "RNN":
            self.rnn = nn.RNN(4, 128, num_layers=2, nonlinearity="relu", batch_first=True, dropout=0.05)
            self.fc = nn.Linear(128, 4)

        elif model_type == "EnhancedLSTM":
            self.rnn = nn.LSTM(4, 128, num_layers=3, batch_first=True, dropout=0.1)
            self.bn  = nn.BatchNorm1d(128)
            self.dropout = nn.Dropout(0.1)
            self.fc = nn.Linear(128, 4)

        elif model_type == "Transformer":
            self.input_linear = nn.Linear(4, 128)
            enc_layer = nn.TransformerEncoderLayer(d_model=128, nhead=8, dropout=0.05)
            self.transformer_encoder = nn.TransformerEncoder(enc_layer, num_layers=3)
            self.fc = nn.Linear(128,4)

        elif model_type in ["N-BEATS","N-HITS"]:
            self.input_size= window_width*4
            self.blocks= nn.ModuleList([nn.Sequential(
                nn.Linear(self.input_size,128),
                nn.ReLU(),
                nn.Linear(128,128),
                nn.ReLU(),
                nn.Linear(128,4)
            ) for _ in range(3)])
        else:
            raise ValueError(f"Invalid model_type: {model_type}")

    def forward(self, x):
        if self.model_type == "CNN":
            x = x.permute(0,2,1)
            x = F.relu(self.conv1(x))
            x = F.relu(self.conv2(x))
            x = x.view(x.size(0), -1)
            return self.fc(x)

        elif self.model_type in ["LSTM","GRU","RNN"]:
            out, _ = self.rnn(x)
            out = out[:,-1,:]
            return self.fc(out)

        elif self.model_type == "EnhancedLSTM":
            out, _= self.rnn(x)
            out = out[:,-1,:]
            out = self.bn(out)
            out = self.dropout(out)
            return self.fc(out)

        elif self.model_type == "Transformer":
            x = self.input_linear(x)
            x = x.permute(1,0,2)
            x = self.transformer_encoder(x)
            x = x[-1,:,:]
            return self.fc(x)

        elif self.model_type in ["N-BEATS","N-HITS"]:
            xflat = x.reshape(x.size(0), -1)
            forecast = 0
            for block in self.blocks:
                forecast += block(xflat)
            return forecast

        else:
            raise ValueError("Invalid model_type")

class SklearnWrapper:
    def __init__(self, model):
        self.model= model
    def forward(self, x):
        arr= x.cpu().numpy().reshape(1,-1)
        pred= self.model.predict(arr)
        return torch.from_numpy(pred).float().to(x.device)
    def eval(self): pass
    def __call__(self, x):
        return self.forward(x)

def load_torch_model(model_type, window_size, path):
    if not os.path.exists(path):
        raise FileNotFoundError(f"File not found: {path}")
    print(f"[PyTorch] Loading {model_type} from {path}")
    net= BaseModel(model_type, window_size).to(device)
    net.load_state_dict(torch.load(path, map_location=device))
    net.eval()
    return net

def load_sklearn_model(model_type, path):
    if not os.path.exists(path):
        raise FileNotFoundError(f"File not found: {path}")
    print(f"[sklearn] Loading {model_type} => {path}")
    loaded= joblib.load(path)
    return SklearnWrapper(loaded)

############################################
# 2) Load & Scale Data
############################################
def load_and_scale_data(train_csv="Silver Futures Historical Data.csv",
                        complete_csv="Silver Futures Historical Data_Complete.csv"):
    df_train = pd.read_csv(train_csv)
    df_train["Date"] = pd.to_datetime(df_train["Date"], errors="coerce")
    for col in ["Vol.","Change %"]:
        if col in df_train.columns:
            df_train.drop(columns=[col], errors="ignore", inplace=True)

    for feat in features:
        if feat not in df_train.columns:
            df_train[feat]= np.nan
        else:
            df_train[feat]= df_train[feat].astype(str).str.replace(",", "", regex=True)
            df_train[feat]= pd.to_numeric(df_train[feat], errors="coerce")

    df_train.sort_values("Date", inplace=True)
    df_train.reset_index(drop=True, inplace=True)

    train_cutoff= pd.to_datetime("2024-07-01")
    val_cutoff  = pd.to_datetime("2024-11-30")
    test_cutoff = pd.to_datetime("2024-12-01")

    df_trn= df_train[df_train["Date"]< train_cutoff].copy()
    df_val= df_train[(df_train["Date"]>= train_cutoff)&(df_train["Date"]<= val_cutoff)].copy()
    df_tst= df_train[df_train["Date"]>= test_cutoff].copy()

    df_trn_nonan= df_trn.dropna(subset=features)
    scaler= MinMaxScaler()
    scaler.fit(df_trn_nonan[features])

    df_trn_scaled= df_trn.copy()
    if not df_trn_nonan.empty:
        df_trn_scaled.loc[df_trn_nonan.index, features]= scaler.transform(df_trn_nonan[features])
    df_val_scaled= df_val.copy()
    val_no_nan= df_val_scaled.dropna(subset=features)
    if not val_no_nan.empty:
        df_val_scaled.loc[val_no_nan.index, features]= scaler.transform(val_no_nan[features])
    df_tst_scaled= df_tst.copy()
    trn_mins= df_trn_nonan[features].min()
    df_tst_filled= df_tst_scaled[features].fillna(trn_mins)
    df_tst_scaled.loc[:, features]= scaler.transform(df_tst_filled)

    df_scaled= pd.concat([df_trn_scaled, df_val_scaled, df_tst_scaled], ignore_index=True)

    # also load complete
    df_complete= pd.read_csv(complete_csv)
    df_complete["Date"]= pd.to_datetime(df_complete["Date"], errors="coerce")
    for col in ["Vol.","Change %"]:
        if col in df_complete.columns:
            df_complete.drop(columns=[col], errors="ignore", inplace=True)
    for feat in features:
        df_complete[feat]= df_complete[feat].astype(str).str.replace(",", "",regex=True).astype(float)
    df_complete.sort_values("Date", inplace=True)
    df_complete.reset_index(drop=True, inplace=True)

    return df_scaled, df_complete, scaler

############################################
# 3) Rolling Forecast
############################################
def get_latest_window(df_actual, current_date, window=35, scaler=None):
    mask= df_actual["Date"]< current_date
    sub= df_actual.loc[mask].copy()
    sub.sort_values("Date", inplace=True)
    if len(sub)< window:
        return None
    sub[features]= sub[features].fillna(method="ffill").fillna(method="bfill")
    arr= scaler.transform(sub[features].iloc[-window:].values)
    return arr

def forecast_n_days_from_date(model, df_actual, start_date, window=35, horizon=30,
                              device=None, scaler=None, noise_std=0.05):
    """
    Rolling forecast with mild random noise => more "volatility". 
    """
    def add_noise_4d(prices, std=0.01):
        noise= np.random.normal(0.0, std, size=prices.shape)
        return np.clip(prices+noise, a_min=0, a_max=None)

    arr_window= get_latest_window(df_actual, start_date, window, scaler)
    if arr_window is None:
        return pd.DataFrame()

    rolling_buffer= np.copy(arr_window)
    forecast_records=[]
    cur_dt= pd.to_datetime(start_date)

    for i in range(horizon):
        X_in= torch.tensor(rolling_buffer,dtype=torch.float).unsqueeze(0).to(device)
        with torch.no_grad():
            out_scaled= model(X_in).cpu().numpy()[0]
        out_unscaled= scaler.inverse_transform(out_scaled.reshape(1,-1))[0]
        # add a little random noise => final
        out_noisy= add_noise_4d(out_unscaled, noise_std)

        dayx= cur_dt+ pd.Timedelta(days=i)
        forecast_records.append({
            "ForecastDate": dayx,
            "Pred_Price_unscaled": out_noisy[0],
            "Pred_Open_unscaled":  out_noisy[1],
            "Pred_High_unscaled":  out_noisy[2],
            "Pred_Low_unscaled":   out_noisy[3]
        })

        out_noisy_scaled= scaler.transform(out_noisy.reshape(1,-1))[0]
        rolling_buffer= np.vstack([rolling_buffer[1:], out_noisy_scaled.reshape(1,-1)])

    return pd.DataFrame(forecast_records)

def rolling_train_validate_predict_moe(
    df_full, scaler_obj, model_types,
    start_train_cutoff=pd.to_datetime("2024-07-01"),
    start_val_cutoff=pd.to_datetime("2024-11-30"),
    start_pred=pd.to_datetime("2024-12-01"),
    end_pred=pd.to_datetime("2025-01-01"),
    horizon_days=30,
    do_daily_plots=False
):
    df_sorted= df_full.copy()
    df_sorted.sort_values("Date", inplace=True)

    date_rng= pd.date_range(start_pred, end_pred, freq="D")
    all_records=[]

    for i, day_i in enumerate(date_rng):
        train_cutoff_i= start_train_cutoff + pd.Timedelta(days=i)
        val_cutoff_i  = start_val_cutoff   + pd.Timedelta(days=i)

        print(f"\n=== Rolling Day {day_i.date()} ===")
        print(f"  train_cutoff={train_cutoff_i.date()}  val_cutoff={val_cutoff_i.date()}")
        print(f"  Forecast next {horizon_days} days from {day_i.date()} w/ noise => more volatility")

        # load each model
        model_dict={}
        for mt in model_types:
            out_file= f"best_{mt}_{day_i.strftime('%Y-%m-%d')}_V1"
            if mt in ["SVM","GPR","Boost"]:
                out_file+= ".pkl"
                net= load_sklearn_model(mt, os.path.join(BEST_MODELS_DIR, out_file))
            else:
                out_file+= ".pt"
                net= load_torch_model(mt, WINDOW_SIZE, os.path.join(BEST_MODELS_DIR, out_file))
            model_dict[mt]= net

        daily_fcst={}
        for mt, netobj in model_dict.items():
            df_fc= forecast_n_days_from_date(
                model=netobj,
                df_actual=df_sorted,
                start_date=day_i,
                window=WINDOW_SIZE,
                horizon=horizon_days,
                device=device,
                scaler=scaler_obj,
                noise_std=0.01
            )
            if not df_fc.empty:
                df_fc["BaseDate"]= day_i
                df_fc["Model"]= mt
                daily_fcst[mt]= df_fc
                all_records.append(df_fc)
            else:
                daily_fcst[mt]= pd.DataFrame()

        # optional daily plots
        if do_daily_plots and (day_i== date_rng[-1]):
            pass

    df_all= pd.concat(all_records, ignore_index=True) if all_records else pd.DataFrame()
    df_all.sort_values(["Model","BaseDate","ForecastDate"], inplace=True)
    return df_all

############################################
# 4) Advanced MoE (Population Voting w/ mini-model approach)
############################################
def build_mini_models_table(final_rolling_fcst, df_actual):
    """
    For each (model, baseDate), measure january performance => mae, slope alignment, volatility alignment
    """
    start_jan= pd.to_datetime("2024-12-01")
    end_jan=   pd.to_datetime("2025-01-01")
    df_jan= final_rolling_fcst[
        (final_rolling_fcst["ForecastDate"]>= start_jan)&
        (final_rolling_fcst["ForecastDate"]<= end_jan)
    ].copy()
    if df_jan.empty:
        return pd.DataFrame(), 0.01

    df_act_jan= df_actual[
        (df_actual["Date"]>= start_jan)&
        (df_actual["Date"]<= end_jan)
    ].copy()
    df_act_jan.rename(columns={"Date":"ForecastDate","Price":"ActualPrice"}, inplace=True)

    df_merge= pd.merge(
        df_jan[["Model","BaseDate","ForecastDate","Pred_Price_unscaled"]],
        df_act_jan[["ForecastDate","ActualPrice"]],
        on="ForecastDate",
        how="inner"
    )
    df_merge["AbsError"]= (df_merge["Pred_Price_unscaled"]- df_merge["ActualPrice"]).abs()

    # mae
    g_mae= df_merge.groupby(["Model","BaseDate"])["AbsError"].mean().reset_index()
    g_mae.rename(columns={"AbsError":"mae_jan"}, inplace=True)

    # slope alignment => quick polynomial fit
    def poly_slope_diff(sub):
        sub= sub.sort_values("ForecastDate")
        xvals= np.arange(len(sub))
        yvals= sub["Pred_Price_unscaled"].values
        if len(yvals)< 4:
            return 0.5
        coefs= polyfit(xvals,yvals,deg=2)
        y_pred= polyval(xvals, coefs)
        resid= yvals- y_pred
        sse= np.mean(resid**2)
        return float(np.exp(-sse))

    def group_slope_func(grp):
        grp["slopeAlign_jan"]= poly_slope_diff(grp)
        return grp

    df_slope= df_merge.groupby(["Model","BaseDate"], group_keys=False).apply(group_slope_func)
    df_slope_agg= df_slope.groupby(["Model","BaseDate"])["slopeAlign_jan"].mean().reset_index()

    # real vol
    df_act_jan_sorted= df_act_jan.drop_duplicates("ForecastDate").copy()
    df_act_jan_sorted.sort_values("ForecastDate", inplace=True)
    df_act_jan_sorted["DayChange"]= df_act_jan_sorted["ActualPrice"].diff()
    real_vol= df_act_jan_sorted["DayChange"].std(skipna=True)
    if pd.isna(real_vol) or real_vol< 1e-9:
        real_vol= 0.01

    # pred vol => stdev of dayChange
    def mini_volatility(sub):
        sub= sub.sort_values("ForecastDate")
        sub["DayChange"]= sub["Pred_Price_unscaled"].diff()
        vol_= sub["DayChange"].std(skipna=True)
        if pd.isna(vol_): vol_= 0.01
        return vol_

    g_vol= df_merge.groupby(["Model","BaseDate"]).apply(mini_volatility).reset_index()
    g_vol.rename(columns={0:"predVol_jan"}, inplace=True)
    def vol_align(v):
        ratio= v/ real_vol
        return np.exp(-abs(ratio-1.0))
    g_vol["volAlign_jan"]= g_vol["predVol_jan"].apply(vol_align)

    mini_models= pd.merge(g_mae, df_slope_agg, on=["Model","BaseDate"], how="left")
    mini_models= pd.merge(mini_models, g_vol[["Model","BaseDate","predVol_jan","volAlign_jan"]], 
                          on=["Model","BaseDate"], how="left")

    mae_min= mini_models["mae_jan"].min()
    mae_max= mini_models["mae_jan"].max()
    if np.isclose(mae_min, mae_max):
        mini_models["baseAcc"]= 1.0
    else:
        mini_models["baseAcc"]= 1.0- ((mini_models["mae_jan"]-mae_min)/(mae_max-mae_min))

    return mini_models, real_vol

def compute_super_advanced_moe(final_rolling_fcst, df_actual):
    """
    Weighted sum => final MoE price, using mae, slope alignment, vol alignment, plus daily direction factor
    """
    print("\n=== SUPER ADVANCED MOE w/ Polynomials & Voting ===\n")
    mini_models, real_vol= build_mini_models_table(final_rolling_fcst, df_actual)
    if mini_models.empty:
        print("No january data => fallback => uniform daily average")
        return pd.DataFrame(columns=["ForecastDate","MOE_Price"])

    mm_dict={}
    for i,row in mini_models.iterrows():
        mm_dict[(row["Model"], row["BaseDate"])]= {
            "baseAcc": row["baseAcc"],
            "slopeAlign_jan": row["slopeAlign_jan"],
            "volAlign_jan": row["volAlign_jan"]
        }

    start_moe= pd.to_datetime("2025-01-02")
    end_moe=   pd.to_datetime("2025-01-31")
    all_days=  pd.date_range(start_moe, end_moe, freq="D")
    records=[]

    for d in all_days:
        df_d= final_rolling_fcst[ final_rolling_fcst["ForecastDate"]== d ].copy()
        if df_d.empty:
            continue

        d_prev= d - pd.Timedelta(days=1)
        ups=0
        downs=0
        total=0
        w_sums=0.0
        weighted_price=0.0

        for idx,row in df_d.iterrows():
            m= row["Model"]
            bD= row["BaseDate"]
            if (m,bD) not in mm_dict:
                continue
            baseAcc= mm_dict[(m,bD)]["baseAcc"]
            slopeA= mm_dict[(m,bD)]["slopeAlign_jan"]
            volA= mm_dict[(m,bD)]["volAlign_jan"]

            df_dprev= final_rolling_fcst[
                (final_rolling_fcst["Model"]==m)&
                (final_rolling_fcst["BaseDate"]==bD)&
                (final_rolling_fcst["ForecastDate"]==d_prev)
            ]
            if df_dprev.empty:
                dirFactor=1.0
            else:
                pd_today= row["Pred_Price_unscaled"]
                pd_yest= df_dprev["Pred_Price_unscaled"].values[0]
                if pd_today>pd_yest:
                    ups+=1
                    dirFactor=1.1
                elif pd_today< pd_yest:
                    downs+=1
                    dirFactor=0.9
                else:
                    dirFactor=1.0
                total+=1

            w= baseAcc* slopeA* volA* dirFactor
            w_sums+= w
            weighted_price+= w* row["Pred_Price_unscaled"]

        if np.isclose(w_sums,0.0):
            day_moe= df_d["Pred_Price_unscaled"].mean()
        else:
            day_moe= weighted_price/ w_sums

        if total>0:
            fraction_up= ups/ total
            fraction_down= downs/ total
            if fraction_up> 0.7:
                day_moe*= 1.01
            elif fraction_down> 0.7:
                day_moe*= 0.99

        # final random tweak
        day_moe+= np.random.normal(0, day_moe*0.002)
        records.append({"ForecastDate": d, "MOE_Price": day_moe})

    df_moe= pd.DataFrame(records)
    df_moe.sort_values("ForecastDate", inplace=True)
    return df_moe

def plot_super_advanced_moe_vs_models(final_rolling_fcst, df_moe,
                                      from_d=pd.to_datetime("2025-01-02"),
                                      to_d=pd.to_datetime("2025-01-31")):
    """
    Plots all 9 models + super advanced MoE in [from_d..to_d], no actual overlay.
    """
    df_sel= final_rolling_fcst[
        (final_rolling_fcst["ForecastDate"]>= from_d)&
        (final_rolling_fcst["ForecastDate"]<= to_d)
    ].copy()

    plt.figure(figsize=(12,6))
    color_map = {
        "LSTM":"red","GRU":"blue","RNN":"green","CNN":"orange","EnhancedLSTM":"magenta",
        "Transformer":"cyan","N-BEATS":"brown","N-HITS":"pink","SVM":"olive","GPR":"teal","Boost":"purple"
    }
    for m in df_sel["Model"].unique():
        df_m= df_sel[df_sel["Model"]== m].copy()
        df_m_agg= df_m.groupby("ForecastDate", as_index=False)["Pred_Price_unscaled"].mean()
        c= color_map.get(m,"gray")
        plt.plot(df_m_agg["ForecastDate"], df_m_agg["Pred_Price_unscaled"], color=c, alpha=0.6, label=m)

    df_moe_sub= df_moe[
        (df_moe["ForecastDate"]>= from_d)&
        (df_moe["ForecastDate"]<= to_d)
    ].copy()
    if not df_moe_sub.empty:
        plt.plot(df_moe_sub["ForecastDate"], df_moe_sub["MOE_Price"],
                 color="black",linestyle="--",lw=2, label="SuperAdvancedMoE")

    plt.title(f"SuperAdvancedMoE vs. Models\n({from_d.date()}..{to_d.date()}) (Volatile MOE)")
    plt.xlabel("Date")
    plt.ylabel("Price")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

############################################
# 5) Polynomial Fitting for BOTH Actual & MoE
#    UPDATED so it returns (df_merge, best_poly_info)
############################################
def polynomial_fitting_actual_and_moe(
    df_moe,
    csv_actual="Silver Futures Historical Data_Final Pure Predictions.csv",
    max_degree=70
):
    """
    - Merge actual data & MoE => 1 DataFrame with columns: Date, Actual, MoE
    - Fit polynomials for Actual + MoE
    - Return df_merge + best_poly_info
    """
    # -- A) Read actual data and merge with MoE
    df_actual = pd.read_csv(csv_actual)
    df_actual["Date"] = pd.to_datetime(df_actual["Date"], errors="coerce")
    for col in ["Vol.","Change %"]:
        if col in df_actual.columns:
            df_actual.drop(columns=[col], errors="ignore", inplace=True)
    if "Price" in df_actual.columns:
        df_actual["Price"] = (
            df_actual["Price"].astype(str)
                               .str.replace(",", "", regex=True)
                               .astype(float)
        )
    df_actual.sort_values("Date", inplace=True)
    df_actual.reset_index(drop=True, inplace=True)

    df_moe_rename = df_moe.rename(columns={"ForecastDate":"Date", "MOE_Price":"MoE"})
    df_moe_rename.sort_values("Date", inplace=True)
    df_moe_rename.reset_index(drop=True, inplace=True)

    # Merge => columns: [Date, MoE, Price=>Actual]
    df_merge = pd.merge(
        df_moe_rename,
        df_actual[["Date","Price"]],
        on="Date", how="inner"
    ).rename(columns={"Price":"Actual"})

    if df_merge.empty:
        print("No overlapping dates between df_moe and actual data. Cannot do polynomial fitting.")
        return pd.DataFrame(), {}

    df_merge.sort_values("Date", inplace=True)
    df_merge.reset_index(drop=True, inplace=True)

    # For train/val split => even index => val, odd => train
    columns_to_fit = ["Actual", "MoE"]
    df_merge["mdates_num"] = mdates.date2num(df_merge["Date"])

    n_points = len(df_merge)
    indices = np.arange(n_points)
    val_mask = (indices % 2 == 0)
    train_mask   = ~val_mask

    color_map = {"Actual":"black", "MoE":"red"}
    best_poly_info = {}

    def format_poly(coeffs):
        terms=[]
        deg = len(coeffs)-1
        for i,c in enumerate(coeffs):
            p = deg - i
            if p>1:
                terms.append(f"{c:+.4e}*x^{p}")
            elif p==1:
                terms.append(f"{c:+.4e}*x")
            else:
                terms.append(f"{c:+.4e}")
        expr="".join(terms).replace("+-","-")
        if expr.startswith("+"):
            expr=expr[1:]
        return expr

    # ---------- Fit polynomials for each column ------------
    from sklearn.metrics import mean_squared_error
    for col in columns_to_fit:
        x_train = df_merge.loc[train_mask, "mdates_num"].values
        y_train = df_merge.loc[train_mask, col].values

        x_val   = df_merge.loc[val_mask, "mdates_num"].values
        y_val   = df_merge.loc[val_mask, col].values

        best_deg=None
        best_mse=float("inf")
        best_coefs=None

        for deg_ in range(1, max_degree+1):
            coefs_ = np.polyfit(x_train, y_train, deg_)
            preds_val = np.polyval(coefs_, x_val)
            mse_ = mean_squared_error(y_val, preds_val)
            if mse_ < best_mse:
                best_mse = mse_
                best_deg = deg_
                best_coefs = coefs_

        best_poly_info[col] = {
            "degree": best_deg,
            "mse": best_mse,
            "coeffs": best_coefs
        }

    # ---------- Plot best polynomial fits ------------
    plt.figure(figsize=(10,6))
    # Plot Actual / MoE points
    plt.scatter(df_merge.loc[train_mask, "Date"], df_merge.loc[train_mask, "Actual"],
                color="black", marker="o", label="Actual(Train)")
    plt.scatter(df_merge.loc[val_mask, "Date"], df_merge.loc[val_mask, "Actual"],
                color="black", marker="x", label="Actual(Val)")
    plt.scatter(df_merge.loc[train_mask, "Date"], df_merge.loc[train_mask, "MoE"],
                color="red", marker="o", label="MoE(Train)")
    plt.scatter(df_merge.loc[val_mask, "Date"], df_merge.loc[val_mask, "MoE"],
                color="red", marker="x", label="MoE(Val)")

    x_dense = np.linspace(df_merge["mdates_num"].min(), df_merge["mdates_num"].max(), 300)
    x_dense_dates = [mdates.num2date(xx) for xx in x_dense]

    for col in columns_to_fit:
        info = best_poly_info[col]
        coefs_ = info["coeffs"]
        deg_   = info["degree"]
        color_ = color_map.get(col, "gray")
        y_dense= np.polyval(coefs_, x_dense)
        plt.plot(x_dense_dates, y_dense, color=color_, linewidth=2,
                 label=f"{col} Poly(Deg {deg_})")

    plt.title("Best Polynomial Fits (Test Window): Actual vs. MoE")
    plt.xlabel("Date")
    plt.ylabel("Price")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    # ---------- Print out polynomial expressions ------------
    print("\n=== Best Polynomial Fitting Results ===")
    for col in columns_to_fit:
        deg_   = best_poly_info[col]["degree"]
        mse_   = best_poly_info[col]["mse"]
        coefs_ = best_poly_info[col]["coeffs"]
        expr_  = format_poly(coefs_)
        print(f"[{col}] => Degree={deg_}, Val MSE={mse_:.6f}")
        print(f"     y = {expr_}\n")

    # ---------- Derivative curves in one figure ------------
    plt.figure(figsize=(10,6))
    for col in columns_to_fit:
        coefs_ = best_poly_info[col]["coeffs"]
        d_coefs_ = np.polyder(coefs_)
        y_deriv  = np.polyval(d_coefs_, x_dense)
        color_   = color_map.get(col, "gray")
        plt.plot(x_dense_dates, y_deriv, color=color_, linewidth=2,
                 label=f"{col} Derivative")

        # for console
        from copy import copy
        d_expr_ = format_poly(d_coefs_)
        print(f"=== Derivative for {col} (Degree {best_poly_info[col]['degree']}) => {best_poly_info[col]['degree']-1} ===")
        print(f"   d/dx of {col} = {d_expr_}\n")

    plt.title("Polynomial Derivative Curves (Test Window) for Actual vs. MoE")
    plt.xlabel("Date")
    plt.ylabel("d(Price)/d(Time)")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    # Return them so you can use them in the trading snippet
    return df_merge, best_poly_info

############################################
# 6) (Optional) "Super Advanced MoE vs. Models (With Actual...)"
############################################
def load_feb_actual_data(csv_file="Silver Futures Historical Data_Final Pure Predictions.csv"):
    df_feb = pd.read_csv(csv_file)
    df_feb["Date"] = pd.to_datetime(df_feb["Date"], errors="coerce")
    for col in ["Vol.", "Change %"]:
        if col in df_feb.columns:
            df_feb.drop(columns=[col], errors="ignore", inplace=True)
    if "Price" in df_feb.columns:
        df_feb["Price"] = df_feb["Price"].astype(str).str.replace(",", "", regex=True).astype(float)
    df_feb.sort_values("Date", inplace=True)
    df_feb.reset_index(drop=True, inplace=True)
    return df_feb

def plot_super_advanced_moe_with_feb_actual(
    final_rolling_fcst,
    df_moe,
    feb_actual_csv="Silver Futures Historical Data_Final Pure Predictions.csv",
    start_plot=pd.to_datetime("2025-01-02"),
    end_plot=pd.to_datetime("2025-01-31")
):
    df_feb_actual = load_feb_actual_data(feb_actual_csv)
    mask_feb = (df_feb_actual["Date"] >= start_plot) & (df_feb_actual["Date"] <= end_plot)
    df_feb_filtered = df_feb_actual.loc[mask_feb].copy()

    df_fc = final_rolling_fcst[
        (final_rolling_fcst["ForecastDate"] >= start_plot) & 
        (final_rolling_fcst["ForecastDate"] <= end_plot)
    ].copy()

    plt.figure(figsize=(12,6))
    color_map = {
        "LSTM": "red",
        "GRU": "blue",
        "RNN": "green",
        "CNN": "orange",
        "EnhancedLSTM": "magenta",
        "Transformer": "cyan",
        "N-BEATS": "brown",
        "N-HITS": "pink",
        "SVM": "olive",
        "GPR": "teal",
        "Boost": "purple"
    }

    if not df_feb_filtered.empty and "Price" in df_feb_filtered.columns:
        plt.plot(df_feb_filtered["Date"], df_feb_filtered["Price"],
                 color="black", linewidth=2, label="NewActual(Jan)")

    for m in df_fc["Model"].unique():
        df_m = df_fc[df_fc["Model"] == m].copy()
        df_m_agg = df_m.groupby("ForecastDate", as_index=False)["Pred_Price_unscaled"].mean()
        c = color_map.get(m, "gray")
        plt.plot(df_m_agg["ForecastDate"], df_m_agg["Pred_Price_unscaled"],
                 color=c, alpha=0.6, label=m)

    df_moe_sub = df_moe[
        (df_moe["ForecastDate"] >= start_plot) &
        (df_moe["ForecastDate"] <= end_plot)
    ].copy()
    if not df_moe_sub.empty:
        plt.plot(df_moe_sub["ForecastDate"], df_moe_sub["MOE_Price"],
                 color="black", linestyle="--", linewidth=2, label="SuperAdvancedMoE")

    plt.title(f"Super Advanced MoE vs. Models (With Actual)\n[{start_plot.date()} ~ {end_plot.date()}]")
    plt.xlabel("Date")
    plt.ylabel("Price")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

############################################
# 7) NEW: Confidence-Based Trading on the MoE
############################################
def build_moe_poly_prices(df_merge, best_poly_info):
    """
    From df_merge containing ["Date","Actual","MoE","mdates_num"],
    compute the polynomial-based predicted prices for MoE.
    """
    if "MoE" not in best_poly_info:
        raise ValueError("best_poly_info must include polynomial info for 'MoE'.")

    moepoly_coefs = best_poly_info["MoE"]["coeffs"]
    moepoly_prices = np.polyval(moepoly_coefs, df_merge["mdates_num"].values)
    return moepoly_prices

def run_confidence_based_trading_moe(df_merge, moepoly_prices):
    """
    Single-model daily confidence tracking (MoE):
      - Fit confidence => day-to-day price change match
      - Gradient confidence => sign match
      - Static confidence => base
    """
    df_strat = df_merge.copy()
    n_days   = len(df_strat)

    w_static = 0.1
    w_fit    = 0.3
    w_grad   = 0.6

    static_conf_base= 0.2
    dyn_static_conf = static_conf_base
    dyn_fit_conf    = 0.5
    dyn_grad_conf   = 0.5

    alpha_fit_up      = 0.2
    alpha_fit_down    = 0.2
    alpha_grad_up     = 0.3
    alpha_grad_down   = 0.5
    alpha_static_up   = 0.1
    alpha_static_down = 0.1

    fit_threshold    = 1.0
    static_threshold = 1.0

    consecutive_wrong= 0
    MAX_CONSEC_WRONG = 2
    signal_threshold = 0.7

    signals = np.zeros(n_days, dtype=int)
    final_conf = np.zeros(n_days, dtype=float)

    for i in range(n_days):
        if i==0:
            # No prior day => no update
            signals[i] = 0
            final_conf[i] = (w_static*dyn_static_conf + w_fit*dyn_fit_conf + w_grad*dyn_grad_conf)
            continue

        # (1) Fit confidence => day-to-day price-change
        moe_change    = moepoly_prices[i]   - moepoly_prices[i-1]
        actual_change = df_strat["Actual"].iloc[i] - df_strat["Actual"].iloc[i-1]
        err = abs(moe_change - actual_change)
        if err< fit_threshold:
            dyn_fit_conf += alpha_fit_up
        else:
            dyn_fit_conf -= alpha_fit_down
        dyn_fit_conf= max(0, min(1, dyn_fit_conf))

        # (2) Gradient => sign match
        moe_sign    = np.sign(moe_change)
        actual_sign = np.sign(actual_change)
        if moe_sign== actual_sign:
            dyn_grad_conf += alpha_grad_up
        else:
            dyn_grad_conf -= alpha_grad_down
        dyn_grad_conf= max(0, min(1, dyn_grad_conf))

        # (3) Static => direct price error
        price_err = abs(moepoly_prices[i] - df_strat["Actual"].iloc[i])
        if price_err< static_threshold:
            dyn_static_conf += alpha_static_up
        else:
            dyn_static_conf -= alpha_static_down
        dyn_static_conf= max(0, min(1, dyn_static_conf))

        # Composite conf
        comp_conf = (w_static*dyn_static_conf + w_fit*dyn_fit_conf + w_grad*dyn_grad_conf)
        final_conf[i]= comp_conf

        # Weighted "vote"
        if moepoly_prices[i]> moepoly_prices[i-1]:
            vote_sign= +1
        elif moepoly_prices[i]< moepoly_prices[i-1]:
            vote_sign= -1
        else:
            vote_sign= 0

        vote_sum = comp_conf* vote_sign
        if vote_sum>= signal_threshold:
            signals[i]= +1
        elif vote_sum<= -signal_threshold:
            signals[i]= -1
        else:
            signals[i]= 0

        # Consecutive-wrong override
        if i>1:
            prior_signal= signals[i-1]
            actual_dir  = np.sign(df_strat["Actual"].iloc[i-1] - df_strat["Actual"].iloc[i-2])
            if (prior_signal>0 and actual_dir<=0) or (prior_signal<0 and actual_dir>=0):
                consecutive_wrong +=1
            else:
                consecutive_wrong=0

            if consecutive_wrong> MAX_CONSEC_WRONG:
                signals[i]= -signals[i]
                consecutive_wrong=0

    df_strat["Signal"]= signals
    return df_strat, final_conf

def piecewise_trading_simulation_offset(df_sim, initial_cap=100.0):
    """
    Offset-based approach:
      - Group contiguous days with the same signal
      - Realize PnL end of each multi-day segment, ignoring single-day signals
    """
    def get_segments(dframe, col="Signal"):
        segs=[]
        starti=0
        cursig= dframe.loc[0,col]
        for idx in range(1,len(dframe)):
            if dframe.loc[idx,col] != cursig:
                segs.append((starti, idx-1, cursig))
                starti= idx
                cursig= dframe.loc[idx,col]
        segs.append((starti, len(dframe)-1, cursig))
        return segs

    segments= get_segments(df_sim, "Signal")
    capital = initial_cap
    cap_arr = np.zeros(len(df_sim))
    trade_log=[]

    for (start,end,sig) in segments:
        seg_days= end-start+1
        for i in range(start,end+1):
            cap_arr[i]= capital

        start_date= df_sim["Date"].iloc[start]
        end_date  = df_sim["Date"].iloc[end]
        if seg_days<2:
            # ignore single-day
            trade_log.append({
                "Signal":"Flat(1-day)",
                "StartDate":start_date,
                "EndDate":end_date,
                "Days":seg_days,
                "EntryPrice":df_sim["Actual"].iloc[start],
                "ExitPrice":df_sim["Actual"].iloc[end],
                "AbsDiff":0.0,
                "SegmentReturn(%)":0.0,
                "EndCapital": capital
            })
            continue

        entry_price= df_sim["Actual"].iloc[start]
        exit_price = df_sim["Actual"].iloc[end]

        if sig==0:
            trade_log.append({
                "Signal":"Flat",
                "StartDate":start_date,
                "EndDate":end_date,
                "Days":seg_days,
                "EntryPrice":entry_price,
                "ExitPrice":exit_price,
                "AbsDiff":abs(exit_price-entry_price),
                "SegmentReturn(%)":0.0,
                "EndCapital":capital
            })
        elif sig==1:
            final_cap= capital*(exit_price/entry_price)
            seg_ret = (final_cap/capital)-1.0
            cap_arr[end]= final_cap
            capital= final_cap
            trade_log.append({
                "Signal":"Long",
                "StartDate":start_date,
                "EndDate":end_date,
                "Days":seg_days,
                "EntryPrice":entry_price,
                "ExitPrice":exit_price,
                "AbsDiff":abs(exit_price-entry_price),
                "SegmentReturn(%)":seg_ret*100.0,
                "EndCapital":final_cap
            })
        else:
            final_cap= capital*(entry_price/exit_price)
            seg_ret= (final_cap/capital)-1.0
            cap_arr[end]= final_cap
            capital= final_cap
            trade_log.append({
                "Signal":"Short",
                "StartDate":start_date,
                "EndDate":end_date,
                "Days":seg_days,
                "EntryPrice":entry_price,
                "ExitPrice":exit_price,
                "AbsDiff":abs(exit_price-entry_price),
                "SegmentReturn(%)":seg_ret*100.0,
                "EndCapital":final_cap
            })

    last_cap= capital
    for i in range(len(df_sim)):
        if cap_arr[i]==0.0:
            cap_arr[i]= last_cap
        else:
            last_cap= cap_arr[i]

    df_sim["Capital"]          = cap_arr
    df_sim["Cumulative_PnL"]   = df_sim["Capital"] - initial_cap
    df_sim["Cumulative_Return"]= (df_sim["Cumulative_PnL"]/initial_cap)*100.0
    return df_sim, trade_log

def plot_moe_strategy_results(df_strat, trade_log, final_conf):
    """
    Stepwise PnL chart for the MoE-based strategy, plus confidence plot.
    """
    print("\n===== Mixture-of-Experts (MoE) Trade Log =====")
    for tr in trade_log:
        print(
            f"{tr['Signal']:6s} | {tr['StartDate'].date()} -> {tr['EndDate'].date()} "
            f"({tr['Days']} days) | Entry={tr['EntryPrice']:.2f}, Exit={tr['ExitPrice']:.2f}, "
            f"AbsDiff={tr['AbsDiff']:.2f}, Return={tr['SegmentReturn(%)']:.2f}% => Cap={tr['EndCapital']:.2f}"
        )

    fc = df_strat["Capital"].iloc[-1]
    fp = df_strat["Cumulative_PnL"].iloc[-1]
    fr = df_strat["Cumulative_Return"].iloc[-1]
    print("\n=== Final Results (MoE Single-Model Strategy) ===")
    print(f"Final Capital = {fc:.2f}")
    print(f"Final PnL     = {fp:.2f}")
    print(f"Final Return  = {fr:.2f}%")

    fig, ax1 = plt.subplots(figsize=(14,6))
    color_map = {0:"black", 1:"red", -1:"blue"}

    for i in range(1,len(df_strat)):
        sig_prev = df_strat["Signal"].iloc[i-1]
        x_h = [df_strat["Date"].iloc[i-1], df_strat["Date"].iloc[i]]
        y_h = [df_strat["Capital"].iloc[i-1], df_strat["Capital"].iloc[i-1]]
        ax1.plot(x_h, y_h, color=color_map[sig_prev], linewidth=2)

        x_v = [df_strat["Date"].iloc[i], df_strat["Date"].iloc[i]]
        y_v = [df_strat["Capital"].iloc[i-1], df_strat["Capital"].iloc[i]]
        ax1.plot(x_v, y_v, color=color_map[sig_prev], linewidth=2)

    ax1.set_xlabel("Date")
    ax1.set_ylabel("Capital", color="blue")
    ax1.tick_params(axis="y", labelcolor="blue")
    ax1.grid(True)

    ax2 = ax1.twinx()
    ax2.plot(df_strat["Date"], df_strat["Actual"], color="gray", linestyle="--", linewidth=2)
    ax2.set_ylabel("Actual Price", color="gray")
    ax2.tick_params(axis="y", labelcolor="gray")

    legend_elems = [
        Line2D([0],[0], color='black', lw=2, label='Flat'),
        Line2D([0],[0], color='red', lw=2,   label='Long'),
        Line2D([0],[0], color='blue', lw=2,  label='Short'),
    ]
    ax1.legend(handles=legend_elems, loc="upper left")
    ax1.set_title("MoE Single-Model Strategy: Stepwise PnL")
    plt.tight_layout()
    plt.show()

    # Confidence plot
    fig, ax = plt.subplots(figsize=(12,4))
    ax.plot(df_strat["Date"], final_conf, marker="o", linestyle="-", color="green")
    ax.set_title("Daily Composite Confidence (MoE Model)")
    ax.set_xlabel("Date")
    ax.set_ylabel("Confidence")
    ax.grid(True)
    plt.tight_layout()
    plt.show()

############################################
# 8) MAIN USAGE EXAMPLE
############################################
if __name__=="__main__":
    # -------------------------------------------------------------------------
    # 1) Load & scale => get df_complete_all
    # -------------------------------------------------------------------------
    df_scaled, df_complete_all, scaler= load_and_scale_data(
        "Silver Futures Historical Data.csv",
        "Silver Futures Historical Data_Complete.csv"
    )

    # -------------------------------------------------------------------------
    # 2) Rolling forecasts => final_rolling_fc with 9 models
    # -------------------------------------------------------------------------
    final_rolling_fc= rolling_train_validate_predict_moe(
        df_full= df_complete_all,
        scaler_obj= scaler,
        model_types=["LSTM","GRU","RNN","CNN","Transformer","N-BEATS","N-HITS","SVM","Boost"],
        start_train_cutoff=pd.to_datetime("2024-07-01"),
        start_val_cutoff=pd.to_datetime("2024-11-30"),
        start_pred=pd.to_datetime("2024-12-01"),
        end_pred=pd.to_datetime("2025-01-02"),
        horizon_days=30,
        do_daily_plots=False
    )
    print("\n=== HEAD of final_rolling_fc ===")
    print(final_rolling_fc.head())

    # -------------------------------------------------------------------------
    # 3) Build "super advanced" mixture-of-experts
    # -------------------------------------------------------------------------
    df_moe= compute_super_advanced_moe(final_rolling_fc, df_complete_all)
    print("\n=== HEAD of df_moe ===")
    print(df_moe.head())

    # Plot => from 2025-01-02..2025-01-31 => models vs MoE
    plot_super_advanced_moe_vs_models(
        final_rolling_fc,
        df_moe,
        from_d=pd.to_datetime("2025-01-02"),
        to_d=pd.to_datetime("2025-01-31")
    )

    # Overlay newly revealed actual data:
    plot_super_advanced_moe_with_feb_actual(
        final_rolling_fcst=final_rolling_fc,
        df_moe=df_moe,
        feb_actual_csv="Silver Futures Historical Data_Final Pure Predictions.csv",
        start_plot=pd.to_datetime("2025-01-02"),
        end_plot=pd.to_datetime("2025-01-31")
    )

    # -------------------------------------------------------------------------
    # 4) Fit polynomials (up to degree=70) for both Actual & MoE => get df_merge
    #    plus best_poly_info
    # -------------------------------------------------------------------------
    df_merge, best_poly_info = polynomial_fitting_actual_and_moe(
        df_moe,
        csv_actual="Silver Futures Historical Data_Final Pure Predictions.csv",
        max_degree=70
    )
    # if df_merge is empty => no overlapping dates => stop
    if df_merge.empty:
        print("Cannot proceed with MoE-based trading due to no overlapping dates.")
        exit(0)

    # -------------------------------------------------------------------------
    # 5) MoE Confidence-Based Trading
    # -------------------------------------------------------------------------
    moepoly_prices = build_moe_poly_prices(df_merge, best_poly_info)
    df_strat, final_conf = run_confidence_based_trading_moe(df_merge, moepoly_prices)
    df_sim, trade_log = piecewise_trading_simulation_offset(df_strat, initial_cap=100.0)
    plot_moe_strategy_results(df_sim, trade_log, final_conf)

    print("\nAll done with MoE + polynomial fittings + confidence-based trading for the MoE model!")
# Out:
# === Rolling Day 2024-12-01 ===
#   train_cutoff=2024-07-01  val_cutoff=2024-11-30
#   Forecast next 30 days from 2024-12-01 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-01_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-01_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-01_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-01_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-01_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-01_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-01_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-01_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-01_V1.pkl
#
# === Rolling Day 2024-12-02 ===
#   train_cutoff=2024-07-02  val_cutoff=2024-12-01
#   Forecast next 30 days from 2024-12-02 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-02_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-02_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-02_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-02_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-02_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-02_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-02_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-02_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-02_V1.pkl
#
# === Rolling Day 2024-12-03 ===
#   train_cutoff=2024-07-03  val_cutoff=2024-12-02
#   Forecast next 30 days from 2024-12-03 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-03_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-03_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-03_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-03_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-03_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-03_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-03_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-03_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-03_V1.pkl
#
# === Rolling Day 2024-12-04 ===
#   train_cutoff=2024-07-04  val_cutoff=2024-12-03
#   Forecast next 30 days from 2024-12-04 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-04_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-04_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-04_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-04_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-04_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-04_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-04_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-04_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-04_V1.pkl
#
# === Rolling Day 2024-12-05 ===
#   train_cutoff=2024-07-05  val_cutoff=2024-12-04
#   Forecast next 30 days from 2024-12-05 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-05_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-05_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-05_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-05_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-05_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-05_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-05_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-05_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-05_V1.pkl
#
# === Rolling Day 2024-12-06 ===
#   train_cutoff=2024-07-06  val_cutoff=2024-12-05
#   Forecast next 30 days from 2024-12-06 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-06_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-06_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-06_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-06_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-06_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-06_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-06_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-06_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-06_V1.pkl
#
# === Rolling Day 2024-12-07 ===
#   train_cutoff=2024-07-07  val_cutoff=2024-12-06
#   Forecast next 30 days from 2024-12-07 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-07_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-07_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-07_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-07_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-07_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-07_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-07_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-07_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-07_V1.pkl
#
# === Rolling Day 2024-12-08 ===
#   train_cutoff=2024-07-08  val_cutoff=2024-12-07
#   Forecast next 30 days from 2024-12-08 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-08_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-08_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-08_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-08_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-08_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-08_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-08_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-08_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-08_V1.pkl
#
# === Rolling Day 2024-12-09 ===
#   train_cutoff=2024-07-09  val_cutoff=2024-12-08
#   Forecast next 30 days from 2024-12-09 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-09_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-09_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-09_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-09_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-09_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-09_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-09_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-09_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-09_V1.pkl
#
# === Rolling Day 2024-12-10 ===
#   train_cutoff=2024-07-10  val_cutoff=2024-12-09
#   Forecast next 30 days from 2024-12-10 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-10_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-10_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-10_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-10_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-10_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-10_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-10_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-10_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-10_V1.pkl
#
# === Rolling Day 2024-12-11 ===
#   train_cutoff=2024-07-11  val_cutoff=2024-12-10
#   Forecast next 30 days from 2024-12-11 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-11_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-11_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-11_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-11_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-11_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-11_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-11_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-11_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-11_V1.pkl
#
# === Rolling Day 2024-12-12 ===
#   train_cutoff=2024-07-12  val_cutoff=2024-12-11
#   Forecast next 30 days from 2024-12-12 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-12_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-12_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-12_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-12_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-12_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-12_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-12_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-12_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-12_V1.pkl
#
# === Rolling Day 2024-12-13 ===
#   train_cutoff=2024-07-13  val_cutoff=2024-12-12
#   Forecast next 30 days from 2024-12-13 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-13_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-13_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-13_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-13_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-13_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-13_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-13_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-13_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-13_V1.pkl
#
# === Rolling Day 2024-12-14 ===
#   train_cutoff=2024-07-14  val_cutoff=2024-12-13
#   Forecast next 30 days from 2024-12-14 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-14_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-14_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-14_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-14_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-14_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-14_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-14_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-14_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-14_V1.pkl
#
# === Rolling Day 2024-12-15 ===
#   train_cutoff=2024-07-15  val_cutoff=2024-12-14
#   Forecast next 30 days from 2024-12-15 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-15_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-15_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-15_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-15_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-15_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-15_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-15_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-15_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-15_V1.pkl
#
# === Rolling Day 2024-12-16 ===
#   train_cutoff=2024-07-16  val_cutoff=2024-12-15
#   Forecast next 30 days from 2024-12-16 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-16_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-16_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-16_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-16_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-16_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-16_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-16_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-16_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-16_V1.pkl
#
# === Rolling Day 2024-12-17 ===
#   train_cutoff=2024-07-17  val_cutoff=2024-12-16
#   Forecast next 30 days from 2024-12-17 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-17_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-17_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-17_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-17_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-17_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-17_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-17_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-17_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-17_V1.pkl
#
# === Rolling Day 2024-12-18 ===
#   train_cutoff=2024-07-18  val_cutoff=2024-12-17
#   Forecast next 30 days from 2024-12-18 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-18_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-18_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-18_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-18_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-18_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-18_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-18_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-18_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-18_V1.pkl
#
# === Rolling Day 2024-12-19 ===
#   train_cutoff=2024-07-19  val_cutoff=2024-12-18
#   Forecast next 30 days from 2024-12-19 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-19_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-19_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-19_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-19_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-19_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-19_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-19_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-19_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-19_V1.pkl
#
# === Rolling Day 2024-12-20 ===
#   train_cutoff=2024-07-20  val_cutoff=2024-12-19
#   Forecast next 30 days from 2024-12-20 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-20_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-20_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-20_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-20_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-20_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-20_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-20_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-20_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-20_V1.pkl
#
# === Rolling Day 2024-12-21 ===
#   train_cutoff=2024-07-21  val_cutoff=2024-12-20
#   Forecast next 30 days from 2024-12-21 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-21_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-21_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-21_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-21_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-21_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-21_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-21_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-21_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-21_V1.pkl
#
# === Rolling Day 2024-12-22 ===
#   train_cutoff=2024-07-22  val_cutoff=2024-12-21
#   Forecast next 30 days from 2024-12-22 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-22_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-22_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-22_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-22_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-22_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-22_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-22_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-22_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-22_V1.pkl
#
# === Rolling Day 2024-12-23 ===
#   train_cutoff=2024-07-23  val_cutoff=2024-12-22
#   Forecast next 30 days from 2024-12-23 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-23_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-23_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-23_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-23_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-23_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-23_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-23_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-23_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-23_V1.pkl
#
# === Rolling Day 2024-12-24 ===
#   train_cutoff=2024-07-24  val_cutoff=2024-12-23
#   Forecast next 30 days from 2024-12-24 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-24_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-24_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-24_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-24_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-24_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-24_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-24_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-24_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-24_V1.pkl
#
# === Rolling Day 2024-12-25 ===
#   train_cutoff=2024-07-25  val_cutoff=2024-12-24
#   Forecast next 30 days from 2024-12-25 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-25_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-25_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-25_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-25_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-25_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-25_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-25_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-25_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-25_V1.pkl
#
# === Rolling Day 2024-12-26 ===
#   train_cutoff=2024-07-26  val_cutoff=2024-12-25
#   Forecast next 30 days from 2024-12-26 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-26_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-26_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-26_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-26_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-26_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-26_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-26_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-26_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-26_V1.pkl
#
# === Rolling Day 2024-12-27 ===
#   train_cutoff=2024-07-27  val_cutoff=2024-12-26
#   Forecast next 30 days from 2024-12-27 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-27_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-27_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-27_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-27_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-27_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-27_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-27_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-27_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-27_V1.pkl
#
# === Rolling Day 2024-12-28 ===
#   train_cutoff=2024-07-28  val_cutoff=2024-12-27
#   Forecast next 30 days from 2024-12-28 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-28_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-28_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-28_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-28_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-28_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-28_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-28_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-28_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-28_V1.pkl
#
# === Rolling Day 2024-12-29 ===
#   train_cutoff=2024-07-29  val_cutoff=2024-12-28
#   Forecast next 30 days from 2024-12-29 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-29_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-29_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-29_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-29_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-29_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-29_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-29_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-29_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-29_V1.pkl
#
# === Rolling Day 2024-12-30 ===
#   train_cutoff=2024-07-30  val_cutoff=2024-12-29
#   Forecast next 30 days from 2024-12-30 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-30_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-30_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-30_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-30_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-30_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-30_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-30_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-30_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-30_V1.pkl
#
# === Rolling Day 2024-12-31 ===
#   train_cutoff=2024-07-31  val_cutoff=2024-12-30
#   Forecast next 30 days from 2024-12-31 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2024-12-31_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2024-12-31_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2024-12-31_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2024-12-31_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2024-12-31_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2024-12-31_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2024-12-31_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-31_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-31_V1.pkl
#
# === Rolling Day 2025-01-01 ===
#   train_cutoff=2024-08-01  val_cutoff=2024-12-31
#   Forecast next 30 days from 2025-01-01 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2025-01-01_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2025-01-01_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2025-01-01_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2025-01-01_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2025-01-01_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2025-01-01_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2025-01-01_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2025-01-01_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2025-01-01_V1.pkl
#
# === Rolling Day 2025-01-02 ===
#   train_cutoff=2024-08-02  val_cutoff=2025-01-01
#   Forecast next 30 days from 2025-01-02 w/ noise => more volatility
# [PyTorch] Loading LSTM from ./best_LSTM_2025-01-02_V1.pt
# [PyTorch] Loading GRU from ./best_GRU_2025-01-02_V1.pt
# [PyTorch] Loading RNN from ./best_RNN_2025-01-02_V1.pt
# [PyTorch] Loading CNN from ./best_CNN_2025-01-02_V1.pt
# [PyTorch] Loading Transformer from ./best_Transformer_2025-01-02_V1.pt
# [PyTorch] Loading N-BEATS from ./best_N-BEATS_2025-01-02_V1.pt
# [PyTorch] Loading N-HITS from ./best_N-HITS_2025-01-02_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2025-01-02_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2025-01-02_V1.pkl
#
# === HEAD of final_rolling_fc ===
#     ForecastDate  Pred_Price_unscaled  Pred_Open_unscaled  Pred_High_unscaled  \
# 240   2024-12-01            31.141379           30.405074           30.493824
# 241   2024-12-02            31.045956           29.658617           30.215023
# 242   2024-12-03            31.662073           29.312402           29.424846
# 243   2024-12-04            31.191013           29.191437           29.585954
# 244   2024-12-05            31.106886           29.205841           29.379925
#
#      Pred_Low_unscaled   BaseDate  Model
# 240          29.461850 2024-12-01  Boost
# 241          28.929095 2024-12-01  Boost
# 242          28.329650 2024-12-01  Boost
# 243          28.336038 2024-12-01  Boost
# 244          28.262161 2024-12-01  Boost
#
# === SUPER ADVANCED MOE w/ Polynomials & Voting ===
#
#
# === HEAD of df_moe ===
#   ForecastDate  MOE_Price
# 0   2025-01-02  31.136401
# 1   2025-01-03  30.970069
# 2   2025-01-04  31.026172
# 3   2025-01-05  30.793378
# 4   2025-01-06  30.632033
# === Best Polynomial Fitting Results ===
# [Actual] => Degree=5, Val MSE=0.250633
#      y = 1.1582e-09*x^5-6.9896e-05*x^4+9.4023e-01*x^3+1.8688e+04*x^2-5.6564e+08*x+3.7931e+12
#
# [MoE] => Degree=5, Val MSE=0.019848
#      y = -5.8177e-10*x^5+3.5113e-05*x^4-4.7237e-01*x^3-9.3882e+03*x^2+2.8418e+08*x-1.9057e+12
#
# === Derivative for Actual (Degree 5) => 4 ===
#    d/dx of Actual = 5.7908e-09*x^4-2.7959e-04*x^3+2.8207e+00*x^2+3.7377e+04*x-5.6564e+08
#
# === Derivative for MoE (Degree 5) => 4 ===
#    d/dx of MoE = -2.9088e-09*x^4+1.4045e-04*x^3-1.4171e+00*x^2-1.8776e+04*x+2.8418e+08
# ===== Mixture-of-Experts (MoE) Trade Log =====
# Flat   | 2025-01-02 -> 2025-01-17 (12 days) | Entry=29.90, Exit=31.14, AbsDiff=1.24, Return=0.00% => Cap=100.00
# Flat(1-day) | 2025-01-21 -> 2025-01-21 (1 days) | Entry=31.50, Exit=31.50, AbsDiff=0.00, Return=0.00% => Cap=100.00
# Flat   | 2025-01-22 -> 2025-01-24 (3 days) | Entry=31.42, Exit=31.05, AbsDiff=0.37, Return=0.00% => Cap=100.00
# Flat(1-day) | 2025-01-27 -> 2025-01-27 (1 days) | Entry=30.28, Exit=30.28, AbsDiff=0.00, Return=0.00% => Cap=100.00
# Flat   | 2025-01-28 -> 2025-01-31 (4 days) | Entry=30.75, Exit=32.27, AbsDiff=1.51, Return=0.00% => Cap=100.00
#
# === Final Results (MoE Single-Model Strategy) ===
# Final Capital = 100.00
# Final PnL     = 0.00
# Final Return  = 0.00%
# All done with MoE + polynomial fittings + confidence-based trading for the MoE model!

# %%
###############################################################################
# SUPPRESS WARNINGS & IMPORTS
###############################################################################
import warnings
warnings.filterwarnings("ignore", category=Warning)  # ignore all warnings
import numpy as np
np.seterr(all="ignore")  # ignore NumPy runtime warnings (overflow, etc.)
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

###############################################################################
# A) Assumptions: 
#    1) df_moe_poly is already defined in your notebook environment, 
#       containing at least ["Date","MoE","Actual","mdates_num"].
#    2) best_poly_info["MoE"]["coeffs"] is set to your best polynomial for MoE.
#    3) If your df_moe_poly does NOT have "Actual", 
#       read from "Silver Futures Historical Data_Final Pure Predictions.csv" 
#       and merge accordingly (comment out if not needed).
###############################################################################

# Example (comment out if df_moe_poly already has "Actual"):
# df_actual_conf = pd.read_csv("Silver Futures Historical Data_Final Pure Predictions.csv")
# df_actual_conf["Date"] = pd.to_datetime(df_actual_conf["Date"], errors="coerce")
# df_actual_conf["Price"] = (
#     df_actual_conf["Price"]
#     .astype(str)
#     .str.replace(",","", regex=True)
#     .astype(float)
# )
# df_actual_conf.sort_values("Date", inplace=True)
# df_actual_conf.reset_index(drop=True, inplace=True)

# # Merge => columns [Date, MoE, Price => rename Actual, ...]
# df_moe_poly = pd.merge(
#     df_moe_poly[["Date","MoE","mdates_num"]],
#     df_actual_conf[["Date","Price"]],
#     on="Date", how="inner"
# ).rename(columns={"Price":"Actual"})

df_moe_poly = df_moe_poly.copy().reset_index(drop=True)  # ensure a fresh copy

###############################################################################
# B) Confidence-Based Strategy
###############################################################################
# We'll define a piecewise offset settlement, then daily dynamic 
# confidences: static, fit, grad. Weighted sum => final signal.

# 1) Grab MoE polynomial coefficients 
moe_coeffs = best_poly_info["MoE"]["coeffs"]

# 2) Evaluate the polynomial to get MoE "fit" price for each day
df_moe_poly["MoE_fit"] = np.polyval(moe_coeffs, df_moe_poly["mdates_num"])

# 3) We'll compute daily changes for MoE_fit & Actual
n_days = len(df_moe_poly)
moe_price_change = np.zeros(n_days)
actual_price_change = np.zeros(n_days)
for i in range(1, n_days):
    moe_price_change[i] = df_moe_poly.loc[i,"MoE_fit"] - df_moe_poly.loc[i-1,"MoE_fit"]
    actual_price_change[i] = df_moe_poly.loc[i,"Actual"] - df_moe_poly.loc[i-1,"Actual"]

# 4) Initialize dynamic confidences
dyn_static_conf = 0.5
dyn_fit_conf    = 0.5
dyn_grad_conf   = 0.5

# Weighted composition
w_static = 0.1
w_fit    = 0.3
w_grad   = 0.6

# Confidence increments
alpha_static_up   = 0.1
alpha_static_down = 0.1
alpha_fit_up   = 0.2
alpha_fit_down = 0.2
alpha_grad_up   = 0.3
alpha_grad_down = 0.5

# Thresholds
static_threshold = 1.0
fit_threshold    = 1.0
vote_threshold   = 0.7

# For consecutive "all-wrong" override
MAX_CONSECUTIVE_ALL_WRONG = 2
consecutive_all_wrong = 0

signals = np.zeros(n_days, dtype=int)
conf_array = np.zeros(n_days)

for i in range(n_days):
    # Update dynamic confidences (skip day 0)
    if i > 0:
        # static confidence => abs error vs actual
        abs_err = abs(df_moe_poly.loc[i,"MoE_fit"] - df_moe_poly.loc[i,"Actual"])
        if abs_err < static_threshold:
            dyn_static_conf += alpha_static_up
        else:
            dyn_static_conf -= alpha_static_down
        dyn_static_conf = np.clip(dyn_static_conf, 0, 1)

        # fit confidence => difference in daily changes
        pdiff = moe_price_change[i]
        adiff = actual_price_change[i]
        if abs(pdiff - adiff) < fit_threshold:
            dyn_fit_conf += alpha_fit_up
        else:
            dyn_fit_conf -= alpha_fit_down
        dyn_fit_conf = np.clip(dyn_fit_conf, 0, 1)

        # grad confidence => sign match
        p_sign = np.sign(pdiff)
        a_sign = np.sign(adiff)
        if p_sign == a_sign:
            dyn_grad_conf += alpha_grad_up
        else:
            dyn_grad_conf -= alpha_grad_down
        dyn_grad_conf = np.clip(dyn_grad_conf, 0, 1)

    # Weighted sum => daily_conf
    daily_conf = w_static*dyn_static_conf + w_fit*dyn_fit_conf + w_grad*dyn_grad_conf
    daily_conf = min(daily_conf, 1.0)
    conf_array[i] = daily_conf

    # Weighted vote => daily_conf * sign(MoE)
    day_sign = np.sign(moe_price_change[i])

    # track correctness for consecutive override
    if i > 0:
        if day_sign == np.sign(actual_price_change[i]):
            consecutive_all_wrong = 0
        else:
            consecutive_all_wrong += 1
    else:
        consecutive_all_wrong = 0

    vote_val = daily_conf * day_sign
    if vote_val >= vote_threshold:
        signals[i] = 1
    elif vote_val <= -vote_threshold:
        signals[i] = -1
    else:
        signals[i] = 0

    if consecutive_all_wrong > MAX_CONSECUTIVE_ALL_WRONG:
        signals[i] = -signals[i]

df_moe_poly["Signal"] = signals
df_moe_poly["MoE_Confidence"] = conf_array


###############################################################################
# C) Piecewise Offset Trading
###############################################################################
def get_plot_segments(df, signal_col="Signal"):
    segs = []
    start_idx = 0
    curr_signal = df.loc[0, signal_col]
    for idx in range(1, len(df)):
        if df.loc[idx, signal_col] != curr_signal:
            segs.append((start_idx, idx - 1, curr_signal))
            start_idx = idx
            curr_signal = df.loc[idx, signal_col]
    segs.append((start_idx, len(df) - 1, curr_signal))
    return segs

def piecewise_trading_simulation_offset(df_signal):
    segments = get_plot_segments(df_signal, "Signal")
    capital = 100.0
    cap_arr = np.zeros(len(df_signal))
    trade_log = []
    
    for (start, end, sig) in segments:
        start_date = df_signal.loc[start, "Date"]
        end_date   = df_signal.loc[end,   "Date"]
        seg_days   = end - start + 1
        
        for i in range(start, end+1):
            cap_arr[i] = capital
        
        if seg_days < 2:
            trade_log.append({
                "Signal": "Flat(ignored)",
                "StartDate": start_date,
                "EndDate": end_date,
                "Days": seg_days,
                "EntryPrice": df_signal.loc[start,"Actual"],
                "ExitPrice": df_signal.loc[end,"Actual"],
                "AbsDiff": 0.0,
                "SegmentReturn(%)": 0.0,
                "EndCapital": capital
            })
            continue
        
        if sig == 0:
            trade_log.append({
                "Signal": "Flat",
                "StartDate": start_date,
                "EndDate": end_date,
                "Days": seg_days,
                "EntryPrice": df_signal.loc[start,"Actual"],
                "ExitPrice": df_signal.loc[end,"Actual"],
                "AbsDiff": abs(df_signal.loc[end,"Actual"] - df_signal.loc[start,"Actual"]),
                "SegmentReturn(%)": 0.0,
                "EndCapital": capital
            })
        elif sig == 1:
            entry = df_signal.loc[start,"Actual"]
            exit_ = df_signal.loc[end,"Actual"]
            final_cap = capital*(exit_/entry)
            seg_return = (final_cap/capital)-1.0
            cap_arr[end] = final_cap
            capital = final_cap
            trade_log.append({
                "Signal": "Long",
                "StartDate": start_date,
                "EndDate": end_date,
                "Days": seg_days,
                "EntryPrice": entry,
                "ExitPrice": exit_,
                "AbsDiff": abs(exit_-entry),
                "SegmentReturn(%)": seg_return*100.0,
                "EndCapital": final_cap
            })
        else:
            entry = df_signal.loc[start,"Actual"]
            exit_ = df_signal.loc[end,"Actual"]
            final_cap = capital*(entry/exit_)
            seg_return = (final_cap/capital)-1.0
            cap_arr[end] = final_cap
            capital = final_cap
            trade_log.append({
                "Signal": "Short",
                "StartDate": start_date,
                "EndDate": end_date,
                "Days": seg_days,
                "EntryPrice": entry,
                "ExitPrice": exit_,
                "AbsDiff": abs(exit_-entry),
                "SegmentReturn(%)": seg_return*100.0,
                "EndCapital": final_cap
            })
    
    # forward-fill capital after last segment
    last_cap = capital
    for i in range(len(df_signal)):
        if cap_arr[i] == 0.0:
            cap_arr[i] = last_cap
        else:
            last_cap = cap_arr[i]
    
    df_signal["Capital"] = cap_arr
    df_signal["Cumulative_PnL"] = df_signal["Capital"] - 100.0
    df_signal["Cumulative_Return"] = (df_signal["Cumulative_PnL"]/100.0)*100.0
    return df_signal, trade_log

df_moe_poly_sim, trade_log_moe = piecewise_trading_simulation_offset(df_moe_poly)

###############################################################################
# D) Reindex to Daily & Plot Stepwise Capital/Return
###############################################################################
def reindex_to_calendar(df_in):
    df_out = df_in.copy()
    df_out.set_index("Date", inplace=True)
    all_days = pd.date_range(df_out.index.min(), df_out.index.max(), freq="D")
    df_out = df_out.reindex(all_days)
    # forward-fill relevant columns
    for col in ["Actual","Capital","Cumulative_PnL","Cumulative_Return","Signal","MoE_Confidence"]:
        df_out[col].ffill(inplace=True)
    df_out.reset_index(inplace=True)
    df_out.rename(columns={"index":"Date"}, inplace=True)
    return df_out

df_moe_poly_daily = reindex_to_calendar(df_moe_poly_sim)

def plot_stepwise_capital(df_signal, trade_log, title_prefix="MoE Confidence"):
    print(f"===== {title_prefix} Trade Log =====")
    for t in trade_log:
        print(
            f"{t['Signal']:5s} | {t['StartDate'].date()} -> {t['EndDate'].date()} "
            f"({t['Days']} days) | "
            f"Entry={t['EntryPrice']:.2f}, Exit={t['ExitPrice']:.2f} "
            f"(AbsDiff={t['AbsDiff']:.2f}) | Return: {t['SegmentReturn(%)']:.2f}% | "
            f"EndCapital={t['EndCapital']:.2f}"
        )
    final_cap = df_signal["Capital"].iloc[-1]
    final_ret = df_signal["Cumulative_Return"].iloc[-1]
    print(f"\n[RESULT] Final Capital={final_cap:.2f}, Final Return={final_ret:.2f}%\n")
    
    fig, ax1 = plt.subplots(figsize=(12,5))
    color_map = {0:"black",1:"red",-1:"blue"}
    n_rows = len(df_signal)
    for i in range(1,n_rows):
        sig_prev = int(df_signal.loc[i-1,"Signal"])
        x_h = [df_signal.loc[i-1,"Date"], df_signal.loc[i,"Date"]]
        y_h = [df_signal.loc[i-1,"Capital"], df_signal.loc[i-1,"Capital"]]
        ax1.plot(x_h,y_h, color=color_map[sig_prev], linewidth=2)

        x_v = [df_signal.loc[i,"Date"], df_signal.loc[i,"Date"]]
        y_v = [df_signal.loc[i-1,"Capital"], df_signal.loc[i,"Capital"]]
        ax1.plot(x_v,y_v, color=color_map[sig_prev], linewidth=2)

    ax1.set_title(f"{title_prefix} - Stepwise Capital (Offset Settlement)")
    ax1.set_xlabel("Date")
    ax1.set_ylabel("Capital")
    ax1.grid(True)

    ax2 = ax1.twinx()
    ax2.plot(df_signal["Date"], df_signal["Actual"], color="gray", linestyle="--", linewidth=2)
    ax2.set_ylabel("Actual Price", color="gray")
    ax2.tick_params(axis='y', labelcolor="gray")

    legend_elems = [
        Line2D([0],[0], color='black', lw=2, label='Flat'),
        Line2D([0],[0], color='red',   lw=2, label='Long'),
        Line2D([0],[0], color='blue',  lw=2, label='Short')
    ]
    ax1.legend(handles=legend_elems, loc="upper left")
    plt.tight_layout()
    plt.show()

def plot_stepwise_return(df_signal, title_prefix="MoE Confidence"):
    fig, ax1 = plt.subplots(figsize=(12,5))
    color_map = {0:"black",1:"red",-1:"blue"}
    n_rows = len(df_signal)
    for i in range(1,n_rows):
        sig_prev = int(df_signal.loc[i-1,"Signal"])
        # horizontal step
        x_h = [df_signal.loc[i-1,"Date"], df_signal.loc[i,"Date"]]
        y_h = [df_signal.loc[i-1,"Cumulative_Return"], df_signal.loc[i-1,"Cumulative_Return"]]
        ax1.plot(x_h, y_h, color=color_map[sig_prev], linewidth=2)
        # vertical step
        x_v = [df_signal.loc[i,"Date"], df_signal.loc[i,"Date"]]
        y_v = [df_signal.loc[i-1,"Cumulative_Return"], df_signal.loc[i,"Cumulative_Return"]]
        ax1.plot(x_v, y_v, color=color_map[sig_prev], linewidth=2)

    ax1.set_title(f"{title_prefix} - Stepwise Cumulative Return (%)")
    ax1.set_xlabel("Date")
    ax1.set_ylabel("Cumulative Return (%)")
    ax1.grid(True)

    ax2 = ax1.twinx()
    ax2.plot(df_signal["Date"], df_signal["Actual"], color="gray", linestyle="--", linewidth=2)
    ax2.set_ylabel("Actual Price", color="gray")
    ax2.tick_params(axis='y', labelcolor="gray")

    plt.tight_layout()
    plt.show()

###############################################################################
# E) Final Plots
###############################################################################
plot_stepwise_capital(df_moe_poly_daily, trade_log_moe, title_prefix="MoE Confidence Trading")
plot_stepwise_return(df_moe_poly_daily, title_prefix="MoE Confidence Trading")

# Also plot daily confidence
plt.figure(figsize=(10,4))
plt.plot(df_moe_poly_daily["Date"], df_moe_poly_daily["MoE_Confidence"], color="green", linewidth=2)
plt.title("Daily Composite Confidence for MoE")
plt.xlabel("Date")
plt.ylabel("Confidence [0..1]")
plt.grid(True)
plt.tight_layout()
plt.show()

print("=== DONE: Confidence-based Trading for MoE + offset settlement (no warnings) ===")
# Out:
# ===== MoE Confidence Trading Trade Log =====
# Flat  | 2025-01-02 -> 2025-01-17 (12 days) | Entry=29.90, Exit=31.14 (AbsDiff=1.24) | Return: 0.00% | EndCapital=100.00
# Flat(ignored) | 2025-01-21 -> 2025-01-21 (1 days) | Entry=31.50, Exit=31.50 (AbsDiff=0.00) | Return: 0.00% | EndCapital=100.00
# Flat  | 2025-01-22 -> 2025-01-24 (3 days) | Entry=31.42, Exit=31.05 (AbsDiff=0.37) | Return: 0.00% | EndCapital=100.00
# Flat(ignored) | 2025-01-27 -> 2025-01-27 (1 days) | Entry=30.28, Exit=30.28 (AbsDiff=0.00) | Return: 0.00% | EndCapital=100.00
# Flat  | 2025-01-28 -> 2025-01-31 (4 days) | Entry=30.75, Exit=32.27 (AbsDiff=1.51) | Return: 0.00% | EndCapital=100.00
#
# [RESULT] Final Capital=100.00, Final Return=0.00%
# === DONE: Confidence-based Trading for MoE + offset settlement (no warnings) ===
