# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=pd.errors.PerformanceWarning)
pd.options.mode.chained_assignment = None

from sklearn.preprocessing import MinMaxScaler
import torch
import torch.nn as nn
import torch.nn.functional as F
import os
import random
import joblib
from sklearn.svm import SVR
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.multioutput import MultiOutputRegressor
from sklearn.ensemble import GradientBoostingRegressor

# For final zoom-in diagrams
import matplotlib.dates as mdates
from matplotlib.lines import Line2D

############################################
# 1. GLOBAL SETTINGS
############################################
torch.manual_seed(0)
np.random.seed(0)
random.seed(0)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(0)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

features = ["Price", "Open", "High", "Low"]
WINDOW_SIZE = 35
NUM_EPOCHS = 1500
BEST_MODELS_DIR = "."  # directory with .pt/.pkl model files

############################################
# 2. Basic Data Preprocessing
############################################
def load_and_scale_data(train_csv, complete_csv):
    df_trainval = pd.read_csv(train_csv)
    df_trainval["Date"] = pd.to_datetime(df_trainval["Date"], errors="coerce")
    for col in ["Vol.", "Change %"]:
        if col in df_trainval.columns:
            df_trainval.drop(columns=[col], errors="ignore", inplace=True)

    for c in features:
        if c not in df_trainval.columns:
            df_trainval[c] = np.nan
        else:
            df_trainval[c] = df_trainval[c].astype(str).str.replace(",", "", regex=True)
            df_trainval[c] = pd.to_numeric(df_trainval[c], errors="coerce")

    df_trainval.sort_values("Date", inplace=True)
    df_trainval.reset_index(drop=True, inplace=True)

    train_cutoff = pd.to_datetime("2024-07-01")
    val_cutoff   = pd.to_datetime("2024-11-30")
    test_cutoff  = pd.to_datetime("2024-12-01")

    df_train = df_trainval[df_trainval["Date"] < train_cutoff].copy()
    df_val   = df_trainval[(df_trainval["Date"] >= train_cutoff) & (df_trainval["Date"] <= val_cutoff)].copy()
    df_test  = df_trainval[df_trainval["Date"] >= test_cutoff].copy()

    df_train_nonan = df_train.dropna(subset=features)
    scaler = MinMaxScaler()
    scaler.fit(df_train_nonan[features])

    df_train_scaled = df_train.copy()
    if not df_train_nonan.empty:
        df_train_scaled.loc[df_train_nonan.index, features] = scaler.transform(df_train_nonan[features])

    df_val_scaled = df_val.copy()
    val_no_nan = df_val_scaled.dropna(subset=features)
    if not val_no_nan.empty:
        df_val_scaled.loc[val_no_nan.index, features] = scaler.transform(val_no_nan[features])

    df_test_scaled = df_test.copy()
    train_mins = df_train_nonan[features].min()
    df_test_filled = df_test_scaled[features].fillna(train_mins)
    df_test_scaled.loc[:, features] = scaler.transform(df_test_filled)

    df_scaled = pd.concat([df_train_scaled, df_val_scaled, df_test_scaled], ignore_index=True)

    # Load complete CSV for final rolling
    df_complete = pd.read_csv(complete_csv)
    df_complete["Date"] = pd.to_datetime(df_complete["Date"], errors="coerce")
    for c in ["Vol.", "Change %"]:
        if c in df_complete.columns:
            df_complete.drop(columns=[c], inplace=True)
    for f in features:
        df_complete[f] = df_complete[f].astype(str).str.replace(",", "", regex=True).astype(float)
    df_complete.sort_values("Date", inplace=True)
    df_complete.reset_index(drop=True, inplace=True)

    return df_scaled, df_complete, scaler

############################################
# 3. Utility: Sequence & Slices
############################################
def make_sequences(df_subset, window=35):
    arr = df_subset[features].values
    dts = df_subset["Date"].values
    X_list, y_list, date_list = [], [], []
    for i in range(window, len(arr)):
        X_window = arr[i - window : i]
        y_target = arr[i]
        X_list.append(X_window)
        y_list.append(y_target)
        date_list.append(dts[i])
    return np.array(X_list), np.array(y_list), np.array(date_list)

############################################
# 4. Model Definitions
############################################
class BaseModel(nn.Module):
    def __init__(self, model_type="LSTM", window_width=35):
        super().__init__()
        self.model_type = model_type

        if model_type == "CNN":
            self.conv1 = nn.Conv1d(4, 64, 3)
            self.conv2 = nn.Conv1d(64, 128, 3)
            with torch.no_grad():
                dummy = torch.zeros(1, 4, window_width)
                outdummy = self.conv2(F.relu(self.conv1(dummy)))
                conv_output_size = outdummy.shape[1]*outdummy.shape[2]
            self.fc = nn.Linear(conv_output_size, 4)

        elif model_type == "LSTM":
            self.rnn = nn.LSTM(4, 128, num_layers=2, batch_first=True, dropout=0.05)
            self.fc = nn.Linear(128, 4)

        elif model_type == "GRU":
            self.rnn = nn.GRU(4, 128, num_layers=2, batch_first=True, dropout=0.05)
            self.fc = nn.Linear(128, 4)

        elif model_type == "RNN":
            self.rnn = nn.RNN(4, 128, num_layers=2, nonlinearity="relu", batch_first=True, dropout=0.05)
            self.fc = nn.Linear(128, 4)

        elif model_type == "EnhancedLSTM":
            self.rnn = nn.LSTM(4, 128, num_layers=3, batch_first=True, dropout=0.1)
            self.bn  = nn.BatchNorm1d(128)
            self.dropout = nn.Dropout(0.1)
            self.fc = nn.Linear(128, 4)

        elif model_type == "Transformer":
            self.input_linear = nn.Linear(4, 128)
            encoder_layer = nn.TransformerEncoderLayer(d_model=128, nhead=8, dropout=0.05)
            self.transformer_encoder = nn.TransformerEncoder(encoder_layer, num_layers=3)
            self.fc = nn.Linear(128,4)

        elif model_type in ["N-BEATS","N-HITS"]:
            self.input_size= window_width*4
            self.blocks= nn.ModuleList([nn.Sequential(
                nn.Linear(self.input_size,128),
                nn.ReLU(),
                nn.Linear(128,128),
                nn.ReLU(),
                nn.Linear(128,4)
            ) for _ in range(3)])
        else:
            raise ValueError(f"Invalid model_type: {model_type}")

    def forward(self, x):
        if self.model_type == "CNN":
            x = x.permute(0,2,1)
            x = F.relu(self.conv1(x))
            x = F.relu(self.conv2(x))
            x = x.view(x.size(0), -1)
            return self.fc(x)

        elif self.model_type in ["LSTM","GRU","RNN"]:
            out, _ = self.rnn(x)
            out = out[:,-1,:]
            return self.fc(out)

        elif self.model_type == "EnhancedLSTM":
            out, _= self.rnn(x)
            out = out[:,-1,:]
            out = self.bn(out)
            out = self.dropout(out)
            return self.fc(out)

        elif self.model_type == "Transformer":
            x = self.input_linear(x)
            x = x.permute(1,0,2)
            x = self.transformer_encoder(x)
            x = x[-1,:,:]
            return self.fc(x)

        elif self.model_type in ["N-BEATS","N-HITS"]:
            xflat= x.reshape(x.size(0), -1)
            forecast=0
            for block in self.blocks:
                forecast += block(xflat)
            return forecast

        else:
            raise ValueError("Invalid model_type")

############################################
# 5. Model Loading (No training)
############################################
class SklearnWrapper:
    def __init__(self, model):
        self.model= model
    def forward(self, x):
        arr= x.cpu().numpy().reshape(1,-1)
        pred= self.model.predict(arr)
        return torch.from_numpy(pred).float().to(x.device)
    def eval(self):
        pass
    def __call__(self, x):
        return self.forward(x)

def load_torch_model(model_type, window_size, model_save_name):
    if not os.path.exists(model_save_name):
        raise FileNotFoundError(f"File not found: {model_save_name}")
    print(f"[PyTorch] Loading existing {model_type} from {model_save_name}")
    net = BaseModel(model_type, window_size).to(device)
    net.load_state_dict(torch.load(model_save_name, map_location=device))
    net.eval()
    return net

def load_sklearn_model(model_type, model_save_name):
    if not os.path.exists(model_save_name):
        raise FileNotFoundError(f"File not found: {model_save_name}")
    print(f"[sklearn] Loading {model_type} => {model_save_name}")
    loaded= joblib.load(model_save_name)
    return SklearnWrapper(loaded)

############################################
# 6. Forecasting utilities
############################################
def get_latest_window(df_actual, current_date, window=35, scaler=None):
    mask= df_actual["Date"]< current_date
    df_sub= df_actual.loc[mask].copy()
    df_sub.sort_values("Date", inplace=True)
    if len(df_sub)< window:
        return None
    df_sub[features]= df_sub[features].fillna(method="ffill").fillna(method="bfill")
    arr= scaler.transform(df_sub[features].iloc[-window:].values)
    return arr

def forecast_n_days_from_date(model, df_actual, start_date, window=35, horizon=30,
                              device=None, scaler=None, noise_std=0.05):
    """
    Full-blind forecast with random noise each day.
    """
    def add_noise_4d(pred_unscaled, std=0.005):
        noise= np.random.normal(0.0, std, size=pred_unscaled.shape)
        return np.clip(pred_unscaled+ noise, a_min=0, a_max=None)

    arr_window= get_latest_window(df_actual, start_date, window, scaler)
    if arr_window is None:
        return pd.DataFrame()

    rolling_buffer= np.copy(arr_window)
    forecast_records=[]
    current_date= pd.to_datetime(start_date)

    for i in range(horizon):
        X_input= torch.tensor(rolling_buffer,dtype=torch.float).unsqueeze(0).to(device)
        with torch.no_grad():
            pred_scaled= model(X_input).cpu().numpy()[0]
        pred_unscaled= scaler.inverse_transform(pred_scaled.reshape(1,-1))[0]
        pred_noisy= add_noise_4d(pred_unscaled, noise_std)

        dayx= current_date+ pd.Timedelta(days=i)
        forecast_records.append({
            "ForecastDate": dayx,
            "Pred_Price_unscaled": pred_noisy[0],
            "Pred_Open_unscaled":  pred_noisy[1],
            "Pred_High_unscaled":  pred_noisy[2],
            "Pred_Low_unscaled":   pred_noisy[3]
        })

        # shift rolling buffer
        pred_noisy_scaled= scaler.transform(pred_noisy.reshape(1,-1))[0]
        rolling_buffer= np.vstack([rolling_buffer[1:], pred_noisy_scaled.reshape(1,-1)])

    return pd.DataFrame(forecast_records)

############################################
# 7. Rolling approach (LOAD only)
############################################
def plot_daily_two_charts(day_i, horizon_days, daily_fcst_dict, df_actual):
    """
    Creates 2 plots for the given day_i:
      1) Joint Diagram up to day_i + horizon_days
      2) Zoomed diagram from day_i to day_i + horizon_days
    """
    df_sorted= df_actual.copy()
    df_sorted.sort_values("Date", inplace=True)
    day_end= day_i+ pd.Timedelta(days= horizon_days -1)

    mask= (df_sorted["Date"]<= day_end)
    df_plot= df_sorted.loc[mask].copy()

    # 1) Joint Diagram
    plt.figure(figsize=(12,5))
    plt.plot(df_plot["Date"], df_plot["Price"], color="black", label="Actual Price")

    color_map= {
        "LSTM": "red",
        "GRU": "blue",
        "RNN": "green",
        "CNN": "orange",
        "EnhancedLSTM": "magenta",
        "Transformer": "cyan",
        "N-BEATS": "brown",
        "N-HITS": "pink",
        "SVM": "olive",
        "GPR": "teal",
        "Boost": "purple"
    }
    for mname, fcdf in daily_fcst_dict.items():
        sub= fcdf[fcdf["ForecastDate"]<= day_end].copy()
        if not sub.empty:
            plt.plot(sub["ForecastDate"], sub["Pred_Price_unscaled"],
                     color=color_map.get(mname,"gray"), linestyle="--", label=f"{mname} Forecast")

    plt.title(f"Day {day_i.date()} - Joint Diagram (up to {day_end.date()}) of NVIDIA Stocks")
    plt.xlabel("Date")
    plt.ylabel("Price")
    plt.legend(prop={"size":7})
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    # 2) Zoom-In
    plt.figure(figsize=(12,5))
    maskz= (df_plot["Date"]>= day_i)&(df_plot["Date"]<= day_end)
    df_zoom= df_plot.loc[maskz].copy()
    if not df_zoom.empty:
        plt.plot(df_zoom["Date"], df_zoom["Price"], color="black", label="Actual Price")
    for mname, fcdf in daily_fcst_dict.items():
        sub= fcdf[(fcdf["ForecastDate"]>=day_i)&(fcdf["ForecastDate"]<=day_end)]
        if not sub.empty:
            plt.plot(sub["ForecastDate"], sub["Pred_Price_unscaled"],
                     color=color_map.get(mname,"gray"), linestyle="--", label=f"{mname} Forecast")

    plt.title(f"Day {day_i.date()} - Zoom-In Forecast ({day_i.date()} to {day_end.date()}) of US Bonds (10-Year T-Note Futures)")
    plt.xlabel("Date")
    plt.ylabel("Price")
    plt.legend(prop={"size":7})
    plt.grid(True)
    plt.tight_layout()
    plt.show()

def rolling_train_validate_predict_moe(
    df_full,
    scaler_obj,
    model_types,
    start_train_cutoff=pd.to_datetime("2024-07-01"),
    start_val_cutoff=pd.to_datetime("2024-11-30"),
    start_pred=pd.to_datetime("2024-12-01"),
    end_pred=pd.to_datetime("2025-01-02"),
    horizon_days=30,
    do_daily_plots=True
):
    """
    Loads each model from pre-saved files for each day in [start_pred..end_pred],
    and produces a forecast with optional daily plots *only* on the final rolling day.
    """
    df_sorted= df_full.copy()
    df_sorted.sort_values("Date", inplace=True)

    df_scaled_all= df_sorted.copy()
    df_scaled_all[features]= df_scaled_all[features].fillna(method="ffill").fillna(method="bfill")
    df_scaled_all[features]= scaler_obj.transform(df_scaled_all[features])

    date_range= pd.date_range(start_pred, end_pred, freq="D")
    all_records= []

    for i, day_i in enumerate(date_range):
        train_cutoff_i= start_train_cutoff + pd.Timedelta(days=i)
        val_cutoff_i  = start_val_cutoff   + pd.Timedelta(days=i)

        print(f"\n=== Rolling Day {day_i.date()} ===")
        print(f"  Loading models for cutoff {train_cutoff_i.date()} / {val_cutoff_i.date()}")
        print(f"  Forecast next {horizon_days} days from {day_i.date()} with noise")

        # 1) Load each model from file
        model_dict= {}
        for mt in model_types:
            out_file= f"best_{mt}_{day_i.strftime('%Y-%m-%d')}_V1"
            if mt in ["SVM","GPR","Boost"]:
                out_file += ".pkl"
                net= load_sklearn_model(mt, os.path.join(BEST_MODELS_DIR, out_file))
            else:
                out_file += ".pt"
                net= load_torch_model(mt, WINDOW_SIZE, os.path.join(BEST_MODELS_DIR, out_file))
            model_dict[mt]= net

        # 2) Forecast
        daily_fcst_dict= {}
        for mt, net in model_dict.items():
            df_fc= forecast_n_days_from_date(
                model= net,
                df_actual= df_sorted,  # unscaled
                start_date= day_i,
                window= WINDOW_SIZE,
                horizon= horizon_days,
                device= device,
                scaler= scaler_obj,
                noise_std=0.05
            )
            if not df_fc.empty:
                df_fc["BaseDate"]= day_i
                df_fc["Model"]= mt
                daily_fcst_dict[mt]= df_fc
                all_records.append(df_fc)
            else:
                daily_fcst_dict[mt]= pd.DataFrame()

        # see actual
        row_actual= df_sorted[df_sorted["Date"]== day_i]
        if not row_actual.empty:
            print(f"  Actual price: {row_actual['Price'].values[0]:.4f}")

        # 3) Only plot daily diagrams on the *final* rolling day
        if do_daily_plots and (day_i == date_range[-1]):
            plot_daily_two_charts(day_i, horizon_days, daily_fcst_dict, df_sorted)

    df_all = pd.concat(all_records, ignore_index=True) if all_records else pd.DataFrame()
    df_all.sort_values(["Model","BaseDate","ForecastDate"], inplace=True)
    return df_all

############################################
# 8. Final Rolling Forecast Plot
############################################
def plot_final_rolling_fc(final_rolling_fcst, df_actual, from_d, to_d):
    if final_rolling_fcst.empty:
        print("No final rolling forecast data. Exiting.")
        return

    df_act= df_actual.copy()
    df_act.sort_values("Date", inplace=True)
    mask= (df_act["Date"]>= from_d)&(df_act["Date"]<= to_d)
    df_a= df_act[mask].copy()

    plt.figure(figsize=(12,5))
    plt.plot(df_a["Date"], df_a["Price"], color="black", label="ActualPrice")

    color_map= {
        "LSTM": "red",
        "GRU": "blue",
        "RNN": "green",
        "CNN": "orange",
        "EnhancedLSTM": "magenta",
        "Transformer": "cyan",
        "N-BEATS": "brown",
        "N-HITS": "pink",
        "SVM": "olive",
        "GPR": "teal",
        "Boost": "purple"
    }
    for m in final_rolling_fcst["Model"].unique():
        df_m= final_rolling_fcst[final_rolling_fcst["Model"]== m].copy()
        df_m= df_m[(df_m["ForecastDate"]>=from_d)&(df_m["ForecastDate"]<= to_d)]
        if not df_m.empty:
            plt.plot(df_m["ForecastDate"], df_m["Pred_Price_unscaled"],
                     color=color_map.get(m,"gray"), linestyle="--", label=f"{m} Forecast")

    plt.title(f"Rolling Forecast from {from_d.date()} to {to_d.date()} of US Bonds (10-Year T-Note Futures) ")
    plt.xlabel("Date")
    plt.ylabel("Price")
    plt.legend(prop={"size":7})
    plt.grid(True)
    plt.tight_layout()
    plt.show()

############################################
# 9. Helper functions for picking base dates
############################################
def pick_every_10th_base_dates(base_dates):
    if len(base_dates)==0:
        return []
    sorted_bases = sorted(base_dates)
    chosen = []
    first_bd = sorted_bases[0]
    for bd in sorted_bases:
        day_diff = (bd - first_bd).days
        if day_diff % 10 == 0:
            chosen.append(bd)
    # ensure final base date is included
    if sorted_bases[-1] not in chosen:
        chosen.append(sorted_bases[-1])
    return sorted(chosen)

def pick_every_5th_base_dates(base_dates):
    """
    Similar logic, but for every 5th date difference from the first base date.
    """
    if len(base_dates)==0:
        return []
    sorted_bases = sorted(base_dates)
    chosen = []
    first_bd = sorted_bases[0]
    for bd in sorted_bases:
        day_diff = (bd - first_bd).days
        if day_diff % 5 == 0:
            chosen.append(bd)
    if sorted_bases[-1] not in chosen:
        chosen.append(sorted_bases[-1])
    return sorted(chosen)

############################################
# 10. Zoom-in Joint Diagram (10th) + Model-by-Model (5th or 10th)
############################################
def plot_joint_10day_forecasts_zoom_in(final_rolling_fcst, df_actual,
                                       start_date_plot, end_date_plot):
    """
    Single figure: Actual Price + multiple model forecasts from every 10th BaseDate,
    restricted to y-axis [28..33].
    """
    color_map = {
        "LSTM": "red",
        "GRU": "blue",
        "RNN": "green",
        "CNN": "orange",
        "EnhancedLSTM": "magenta",
        "Transformer": "cyan",
        "N-BEATS": "brown",
        "N-HITS": "pink",
        "SVM": "olive",
        "GPR": "teal",
        "Boost": "purple"
    }
    df_plot = df_actual[
        (df_actual["Date"]>=start_date_plot) & (df_actual["Date"]<= end_date_plot)
    ].copy()

    base_dates = pick_every_10th_base_dates(final_rolling_fcst["BaseDate"].unique())

    plt.figure(figsize=(12,6))
    # Actual
    plt.plot(df_plot["Date"], df_plot["Price"], color="black", lw=2, label="Actual Price")

    models = final_rolling_fcst["Model"].unique()
    for m in models:
        df_m = final_rolling_fcst[final_rolling_fcst["Model"]==m].copy()
        c = color_map.get(m, "gray")
        for bd in base_dates:
            df_bd = df_m[df_m["BaseDate"]==bd].copy()
            df_bd = df_bd[(df_bd["ForecastDate"]>=start_date_plot) & (df_bd["ForecastDate"]<=end_date_plot)]
            if len(df_bd)==0:
                continue
            plt.plot(df_bd["ForecastDate"], df_bd["Pred_Price_unscaled"], color=c, alpha=0.4)

    legend_elems = [Line2D([0],[0], color="black", lw=2, label="Actual Price")]
    for m in models:
        legend_elems.append(Line2D([0],[0], color=color_map.get(m,"gray"), lw=2, label=m))
    plt.legend(handles=legend_elems, loc="best")

    #plt.ylim(28, 33)  # y-axis restriction
    plt.title(f"Zoom-in Joint Diagram (Every 10th BaseDate)\n{start_date_plot.date()} ~ {end_date_plot.date()} of US Bonds (10-Year T-Note Futures)")
    plt.xlabel("Date")
    plt.ylabel("Price")
    plt.grid(True)
    plt.tight_layout()
    plt.show()

def plot_each_model_10days(final_rolling_fcst, df_actual,
                           start_date_plot, end_date_plot):
    """
    Model-by-model Rolling Forecast, using every 10th BaseDate, no y-limit.
    """
    models = sorted(final_rolling_fcst["Model"].unique())
    df_plot = df_actual[
        (df_actual["Date"]>=start_date_plot) & (df_actual["Date"]<=end_date_plot)
    ].copy()

    base_dates = pick_every_10th_base_dates(final_rolling_fcst["BaseDate"].unique())

    for m in models:
        df_m = final_rolling_fcst[final_rolling_fcst["Model"]==m].copy()
        plt.figure(figsize=(10,5))
        # Actual
        plt.plot(df_plot["Date"], df_plot["Price"], color="black", lw=2, label="Actual Price")

        for bd in base_dates:
            df_bd = df_m[df_m["BaseDate"]==bd].copy()
            df_bd= df_bd[(df_bd["ForecastDate"]>=start_date_plot) & (df_bd["ForecastDate"]<=end_date_plot)]
            if len(df_bd)==0:
                continue
            plt.plot(df_bd["ForecastDate"], df_bd["Pred_Price_unscaled"], alpha=0.6)

        plt.title(f"{m}: Rolling Forecast (Every 10th BaseDate) of US Bonds (10-Year T-Note Futures)")
        plt.xlabel("Date")
        plt.ylabel("Price")
        plt.grid(True)
        plt.legend(prop={"size":7})
        plt.tight_layout()
        plt.show()

def plot_each_model_5days(final_rolling_fcst, df_actual,
                          start_date_plot, end_date_plot):
    """
    Model-by-model Rolling Forecast, using every 5th BaseDate, no y-limit.
    """
    models = sorted(final_rolling_fcst["Model"].unique())
    df_plot = df_actual[
        (df_actual["Date"]>=start_date_plot) & (df_actual["Date"]<=end_date_plot)
    ].copy()

    base_dates = pick_every_5th_base_dates(final_rolling_fcst["BaseDate"].unique())

    for m in models:
        df_m = final_rolling_fcst[final_rolling_fcst["Model"]==m].copy()
        plt.figure(figsize=(10,5))
        # Actual
        plt.plot(df_plot["Date"], df_plot["Price"], color="black", lw=2, label="Actual Price")

        for bd in base_dates:
            df_bd = df_m[df_m["BaseDate"]==bd].copy()
            df_bd= df_bd[(df_bd["ForecastDate"]>=start_date_plot) & (df_bd["ForecastDate"]<=end_date_plot)]
            if len(df_bd)==0:
                continue
            plt.plot(df_bd["ForecastDate"], df_bd["Pred_Price_unscaled"], alpha=0.6)

        plt.title(f"{m}: Rolling Forecast (Every 5th BaseDate) of US Bonds (10-Year T-Note Futures)")
        plt.xlabel("Date")
        plt.ylabel("Price")
        plt.grid(True)
        plt.legend(prop={"size":7})
        plt.tight_layout()
        plt.show()

############################################
# 11. MAIN
############################################
if __name__=="__main__":
    # 1) Load & scale data
    df_scaled, df_complete_all, scaler = load_and_scale_data(
        "US 10 Year T-Note Futures Historical Data.csv",
        "US 10 Year T-Note Futures Historical Data_Complete.csv"
    )

    # 2) Perform rolling approach: LOAD models only,
    #    daily rolling plots only on final day (2025-01-31)
    final_rolling_fc = rolling_train_validate_predict_moe(
        df_full=df_complete_all,
        scaler_obj=scaler,
        model_types=["LSTM","GRU","RNN","CNN","Transformer","N-BEATS","N-HITS","SVM","Boost"],
        start_train_cutoff=pd.to_datetime("2024-07-01"),
        start_val_cutoff=pd.to_datetime("2024-11-30"),
        start_pred=pd.to_datetime("2024-12-01"),
        end_pred=pd.to_datetime("2025-01-02"),
        horizon_days=30,
        do_daily_plots=True   # but effectively only for final day
    )

    # 3) Plot final rolling forecast
    print("\n===== ROLLING FC HEAD =====")
    print(final_rolling_fc.head(50))
    plot_final_rolling_fc(
        final_rolling_fc,
        df_complete_all, 
        from_d=pd.to_datetime("2024-12-01"),
        to_d=pd.to_datetime("2025-01-31")
    )

    # 4) Additional diagrams:

    # A) 2025-01-01 ~ 2025-03-01
    #    - Zoom-in Joint Diagram => every 10th base date, y-limited [28..33]
    #    - Model-by-model => every 10th base date
    print("\n=== PLOTS for 2024-12-01 to 2025-01-31 of US Bonds (10-Year T-Note Futures)===")
    plot_joint_10day_forecasts_zoom_in(
        final_rolling_fc,
        df_complete_all,
        start_date_plot=pd.to_datetime("2024-12-01"),
        end_date_plot=pd.to_datetime("2025-01-31")
    )
    plot_each_model_10days(
        final_rolling_fc,
        df_complete_all,
        start_date_plot=pd.to_datetime("2024-12-01"),
        end_date_plot=pd.to_datetime("2025-01-31")
    )

    # B) 2025-01-01 ~ 2025-02-01
    #    - Zoom-in Joint Diagram => every 10th base date, y-limited [28..33]
    #    - Model-by-model => every 5th base date
    print("\n=== PLOTS for 2024-12-01 to 2025-01-01 of US Bonds (10-Year T-Note Futures)===")
    plot_joint_10day_forecasts_zoom_in(
        final_rolling_fc,
        df_complete_all,
        start_date_plot=pd.to_datetime("2024-12-01"),
        end_date_plot=pd.to_datetime("2025-01-01")
    )
    plot_each_model_5days(
        final_rolling_fc,
        df_complete_all,
        start_date_plot=pd.to_datetime("2024-12-01"),
        end_date_plot=pd.to_datetime("2025-01-01")
    )

    # C) 2025-02-01 ~ 2025-03-01
    #    - Zoom-in Joint Diagram => every 10th base date, y-limited [28..33]
    #    - Model-by-model => every 5th base date
    print("\n=== PLOTS for 2025-01-02 to 2025-01-31 of US Bonds (10-Year T-Note Futures)===")
    plot_joint_10day_forecasts_zoom_in(
        final_rolling_fc,
        df_complete_all,
        start_date_plot=pd.to_datetime("2025-01-02"),
        end_date_plot=pd.to_datetime("2025-01-31")
    )
    plot_each_model_5days(
        final_rolling_fc,
        df_complete_all,
        start_date_plot=pd.to_datetime("2025-01-02"),
        end_date_plot=pd.to_datetime("2025-01-31")
    )

    print("\nAll done.")
# Out:
# === Rolling Day 2024-12-01 ===
#   Loading models for cutoff 2024-07-01 / 2024-11-30
#   Forecast next 30 days from 2024-12-01 with noise
# [PyTorch] Loading existing LSTM from ./best_LSTM_2024-12-01_V1.pt
# [PyTorch] Loading existing GRU from ./best_GRU_2024-12-01_V1.pt
# [PyTorch] Loading existing RNN from ./best_RNN_2024-12-01_V1.pt
# [PyTorch] Loading existing CNN from ./best_CNN_2024-12-01_V1.pt
# [PyTorch] Loading existing Transformer from ./best_Transformer_2024-12-01_V1.pt
# [PyTorch] Loading existing N-BEATS from ./best_N-BEATS_2024-12-01_V1.pt
# [PyTorch] Loading existing N-HITS from ./best_N-HITS_2024-12-01_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-01_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-01_V1.pkl
#
# === Rolling Day 2024-12-02 ===
#   Loading models for cutoff 2024-07-02 / 2024-12-01
#   Forecast next 30 days from 2024-12-02 with noise
# [PyTorch] Loading existing LSTM from ./best_LSTM_2024-12-02_V1.pt
# [PyTorch] Loading existing GRU from ./best_GRU_2024-12-02_V1.pt
# [PyTorch] Loading existing RNN from ./best_RNN_2024-12-02_V1.pt
# [PyTorch] Loading existing CNN from ./best_CNN_2024-12-02_V1.pt
# [PyTorch] Loading existing Transformer from ./best_Transformer_2024-12-02_V1.pt
# [PyTorch] Loading existing N-BEATS from ./best_N-BEATS_2024-12-02_V1.pt
# [PyTorch] Loading existing N-HITS from ./best_N-HITS_2024-12-02_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-02_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-02_V1.pkl
#   Actual price: 111.1100
#
# === Rolling Day 2024-12-03 ===
#   Loading models for cutoff 2024-07-03 / 2024-12-02
#   Forecast next 30 days from 2024-12-03 with noise
# [PyTorch] Loading existing LSTM from ./best_LSTM_2024-12-03_V1.pt
# [PyTorch] Loading existing GRU from ./best_GRU_2024-12-03_V1.pt
# [PyTorch] Loading existing RNN from ./best_RNN_2024-12-03_V1.pt
# [PyTorch] Loading existing CNN from ./best_CNN_2024-12-03_V1.pt
# [PyTorch] Loading existing Transformer from ./best_Transformer_2024-12-03_V1.pt
# [PyTorch] Loading existing N-BEATS from ./best_N-BEATS_2024-12-03_V1.pt
# [PyTorch] Loading existing N-HITS from ./best_N-HITS_2024-12-03_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-03_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-03_V1.pkl
#   Actual price: 110.9700
#
# === Rolling Day 2024-12-04 ===
#   Loading models for cutoff 2024-07-04 / 2024-12-03
#   Forecast next 30 days from 2024-12-04 with noise
# [PyTorch] Loading existing LSTM from ./best_LSTM_2024-12-04_V1.pt
# [PyTorch] Loading existing GRU from ./best_GRU_2024-12-04_V1.pt
# [PyTorch] Loading existing RNN from ./best_RNN_2024-12-04_V1.pt
# [PyTorch] Loading existing CNN from ./best_CNN_2024-12-04_V1.pt
# [PyTorch] Loading existing Transformer from ./best_Transformer_2024-12-04_V1.pt
# [PyTorch] Loading existing N-BEATS from ./best_N-BEATS_2024-12-04_V1.pt
# [PyTorch] Loading existing N-HITS from ./best_N-HITS_2024-12-04_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-04_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-04_V1.pkl
#   Actual price: 111.2500
#
# === Rolling Day 2024-12-05 ===
#   Loading models for cutoff 2024-07-05 / 2024-12-04
#   Forecast next 30 days from 2024-12-05 with noise
# [PyTorch] Loading existing LSTM from ./best_LSTM_2024-12-05_V1.pt
# [PyTorch] Loading existing GRU from ./best_GRU_2024-12-05_V1.pt
# [PyTorch] Loading existing RNN from ./best_RNN_2024-12-05_V1.pt
# [PyTorch] Loading existing CNN from ./best_CNN_2024-12-05_V1.pt
# [PyTorch] Loading existing Transformer from ./best_Transformer_2024-12-05_V1.pt
# [PyTorch] Loading existing N-BEATS from ./best_N-BEATS_2024-12-05_V1.pt
# [PyTorch] Loading existing N-HITS from ./best_N-HITS_2024-12-05_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-05_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-05_V1.pkl
#   Actual price: 111.2000
#
# === Rolling Day 2024-12-06 ===
#   Loading models for cutoff 2024-07-06 / 2024-12-05
#   Forecast next 30 days from 2024-12-06 with noise
# [PyTorch] Loading existing LSTM from ./best_LSTM_2024-12-06_V1.pt
# [PyTorch] Loading existing GRU from ./best_GRU_2024-12-06_V1.pt
# [PyTorch] Loading existing RNN from ./best_RNN_2024-12-06_V1.pt
# [PyTorch] Loading existing CNN from ./best_CNN_2024-12-06_V1.pt
# [PyTorch] Loading existing Transformer from ./best_Transformer_2024-12-06_V1.pt
# [PyTorch] Loading existing N-BEATS from ./best_N-BEATS_2024-12-06_V1.pt
# [PyTorch] Loading existing N-HITS from ./best_N-HITS_2024-12-06_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-06_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-06_V1.pkl
#   Actual price: 111.4500
#
# === Rolling Day 2024-12-07 ===
#   Loading models for cutoff 2024-07-07 / 2024-12-06
#   Forecast next 30 days from 2024-12-07 with noise
# [PyTorch] Loading existing LSTM from ./best_LSTM_2024-12-07_V1.pt
# [PyTorch] Loading existing GRU from ./best_GRU_2024-12-07_V1.pt
# [PyTorch] Loading existing RNN from ./best_RNN_2024-12-07_V1.pt
# [PyTorch] Loading existing CNN from ./best_CNN_2024-12-07_V1.pt
# [PyTorch] Loading existing Transformer from ./best_Transformer_2024-12-07_V1.pt
# [PyTorch] Loading existing N-BEATS from ./best_N-BEATS_2024-12-07_V1.pt
# [PyTorch] Loading existing N-HITS from ./best_N-HITS_2024-12-07_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-07_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-07_V1.pkl
#
# === Rolling Day 2024-12-08 ===
#   Loading models for cutoff 2024-07-08 / 2024-12-07
#   Forecast next 30 days from 2024-12-08 with noise
# [PyTorch] Loading existing LSTM from ./best_LSTM_2024-12-08_V1.pt
# [PyTorch] Loading existing GRU from ./best_GRU_2024-12-08_V1.pt
# [PyTorch] Loading existing RNN from ./best_RNN_2024-12-08_V1.pt
# [PyTorch] Loading existing CNN from ./best_CNN_2024-12-08_V1.pt
# [PyTorch] Loading existing Transformer from ./best_Transformer_2024-12-08_V1.pt
# [PyTorch] Loading existing N-BEATS from ./best_N-BEATS_2024-12-08_V1.pt
# [PyTorch] Loading existing N-HITS from ./best_N-HITS_2024-12-08_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-08_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-08_V1.pkl
#
# === Rolling Day 2024-12-09 ===
#   Loading models for cutoff 2024-07-09 / 2024-12-08
#   Forecast next 30 days from 2024-12-09 with noise
# [PyTorch] Loading existing LSTM from ./best_LSTM_2024-12-09_V1.pt
# [PyTorch] Loading existing GRU from ./best_GRU_2024-12-09_V1.pt
# [PyTorch] Loading existing RNN from ./best_RNN_2024-12-09_V1.pt
# [PyTorch] Loading existing CNN from ./best_CNN_2024-12-09_V1.pt
# [PyTorch] Loading existing Transformer from ./best_Transformer_2024-12-09_V1.pt
# [PyTorch] Loading existing N-BEATS from ./best_N-BEATS_2024-12-09_V1.pt
# [PyTorch] Loading existing N-HITS from ./best_N-HITS_2024-12-09_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-09_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-09_V1.pkl
#   Actual price: 111.1700
#
# === Rolling Day 2024-12-10 ===
#   Loading models for cutoff 2024-07-10 / 2024-12-09
#   Forecast next 30 days from 2024-12-10 with noise
# [PyTorch] Loading existing LSTM from ./best_LSTM_2024-12-10_V1.pt
# [PyTorch] Loading existing GRU from ./best_GRU_2024-12-10_V1.pt
# [PyTorch] Loading existing RNN from ./best_RNN_2024-12-10_V1.pt
# [PyTorch] Loading existing CNN from ./best_CNN_2024-12-10_V1.pt
# [PyTorch] Loading existing Transformer from ./best_Transformer_2024-12-10_V1.pt
# [PyTorch] Loading existing N-BEATS from ./best_N-BEATS_2024-12-10_V1.pt
# [PyTorch] Loading existing N-HITS from ./best_N-HITS_2024-12-10_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-10_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-10_V1.pkl
#   Actual price: 111.0000
#
# === Rolling Day 2024-12-11 ===
#   Loading models for cutoff 2024-07-11 / 2024-12-10
#   Forecast next 30 days from 2024-12-11 with noise
# [PyTorch] Loading existing LSTM from ./best_LSTM_2024-12-11_V1.pt
# [PyTorch] Loading existing GRU from ./best_GRU_2024-12-11_V1.pt
# [PyTorch] Loading existing RNN from ./best_RNN_2024-12-11_V1.pt
# [PyTorch] Loading existing CNN from ./best_CNN_2024-12-11_V1.pt
# [PyTorch] Loading existing Transformer from ./best_Transformer_2024-12-11_V1.pt
# [PyTorch] Loading existing N-BEATS from ./best_N-BEATS_2024-12-11_V1.pt
# [PyTorch] Loading existing N-HITS from ./best_N-HITS_2024-12-11_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-11_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-11_V1.pkl
#   Actual price: 110.6900
#
# === Rolling Day 2024-12-12 ===
#   Loading models for cutoff 2024-07-12 / 2024-12-11
#   Forecast next 30 days from 2024-12-12 with noise
# [PyTorch] Loading existing LSTM from ./best_LSTM_2024-12-12_V1.pt
# [PyTorch] Loading existing GRU from ./best_GRU_2024-12-12_V1.pt
# [PyTorch] Loading existing RNN from ./best_RNN_2024-12-12_V1.pt
# [PyTorch] Loading existing CNN from ./best_CNN_2024-12-12_V1.pt
# [PyTorch] Loading existing Transformer from ./best_Transformer_2024-12-12_V1.pt
# [PyTorch] Loading existing N-BEATS from ./best_N-BEATS_2024-12-12_V1.pt
# [PyTorch] Loading existing N-HITS from ./best_N-HITS_2024-12-12_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-12_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-12_V1.pkl
#   Actual price: 110.3800
#
# === Rolling Day 2024-12-13 ===
#   Loading models for cutoff 2024-07-13 / 2024-12-12
#   Forecast next 30 days from 2024-12-13 with noise
# [PyTorch] Loading existing LSTM from ./best_LSTM_2024-12-13_V1.pt
# [PyTorch] Loading existing GRU from ./best_GRU_2024-12-13_V1.pt
# [PyTorch] Loading existing RNN from ./best_RNN_2024-12-13_V1.pt
# [PyTorch] Loading existing CNN from ./best_CNN_2024-12-13_V1.pt
# [PyTorch] Loading existing Transformer from ./best_Transformer_2024-12-13_V1.pt
# [PyTorch] Loading existing N-BEATS from ./best_N-BEATS_2024-12-13_V1.pt
# [PyTorch] Loading existing N-HITS from ./best_N-HITS_2024-12-13_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-13_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-13_V1.pkl
#   Actual price: 109.8800
#
# === Rolling Day 2024-12-14 ===
#   Loading models for cutoff 2024-07-14 / 2024-12-13
#   Forecast next 30 days from 2024-12-14 with noise
# [PyTorch] Loading existing LSTM from ./best_LSTM_2024-12-14_V1.pt
# [PyTorch] Loading existing GRU from ./best_GRU_2024-12-14_V1.pt
# [PyTorch] Loading existing RNN from ./best_RNN_2024-12-14_V1.pt
# [PyTorch] Loading existing CNN from ./best_CNN_2024-12-14_V1.pt
# [PyTorch] Loading existing Transformer from ./best_Transformer_2024-12-14_V1.pt
# [PyTorch] Loading existing N-BEATS from ./best_N-BEATS_2024-12-14_V1.pt
# [PyTorch] Loading existing N-HITS from ./best_N-HITS_2024-12-14_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-14_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-14_V1.pkl
#
# === Rolling Day 2024-12-15 ===
#   Loading models for cutoff 2024-07-15 / 2024-12-14
#   Forecast next 30 days from 2024-12-15 with noise
# [PyTorch] Loading existing LSTM from ./best_LSTM_2024-12-15_V1.pt
# [PyTorch] Loading existing GRU from ./best_GRU_2024-12-15_V1.pt
# [PyTorch] Loading existing RNN from ./best_RNN_2024-12-15_V1.pt
# [PyTorch] Loading existing CNN from ./best_CNN_2024-12-15_V1.pt
# [PyTorch] Loading existing Transformer from ./best_Transformer_2024-12-15_V1.pt
# [PyTorch] Loading existing N-BEATS from ./best_N-BEATS_2024-12-15_V1.pt
# [PyTorch] Loading existing N-HITS from ./best_N-HITS_2024-12-15_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-15_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-15_V1.pkl
#
# === Rolling Day 2024-12-16 ===
#   Loading models for cutoff 2024-07-16 / 2024-12-15
#   Forecast next 30 days from 2024-12-16 with noise
# [PyTorch] Loading existing LSTM from ./best_LSTM_2024-12-16_V1.pt
# [PyTorch] Loading existing GRU from ./best_GRU_2024-12-16_V1.pt
# [PyTorch] Loading existing RNN from ./best_RNN_2024-12-16_V1.pt
# [PyTorch] Loading existing CNN from ./best_CNN_2024-12-16_V1.pt
# [PyTorch] Loading existing Transformer from ./best_Transformer_2024-12-16_V1.pt
# [PyTorch] Loading existing N-BEATS from ./best_N-BEATS_2024-12-16_V1.pt
# [PyTorch] Loading existing N-HITS from ./best_N-HITS_2024-12-16_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-16_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-16_V1.pkl
#   Actual price: 109.8600
#
# === Rolling Day 2024-12-17 ===
#   Loading models for cutoff 2024-07-17 / 2024-12-16
#   Forecast next 30 days from 2024-12-17 with noise
# [PyTorch] Loading existing LSTM from ./best_LSTM_2024-12-17_V1.pt
# [PyTorch] Loading existing GRU from ./best_GRU_2024-12-17_V1.pt
# [PyTorch] Loading existing RNN from ./best_RNN_2024-12-17_V1.pt
# [PyTorch] Loading existing CNN from ./best_CNN_2024-12-17_V1.pt
# [PyTorch] Loading existing Transformer from ./best_Transformer_2024-12-17_V1.pt
# [PyTorch] Loading existing N-BEATS from ./best_N-BEATS_2024-12-17_V1.pt
# [PyTorch] Loading existing N-HITS from ./best_N-HITS_2024-12-17_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-17_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-17_V1.pkl
#   Actual price: 109.9100
#
# === Rolling Day 2024-12-18 ===
#   Loading models for cutoff 2024-07-18 / 2024-12-17
#   Forecast next 30 days from 2024-12-18 with noise
# [PyTorch] Loading existing LSTM from ./best_LSTM_2024-12-18_V1.pt
# [PyTorch] Loading existing GRU from ./best_GRU_2024-12-18_V1.pt
# [PyTorch] Loading existing RNN from ./best_RNN_2024-12-18_V1.pt
# [PyTorch] Loading existing CNN from ./best_CNN_2024-12-18_V1.pt
# [PyTorch] Loading existing Transformer from ./best_Transformer_2024-12-18_V1.pt
# [PyTorch] Loading existing N-BEATS from ./best_N-BEATS_2024-12-18_V1.pt
# [PyTorch] Loading existing N-HITS from ./best_N-HITS_2024-12-18_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-18_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-18_V1.pkl
#   Actual price: 109.0200
#
# === Rolling Day 2024-12-19 ===
#   Loading models for cutoff 2024-07-19 / 2024-12-18
#   Forecast next 30 days from 2024-12-19 with noise
# [PyTorch] Loading existing LSTM from ./best_LSTM_2024-12-19_V1.pt
# [PyTorch] Loading existing GRU from ./best_GRU_2024-12-19_V1.pt
# [PyTorch] Loading existing RNN from ./best_RNN_2024-12-19_V1.pt
# [PyTorch] Loading existing CNN from ./best_CNN_2024-12-19_V1.pt
# [PyTorch] Loading existing Transformer from ./best_Transformer_2024-12-19_V1.pt
# [PyTorch] Loading existing N-BEATS from ./best_N-BEATS_2024-12-19_V1.pt
# [PyTorch] Loading existing N-HITS from ./best_N-HITS_2024-12-19_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-19_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-19_V1.pkl
#   Actual price: 108.6100
#
# === Rolling Day 2024-12-20 ===
#   Loading models for cutoff 2024-07-20 / 2024-12-19
#   Forecast next 30 days from 2024-12-20 with noise
# [PyTorch] Loading existing LSTM from ./best_LSTM_2024-12-20_V1.pt
# [PyTorch] Loading existing GRU from ./best_GRU_2024-12-20_V1.pt
# [PyTorch] Loading existing RNN from ./best_RNN_2024-12-20_V1.pt
# [PyTorch] Loading existing CNN from ./best_CNN_2024-12-20_V1.pt
# [PyTorch] Loading existing Transformer from ./best_Transformer_2024-12-20_V1.pt
# [PyTorch] Loading existing N-BEATS from ./best_N-BEATS_2024-12-20_V1.pt
# [PyTorch] Loading existing N-HITS from ./best_N-HITS_2024-12-20_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-20_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-20_V1.pkl
#   Actual price: 108.9700
#
# === Rolling Day 2024-12-21 ===
#   Loading models for cutoff 2024-07-21 / 2024-12-20
#   Forecast next 30 days from 2024-12-21 with noise
# [PyTorch] Loading existing LSTM from ./best_LSTM_2024-12-21_V1.pt
# [PyTorch] Loading existing GRU from ./best_GRU_2024-12-21_V1.pt
# [PyTorch] Loading existing RNN from ./best_RNN_2024-12-21_V1.pt
# [PyTorch] Loading existing CNN from ./best_CNN_2024-12-21_V1.pt
# [PyTorch] Loading existing Transformer from ./best_Transformer_2024-12-21_V1.pt
# [PyTorch] Loading existing N-BEATS from ./best_N-BEATS_2024-12-21_V1.pt
# [PyTorch] Loading existing N-HITS from ./best_N-HITS_2024-12-21_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-21_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-21_V1.pkl
#
# === Rolling Day 2024-12-22 ===
#   Loading models for cutoff 2024-07-22 / 2024-12-21
#   Forecast next 30 days from 2024-12-22 with noise
# [PyTorch] Loading existing LSTM from ./best_LSTM_2024-12-22_V1.pt
# [PyTorch] Loading existing GRU from ./best_GRU_2024-12-22_V1.pt
# [PyTorch] Loading existing RNN from ./best_RNN_2024-12-22_V1.pt
# [PyTorch] Loading existing CNN from ./best_CNN_2024-12-22_V1.pt
# [PyTorch] Loading existing Transformer from ./best_Transformer_2024-12-22_V1.pt
# [PyTorch] Loading existing N-BEATS from ./best_N-BEATS_2024-12-22_V1.pt
# [PyTorch] Loading existing N-HITS from ./best_N-HITS_2024-12-22_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-22_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-22_V1.pkl
#
# === Rolling Day 2024-12-23 ===
#   Loading models for cutoff 2024-07-23 / 2024-12-22
#   Forecast next 30 days from 2024-12-23 with noise
# [PyTorch] Loading existing LSTM from ./best_LSTM_2024-12-23_V1.pt
# [PyTorch] Loading existing GRU from ./best_GRU_2024-12-23_V1.pt
# [PyTorch] Loading existing RNN from ./best_RNN_2024-12-23_V1.pt
# [PyTorch] Loading existing CNN from ./best_CNN_2024-12-23_V1.pt
# [PyTorch] Loading existing Transformer from ./best_Transformer_2024-12-23_V1.pt
# [PyTorch] Loading existing N-BEATS from ./best_N-BEATS_2024-12-23_V1.pt
# [PyTorch] Loading existing N-HITS from ./best_N-HITS_2024-12-23_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-23_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-23_V1.pkl
#   Actual price: 108.4700
#
# === Rolling Day 2024-12-24 ===
#   Loading models for cutoff 2024-07-24 / 2024-12-23
#   Forecast next 30 days from 2024-12-24 with noise
# [PyTorch] Loading existing LSTM from ./best_LSTM_2024-12-24_V1.pt
# [PyTorch] Loading existing GRU from ./best_GRU_2024-12-24_V1.pt
# [PyTorch] Loading existing RNN from ./best_RNN_2024-12-24_V1.pt
# [PyTorch] Loading existing CNN from ./best_CNN_2024-12-24_V1.pt
# [PyTorch] Loading existing Transformer from ./best_Transformer_2024-12-24_V1.pt
# [PyTorch] Loading existing N-BEATS from ./best_N-BEATS_2024-12-24_V1.pt
# [PyTorch] Loading existing N-HITS from ./best_N-HITS_2024-12-24_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-24_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-24_V1.pkl
#   Actual price: 108.5600
#
# === Rolling Day 2024-12-25 ===
#   Loading models for cutoff 2024-07-25 / 2024-12-24
#   Forecast next 30 days from 2024-12-25 with noise
# [PyTorch] Loading existing LSTM from ./best_LSTM_2024-12-25_V1.pt
# [PyTorch] Loading existing GRU from ./best_GRU_2024-12-25_V1.pt
# [PyTorch] Loading existing RNN from ./best_RNN_2024-12-25_V1.pt
# [PyTorch] Loading existing CNN from ./best_CNN_2024-12-25_V1.pt
# [PyTorch] Loading existing Transformer from ./best_Transformer_2024-12-25_V1.pt
# [PyTorch] Loading existing N-BEATS from ./best_N-BEATS_2024-12-25_V1.pt
# [PyTorch] Loading existing N-HITS from ./best_N-HITS_2024-12-25_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-25_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-25_V1.pkl
#
# === Rolling Day 2024-12-26 ===
#   Loading models for cutoff 2024-07-26 / 2024-12-25
#   Forecast next 30 days from 2024-12-26 with noise
# [PyTorch] Loading existing LSTM from ./best_LSTM_2024-12-26_V1.pt
# [PyTorch] Loading existing GRU from ./best_GRU_2024-12-26_V1.pt
# [PyTorch] Loading existing RNN from ./best_RNN_2024-12-26_V1.pt
# [PyTorch] Loading existing CNN from ./best_CNN_2024-12-26_V1.pt
# [PyTorch] Loading existing Transformer from ./best_Transformer_2024-12-26_V1.pt
# [PyTorch] Loading existing N-BEATS from ./best_N-BEATS_2024-12-26_V1.pt
# [PyTorch] Loading existing N-HITS from ./best_N-HITS_2024-12-26_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-26_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-26_V1.pkl
#   Actual price: 108.6600
#
# === Rolling Day 2024-12-27 ===
#   Loading models for cutoff 2024-07-27 / 2024-12-26
#   Forecast next 30 days from 2024-12-27 with noise
# [PyTorch] Loading existing LSTM from ./best_LSTM_2024-12-27_V1.pt
# [PyTorch] Loading existing GRU from ./best_GRU_2024-12-27_V1.pt
# [PyTorch] Loading existing RNN from ./best_RNN_2024-12-27_V1.pt
# [PyTorch] Loading existing CNN from ./best_CNN_2024-12-27_V1.pt
# [PyTorch] Loading existing Transformer from ./best_Transformer_2024-12-27_V1.pt
# [PyTorch] Loading existing N-BEATS from ./best_N-BEATS_2024-12-27_V1.pt
# [PyTorch] Loading existing N-HITS from ./best_N-HITS_2024-12-27_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-27_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-27_V1.pkl
#   Actual price: 108.4400
#
# === Rolling Day 2024-12-28 ===
#   Loading models for cutoff 2024-07-28 / 2024-12-27
#   Forecast next 30 days from 2024-12-28 with noise
# [PyTorch] Loading existing LSTM from ./best_LSTM_2024-12-28_V1.pt
# [PyTorch] Loading existing GRU from ./best_GRU_2024-12-28_V1.pt
# [PyTorch] Loading existing RNN from ./best_RNN_2024-12-28_V1.pt
# [PyTorch] Loading existing CNN from ./best_CNN_2024-12-28_V1.pt
# [PyTorch] Loading existing Transformer from ./best_Transformer_2024-12-28_V1.pt
# [PyTorch] Loading existing N-BEATS from ./best_N-BEATS_2024-12-28_V1.pt
# [PyTorch] Loading existing N-HITS from ./best_N-HITS_2024-12-28_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-28_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-28_V1.pkl
#
# === Rolling Day 2024-12-29 ===
#   Loading models for cutoff 2024-07-29 / 2024-12-28
#   Forecast next 30 days from 2024-12-29 with noise
# [PyTorch] Loading existing LSTM from ./best_LSTM_2024-12-29_V1.pt
# [PyTorch] Loading existing GRU from ./best_GRU_2024-12-29_V1.pt
# [PyTorch] Loading existing RNN from ./best_RNN_2024-12-29_V1.pt
# [PyTorch] Loading existing CNN from ./best_CNN_2024-12-29_V1.pt
# [PyTorch] Loading existing Transformer from ./best_Transformer_2024-12-29_V1.pt
# [PyTorch] Loading existing N-BEATS from ./best_N-BEATS_2024-12-29_V1.pt
# [PyTorch] Loading existing N-HITS from ./best_N-HITS_2024-12-29_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-29_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-29_V1.pkl
#
# === Rolling Day 2024-12-30 ===
#   Loading models for cutoff 2024-07-30 / 2024-12-29
#   Forecast next 30 days from 2024-12-30 with noise
# [PyTorch] Loading existing LSTM from ./best_LSTM_2024-12-30_V1.pt
# [PyTorch] Loading existing GRU from ./best_GRU_2024-12-30_V1.pt
# [PyTorch] Loading existing RNN from ./best_RNN_2024-12-30_V1.pt
# [PyTorch] Loading existing CNN from ./best_CNN_2024-12-30_V1.pt
# [PyTorch] Loading existing Transformer from ./best_Transformer_2024-12-30_V1.pt
# [PyTorch] Loading existing N-BEATS from ./best_N-BEATS_2024-12-30_V1.pt
# [PyTorch] Loading existing N-HITS from ./best_N-HITS_2024-12-30_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-30_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-30_V1.pkl
#   Actual price: 108.9700
#
# === Rolling Day 2024-12-31 ===
#   Loading models for cutoff 2024-07-31 / 2024-12-30
#   Forecast next 30 days from 2024-12-31 with noise
# [PyTorch] Loading existing LSTM from ./best_LSTM_2024-12-31_V1.pt
# [PyTorch] Loading existing GRU from ./best_GRU_2024-12-31_V1.pt
# [PyTorch] Loading existing RNN from ./best_RNN_2024-12-31_V1.pt
# [PyTorch] Loading existing CNN from ./best_CNN_2024-12-31_V1.pt
# [PyTorch] Loading existing Transformer from ./best_Transformer_2024-12-31_V1.pt
# [PyTorch] Loading existing N-BEATS from ./best_N-BEATS_2024-12-31_V1.pt
# [PyTorch] Loading existing N-HITS from ./best_N-HITS_2024-12-31_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2024-12-31_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2024-12-31_V1.pkl
#   Actual price: 108.7500
#
# === Rolling Day 2025-01-01 ===
#   Loading models for cutoff 2024-08-01 / 2024-12-31
#   Forecast next 30 days from 2025-01-01 with noise
# [PyTorch] Loading existing LSTM from ./best_LSTM_2025-01-01_V1.pt
# [PyTorch] Loading existing GRU from ./best_GRU_2025-01-01_V1.pt
# [PyTorch] Loading existing RNN from ./best_RNN_2025-01-01_V1.pt
# [PyTorch] Loading existing CNN from ./best_CNN_2025-01-01_V1.pt
# [PyTorch] Loading existing Transformer from ./best_Transformer_2025-01-01_V1.pt
# [PyTorch] Loading existing N-BEATS from ./best_N-BEATS_2025-01-01_V1.pt
# [PyTorch] Loading existing N-HITS from ./best_N-HITS_2025-01-01_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2025-01-01_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2025-01-01_V1.pkl
#
# === Rolling Day 2025-01-02 ===
#   Loading models for cutoff 2024-08-02 / 2025-01-01
#   Forecast next 30 days from 2025-01-02 with noise
# [PyTorch] Loading existing LSTM from ./best_LSTM_2025-01-02_V1.pt
# [PyTorch] Loading existing GRU from ./best_GRU_2025-01-02_V1.pt
# [PyTorch] Loading existing RNN from ./best_RNN_2025-01-02_V1.pt
# [PyTorch] Loading existing CNN from ./best_CNN_2025-01-02_V1.pt
# [PyTorch] Loading existing Transformer from ./best_Transformer_2025-01-02_V1.pt
# [PyTorch] Loading existing N-BEATS from ./best_N-BEATS_2025-01-02_V1.pt
# [PyTorch] Loading existing N-HITS from ./best_N-HITS_2025-01-02_V1.pt
# [sklearn] Loading SVM => ./best_SVM_2025-01-02_V1.pkl
# [sklearn] Loading Boost => ./best_Boost_2025-01-02_V1.pkl
#   Actual price: nan
# ===== ROLLING FC HEAD =====
#     ForecastDate  Pred_Price_unscaled  Pred_Open_unscaled  Pred_High_unscaled  \
# 240   2024-12-01           111.002886          111.234794          111.364461
# 241   2024-12-02           110.939451          111.082663          111.027932
# 242   2024-12-03           110.937392          111.161851          111.056375
# 243   2024-12-04           110.630778          111.143417          111.173404
# 244   2024-12-05           110.732637          110.605930          111.114807
# 245   2024-12-06           110.791901          110.668324          111.095033
# 246   2024-12-07           110.772129          110.810138          111.152112
# 247   2024-12-08           110.808406          110.782102          111.181834
# 248   2024-12-09           110.711723          110.810753          111.134146
# 249   2024-12-10           110.756018          110.698016          111.095429
# 250   2024-12-11           110.681241          110.860870          111.154742
# 251   2024-12-12           110.716740          110.674854          111.058632
# 252   2024-12-13           110.738562          110.671459          111.041963
# 253   2024-12-14           110.851187          110.858650          111.144060
# 254   2024-12-15           110.704351          110.702343          111.047957
# 255   2024-12-16           110.761706          110.700358          110.944809
# 256   2024-12-17           110.641119          110.770720          110.986016
# 257   2024-12-18           110.806437          110.584719          111.015827
# 258   2024-12-19           110.712393          110.735848          111.099536
# 259   2024-12-20           110.812617          110.703171          110.995885
# 260   2024-12-21           110.753239          110.828607          110.998197
# 261   2024-12-22           110.868527          110.795738          111.004031
# 262   2024-12-23           110.694266          110.722757          110.975272
# 263   2024-12-24           110.764942          110.667773          111.147028
# 264   2024-12-25           110.705033          110.839754          111.080244
# 265   2024-12-26           110.727595          110.613208          111.084091
# 266   2024-12-27           110.734136          110.681798          111.061869
# 267   2024-12-28           110.954615          110.701014          111.109917
# 268   2024-12-29           111.016556          110.986827          111.183126
# 269   2024-12-30           110.954016          111.018804          111.163789
# 510   2024-12-02           110.991839          111.239974          111.317637
# 511   2024-12-03           110.868830          110.989764          111.120612
# 512   2024-12-04           110.701631          110.848963          110.881338
# 513   2024-12-05           110.195599          110.695771          110.862858
# 514   2024-12-06           110.240216          110.297182          110.548027
# 515   2024-12-07           110.298692          110.341053          110.557309
# 516   2024-12-08           110.121585          110.230448          110.401387
# 517   2024-12-09           110.088368          110.366388          110.590567
# 518   2024-12-10           110.224484          110.276088          110.575521
# 519   2024-12-11           110.178403          110.254931          110.629855
# 520   2024-12-12           110.126237          110.307554          110.570407
# 521   2024-12-13           110.128190          110.163037          110.400664
# 522   2024-12-14           110.194237          110.135818          110.547023
# 523   2024-12-15           110.104993          110.227972          110.618312
# 524   2024-12-16           110.100590          110.185102          110.464659
# 525   2024-12-17           110.037447          110.244019          110.379875
# 526   2024-12-18           110.103948          110.005077          110.427507
# 527   2024-12-19           110.010223          110.154924          110.516275
# 528   2024-12-20           109.718809          109.845526          110.073129
# 529   2024-12-21           109.694870          109.815266          109.921030
#
#      Pred_Low_unscaled   BaseDate  Model
# 240         110.841144 2024-12-01  Boost
# 241         110.931322 2024-12-01  Boost
# 242         110.808309 2024-12-01  Boost
# 243         110.697529 2024-12-01  Boost
# 244         110.403804 2024-12-01  Boost
# 245         110.491584 2024-12-01  Boost
# 246         110.470979 2024-12-01  Boost
# 247         110.464964 2024-12-01  Boost
# 248         110.531340 2024-12-01  Boost
# 249         110.423569 2024-12-01  Boost
# 250         110.425394 2024-12-01  Boost
# 251         110.353798 2024-12-01  Boost
# 252         110.557027 2024-12-01  Boost
# 253         110.445022 2024-12-01  Boost
# 254         110.512345 2024-12-01  Boost
# 255         110.342357 2024-12-01  Boost
# 256         110.387484 2024-12-01  Boost
# 257         110.445628 2024-12-01  Boost
# 258         110.488340 2024-12-01  Boost
# 259         110.284092 2024-12-01  Boost
# 260         110.512795 2024-12-01  Boost
# 261         110.390388 2024-12-01  Boost
# 262         110.412490 2024-12-01  Boost
# 263         110.400878 2024-12-01  Boost
# 264         110.305524 2024-12-01  Boost
# 265         110.269148 2024-12-01  Boost
# 266         110.335747 2024-12-01  Boost
# 267         110.263431 2024-12-01  Boost
# 268         110.765794 2024-12-01  Boost
# 269         110.709790 2024-12-01  Boost
# 510         110.854301 2024-12-02  Boost
# 511         110.913433 2024-12-02  Boost
# 512         110.496417 2024-12-02  Boost
# 513         110.227855 2024-12-02  Boost
# 514         109.992954 2024-12-02  Boost
# 515         109.835201 2024-12-02  Boost
# 516         109.985277 2024-12-02  Boost
# 517         109.779643 2024-12-02  Boost
# 518         109.894971 2024-12-02  Boost
# 519         110.019446 2024-12-02  Boost
# 520         109.787258 2024-12-02  Boost
# 521         109.848591 2024-12-02  Boost
# 522         109.802020 2024-12-02  Boost
# 523         109.877258 2024-12-02  Boost
# 524         109.836204 2024-12-02  Boost
# 525         109.636725 2024-12-02  Boost
# 526         109.703615 2024-12-02  Boost
# 527         109.735951 2024-12-02  Boost
# 528         109.643911 2024-12-02  Boost
# 529         109.477588 2024-12-02  Boost
# === PLOTS for 2024-12-01 to 2025-01-31 of US Bonds (10-Year T-Note Futures)===
# === PLOTS for 2024-12-01 to 2025-01-01 of US Bonds (10-Year T-Note Futures)===
# === PLOTS for 2025-01-02 to 2025-01-31 of US Bonds (10-Year T-Note Futures)===
# All done.
