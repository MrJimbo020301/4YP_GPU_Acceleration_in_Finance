# %%
###############################################################################
# basket_trade_two_assets.py  –  Jan‑2025 Citigroup + Brent‑Oil basket trading
###############################################################################
import pandas as pd
from pathlib import Path

# --------------------------------------------------------------------------- #
# 0) CONFIGURATION                                                            #
# --------------------------------------------------------------------------- #
INIT_NAV     = 10_000           # initial portfolio value
MAX_WEIGHT   = 0.75             # cap per‑asset weight (optional risk‑guard)
ASSETS = {                       # filenames for each asset
    "citi":  dict(sig="signals_citi.csv",
                  conf="confidence_citi.csv",
                  ret="returns_citi.csv"),
    "brent": dict(sig="signals_brentoil.csv",
                  conf="confidence_brentoil.csv",
                  ret="returns_brentoil.csv")
}
OUT_BASKET_NAV = "basket_nav_jan25.csv"
# --------------------------------------------------------------------------- #

def _load_col(fname: str, colname: str) -> pd.Series:
    """Load CSV and return <colname> as a date‑indexed Series."""
    s = (pd.read_csv(fname, parse_dates=["date"])
          .set_index("date")[colname])
    if not s.index.is_monotonic_increasing:
        s = s.sort_index()
    return s

# -------- 1) load & merge the three feeds per asset ------------------------ #
frames = []
for asset, f in ASSETS.items():
    sig  = _load_col(f["sig"],  "signal").rename(f"{asset}_sig")
    conf = _load_col(f["conf"], "conf"  ).rename(f"{asset}_conf")
    ret  = _load_col(f["ret"],  "ret"   ).rename(f"{asset}_ret")
    frames.append(pd.concat([sig, conf, ret], axis=1))

###############################################################################
# … everything above unchanged …
###############################################################################

basket_df = pd.concat(frames, axis=1).loc["2025-01-01":"2025-01-31"]
basket_df = basket_df.sort_index()

# ---------- NEW: sanitise missing data --------------------------------------
for a in ASSETS:                                       # ← add this block
    basket_df[f"{a}_sig" ].fillna(0, inplace=True)     #   signals:   0 = flat
    basket_df[f"{a}_conf"].fillna(0, inplace=True)     #   conf:      0 means “skip asset”
    basket_df[f"{a}_ret" ].fillna(0, inplace=True)     #   returns:   0 → no PnL impact
#  (If you prefer ffill/back‑fill for conf/ret, replace the three lines above by
#   basket_df[[f"{a}_conf", f"{a}_ret"]].fillna(method="ffill", inplace=True)
#   basket_df.fillna(0, inplace=True))

# -------- 2) back‑test loop ------------------------------------------------ #
nav_hist = []
trade_log = []
nav = INIT_NAV

for dt, row in basket_df.iterrows():
    active = [a for a in ASSETS if row[f"{a}_sig"] != 0]

    if not active:
        nav_hist.append({"date": dt, "nav": nav, "sig": 0})
        trade_log.append(f"{dt.date()}  |  FLAT  |  NAV stays {nav:,.2f}")
        continue

    # ---- 2a) weights --------------------------------------------------------
    confs = {a: row[f"{a}_conf"] for a in active}
    tot_conf = sum(confs.values())

    if tot_conf <= 0 or np.isnan(tot_conf):            # ← NEW guard
        weights = {a: 1/len(active) for a in active}
    else:
        weights = {a: min(confs[a] / tot_conf, MAX_WEIGHT) for a in active}
        scale = 1 / sum(weights.values())
        weights = {a: w*scale for a, w in weights.items()}

    # ---- 2b) PnL ------------------------------------------------------------
    daily_pnl = 0.0
    net_sig   = 0.0
    for a in active:
        capital_i = nav * weights[a]
        pnl_i     = capital_i * row[f"{a}_sig"] * row[f"{a}_ret"]
        daily_pnl += pnl_i
        net_sig   += weights[a] * row[f"{a}_sig"]

        trade_log.append(
            f"{dt.date()} | {a.upper():5s} | "
            f"{'LONG' if row[f'{a}_sig']>0 else 'SHORT':5s} | "
            f"{capital_i:,.2f}$ | ret {row[f'{a}_ret']*100:+.2f}% -> pnl {pnl_i:+.2f}"
        )

    nav += daily_pnl
    net_sig_val = np.sign(net_sig) if not np.isnan(net_sig) else 0   # ← NEW
    nav_hist.append({"date": dt, "nav": nav, "sig": int(net_sig_val)})

# -------- 3) results to CSV + console summary ------------------------------ #
nav_df = pd.DataFrame(nav_hist).set_index("date")
nav_df["cum_ret_%"] = 100 * (nav_df["nav"] / INIT_NAV - 1)
nav_df.to_csv(OUT_BASKET_NAV, float_format="%.6f")

print("\n================  DAILY TRADING LOG  ================\n")
for line in trade_log:
    print(line)

final_ret = nav_df["cum_ret_%"].iloc[-1]
print("\n================  SUMMARY  ==========================")
print(f"Final NAV:  {nav_df['nav'].iloc[-1]:,.2f}  "
      f" ({final_ret:+.2f} %)   — written to {OUT_BASKET_NAV}")
# Out:
# ================  DAILY TRADING LOG  ================
#
# 2025-01-02  |  FLAT  |  NAV stays 10,000.00
# 2025-01-03 | CITI  | LONG  | 5,325.58$ | ret +1.52% -> pnl +80.71
# 2025-01-03 | BRENT | LONG  | 4,674.42$ | ret +0.76% -> pnl +35.71
# 2025-01-06 | BRENT | LONG  | 10,116.42$ | ret -0.27% -> pnl -27.77
# 2025-01-07 | CITI  | LONG  | 6,114.92$ | ret +1.29% -> pnl +79.02
# 2025-01-07 | BRENT | LONG  | 3,973.74$ | ret +0.98% -> pnl +39.06
# 2025-01-08 | BRENT | LONG  | 10,206.73$ | ret -1.16% -> pnl -117.90
# 2025-01-09 | BRENT | LONG  | 10,088.84$ | ret +1.00% -> pnl +100.68
# 2025-01-10 | CITI  | SHORT | 3,481.18$ | ret -2.54% -> pnl +88.38
# 2025-01-10 | BRENT | LONG  | 6,708.34$ | ret +3.69% -> pnl +247.68
# 2025-01-13 | BRENT | LONG  | 10,525.58$ | ret +1.57% -> pnl +164.96
# 2025-01-14  |  FLAT  |  NAV stays 10,690.54
# 2025-01-15 | CITI  | LONG  | 5,968.18$ | ret +6.49% -> pnl +387.32
# 2025-01-15 | BRENT | LONG  | 4,722.36$ | ret +2.64% -> pnl +124.68
# 2025-01-16 | CITI  | LONG  | 11,202.54$ | ret +0.31% -> pnl +34.35
# 2025-01-17 | CITI  | LONG  | 11,236.89$ | ret +1.89% -> pnl +211.83
# 2025-01-20  |  FLAT  |  NAV stays 11,448.71
# 2025-01-21 | CITI  | LONG  | 11,448.71$ | ret +2.10% -> pnl +240.45
# 2025-01-22 | CITI  | LONG  | 11,689.17$ | ret +0.02% -> pnl +2.86
# 2025-01-23 | CITI  | LONG  | 11,692.03$ | ret +0.36% -> pnl +41.51
# 2025-01-24 | CITI  | LONG  | 11,733.54$ | ret -0.61% -> pnl -71.56
# 2025-01-27 | CITI  | LONG  | 11,661.97$ | ret -0.50% -> pnl -58.68
# 2025-01-28 | BRENT | LONG  | 11,603.29$ | ret +0.53% -> pnl +61.72
# 2025-01-29  |  FLAT  |  NAV stays 11,665.01
# 2025-01-30 | BRENT | LONG  | 11,665.01$ | ret +0.38% -> pnl +44.17
# 2025-01-31  |  FLAT  |  NAV stays 11,709.18
#
# ================  SUMMARY  ==========================
# Final NAV:  11,709.18   (+17.09 %)   — written to basket_nav_jan25.csv
# /tmp/ipykernel_904478/921774571.py:48: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   basket_df[f"{a}_sig" ].fillna(0, inplace=True)     #   signals:   0 = flat
# /tmp/ipykernel_904478/921774571.py:49: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   basket_df[f"{a}_conf"].fillna(0, inplace=True)     #   conf:      0 means “skip asset”
# /tmp/ipykernel_904478/921774571.py:50: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   basket_df[f"{a}_ret" ].fillna(0, inplace=True)     #   returns:   0 → no PnL impact

# %%
###############################################################################
# basket_trade_two_assets.py  –  Jan‑2025 Citigroup + Brent‑Oil basket trading
###############################################################################
import numpy as np                               # ← NEW
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt                  # ← NEW
from matplotlib.lines import Line2D              # ← NEW

# --------------------------------------------------------------------------- #
# 0) CONFIGURATION                                                            #
# --------------------------------------------------------------------------- #
INIT_NAV     = 10_000           # initial portfolio value
MAX_WEIGHT   = 0.75             # cap per‑asset weight (optional risk‑guard)
ASSETS = {                       # filenames for each asset
    "citi":  dict(sig="signals_citi.csv",
                  conf="confidence_citi.csv",
                  ret="returns_citi.csv"),
    "brent": dict(sig="signals_brentoil.csv",
                  conf="confidence_brentoil.csv",
                  ret="returns_brentoil.csv")
}
OUT_BASKET_NAV = "basket_nav_jan25.csv"
# --------------------------------------------------------------------------- #

def _load_col(fname: str, colname: str) -> pd.Series:
    """Load CSV and return <colname> as a date‑indexed Series."""
    s = (pd.read_csv(fname, parse_dates=["date"])
          .set_index("date")[colname])
    if not s.index.is_monotonic_increasing:
        s = s.sort_index()
    return s

# -------- 1) load & merge the three feeds per asset ------------------------ #
frames = []
for asset, f in ASSETS.items():
    sig  = _load_col(f["sig"],  "signal").rename(f"{asset}_sig")
    conf = _load_col(f["conf"], "conf"  ).rename(f"{asset}_conf")
    ret  = _load_col(f["ret"],  "ret"   ).rename(f"{asset}_ret")
    frames.append(pd.concat([sig, conf, ret], axis=1))

basket_df = pd.concat(frames, axis=1).loc["2025-01-01":"2025-01-31"]
basket_df = basket_df.sort_index()

# ---------- sanitise missing data ------------------------------------------
for a in ASSETS:
    basket_df[f"{a}_sig" ].fillna(0, inplace=True)
    basket_df[f"{a}_conf"].fillna(0, inplace=True)
    basket_df[f"{a}_ret" ].fillna(0, inplace=True)

# -------- 2) back‑test loop ------------------------------------------------ #
nav_hist  = []
trade_log = []
nav       = INIT_NAV

for dt, row in basket_df.iterrows():
    active = [a for a in ASSETS if row[f"{a}_sig"] != 0]

    if not active:
        nav_hist.append({"date": dt, "nav": nav, "sig": 0})
        trade_log.append(f"{dt.date()}  |  FLAT  |  NAV stays {nav:,.2f}")
        continue

    # ---- 2a) weights -------------------------------------------------------
    confs    = {a: row[f"{a}_conf"] for a in active}
    tot_conf = sum(confs.values())

    if tot_conf <= 0 or np.isnan(tot_conf):
        weights = {a: 1/len(active) for a in active}
    else:
        weights = {a: min(confs[a] / tot_conf, MAX_WEIGHT) for a in active}
        scale   = 1 / sum(weights.values())
        weights = {a: w*scale for a, w in weights.items()}

    # ---- 2b) PnL -----------------------------------------------------------
    daily_pnl = 0.0
    net_sig   = 0.0
    for a in active:
        capital_i = nav * weights[a]
        pnl_i     = capital_i * row[f"{a}_sig"] * row[f"{a}_ret"]
        daily_pnl += pnl_i
        net_sig   += weights[a] * row[f"{a}_sig"]

        trade_log.append(
            f"{dt.date()} | {a.upper():5s} | "
            f"{'LONG' if row[f'{a}_sig']>0 else 'SHORT':5s} | "
            f"{capital_i:,.2f}$ | ret {row[f'{a}_ret']*100:+.2f}% -> pnl {pnl_i:+.2f}"
        )

    nav += daily_pnl
    net_sig_val = np.sign(net_sig) if not np.isnan(net_sig) else 0
    nav_hist.append({"date": dt, "nav": nav, "sig": int(net_sig_val)})

# -------- 3) results to CSV + console summary ------------------------------ #
nav_df = pd.DataFrame(nav_hist).set_index("date")
nav_df["cum_ret_%"] = 100 * (nav_df["nav"] / INIT_NAV - 1)
nav_df.to_csv(OUT_BASKET_NAV, float_format="%.6f")

print("\n================  DAILY TRADING LOG  ================\n")
for line in trade_log:
    print(line)

final_ret = nav_df["cum_ret_%"].iloc[-1]
print("\n================  SUMMARY  ==========================")
print(f"Final NAV:  {nav_df['nav'].iloc[-1]:,.2f}  "
      f" ({final_ret:+.2f} %)   — written to {OUT_BASKET_NAV}")

# --------------------------------------------------------------------------- #
# 4) PLOT THE TWO REQUESTED DIAGRAMS                                          #
# --------------------------------------------------------------------------- #
def _step_plot_core(ax, x, y, sig):
    """Draw horizontal‑then‑vertical steps coloured by position signal."""
    colour = {1: "red", -1: "blue", 0: "black"}
    for i in range(1, len(x)):
        c = colour.get(sig[i-1], "black")
        # horizontal segment
        ax.plot([x[i-1], x[i]], [y[i-1], y[i-1]], color=c, lw=2)
        # vertical jump
        ax.plot([x[i], x[i]], [y[i-1], y[i]],   color=c, lw=2)

def plot_stepwise_nav_curve(navdf: pd.DataFrame, title_suffix=""):
    fig, ax1 = plt.subplots(figsize=(14,6))
    dates = navdf.index.to_pydatetime()
    _step_plot_core(ax1, dates, navdf["nav"].values, navdf["sig"].values)

    ax1.set_xlabel("Date")
    ax1.set_ylabel("Capital (NAV)", color="blue")
    ax1.tick_params(axis="y", labelcolor="blue")
    ax1.grid(True)

    legend_elems = [
        Line2D([0],[0], color='black', lw=2, label='Flat'),
        Line2D([0],[0], color='red',   lw=2, label='Net Long'),
        Line2D([0],[0], color='blue',  lw=2, label='Net Short')
    ]
    ax1.legend(handles=legend_elems, loc="upper left")
    ax1.set_title(f"Day‑by‑Day Stepwise P&L Curve (Offset Settlement) {title_suffix}")
    plt.tight_layout()
    plt.show()

def plot_stepwise_pct_curve(navdf: pd.DataFrame, title_suffix=""):
    fig, ax1 = plt.subplots(figsize=(14,6))
    dates = navdf.index.to_pydatetime()
    _step_plot_core(ax1, dates, navdf["cum_ret_%"].values, navdf["sig"].values)

    ax1.set_xlabel("Date")
    ax1.set_ylabel("Cumulative Return (%)", color="blue")
    ax1.tick_params(axis="y", labelcolor="blue")
    ax1.grid(True)

    legend_elems = [
        Line2D([0],[0], color='black', lw=2, label='Flat'),
        Line2D([0],[0], color='red',   lw=2, label='Net Long'),
        Line2D([0],[0], color='blue',  lw=2, label='Net Short')
    ]
    ax1.legend(handles=legend_elems, loc="upper left")
    ax1.set_title(f"Day‑by‑Day Stepwise P&L Percentage Returns {title_suffix}")
    plt.tight_layout()
    plt.show()

# call the two plots
plot_stepwise_nav_curve(nav_df,       "of Citigroup + Brent‑Oil Basket")
plot_stepwise_pct_curve(nav_df,       "of Citigroup + Brent‑Oil Basket")
# Out:
# /tmp/ipykernel_904478/1520600971.py:47: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   basket_df[f"{a}_sig" ].fillna(0, inplace=True)
# /tmp/ipykernel_904478/1520600971.py:48: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   basket_df[f"{a}_conf"].fillna(0, inplace=True)
# /tmp/ipykernel_904478/1520600971.py:49: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   basket_df[f"{a}_ret" ].fillna(0, inplace=True)
# ================  DAILY TRADING LOG  ================
#
# 2025-01-02  |  FLAT  |  NAV stays 10,000.00
# 2025-01-03 | CITI  | LONG  | 5,325.58$ | ret +1.52% -> pnl +80.71
# 2025-01-03 | BRENT | LONG  | 4,674.42$ | ret +0.76% -> pnl +35.71
# 2025-01-06 | BRENT | LONG  | 10,116.42$ | ret -0.27% -> pnl -27.77
# 2025-01-07 | CITI  | LONG  | 6,114.92$ | ret +1.29% -> pnl +79.02
# 2025-01-07 | BRENT | LONG  | 3,973.74$ | ret +0.98% -> pnl +39.06
# 2025-01-08 | BRENT | LONG  | 10,206.73$ | ret -1.16% -> pnl -117.90
# 2025-01-09 | BRENT | LONG  | 10,088.84$ | ret +1.00% -> pnl +100.68
# 2025-01-10 | CITI  | SHORT | 3,481.18$ | ret -2.54% -> pnl +88.38
# 2025-01-10 | BRENT | LONG  | 6,708.34$ | ret +3.69% -> pnl +247.68
# 2025-01-13 | BRENT | LONG  | 10,525.58$ | ret +1.57% -> pnl +164.96
# 2025-01-14  |  FLAT  |  NAV stays 10,690.54
# 2025-01-15 | CITI  | LONG  | 5,968.18$ | ret +6.49% -> pnl +387.32
# 2025-01-15 | BRENT | LONG  | 4,722.36$ | ret +2.64% -> pnl +124.68
# 2025-01-16 | CITI  | LONG  | 11,202.54$ | ret +0.31% -> pnl +34.35
# 2025-01-17 | CITI  | LONG  | 11,236.89$ | ret +1.89% -> pnl +211.83
# 2025-01-20  |  FLAT  |  NAV stays 11,448.71
# 2025-01-21 | CITI  | LONG  | 11,448.71$ | ret +2.10% -> pnl +240.45
# 2025-01-22 | CITI  | LONG  | 11,689.17$ | ret +0.02% -> pnl +2.86
# 2025-01-23 | CITI  | LONG  | 11,692.03$ | ret +0.36% -> pnl +41.51
# 2025-01-24 | CITI  | LONG  | 11,733.54$ | ret -0.61% -> pnl -71.56
# 2025-01-27 | CITI  | LONG  | 11,661.97$ | ret -0.50% -> pnl -58.68
# 2025-01-28 | BRENT | LONG  | 11,603.29$ | ret +0.53% -> pnl +61.72
# 2025-01-29  |  FLAT  |  NAV stays 11,665.01
# 2025-01-30 | BRENT | LONG  | 11,665.01$ | ret +0.38% -> pnl +44.17
# 2025-01-31  |  FLAT  |  NAV stays 11,709.18
#
# ================  SUMMARY  ==========================
# Final NAV:  11,709.18   (+17.09 %)   — written to basket_nav_jan25.csv

# %%
###############################################################################
# basket_trade_three_assets.py  –  Jan-2025 3-asset basket trading
###############################################################################
import numpy as np
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# --------------------------------------------------------------------------- #
# 0) CONFIGURATION                                                            #
# --------------------------------------------------------------------------- #
INIT_NAV       = 10_000
MAX_WEIGHT     = 0.75
ASSETS = {
    "citi":  dict(sig="signals_citi.csv",
                  conf="confidence_citi.csv",
                  ret="returns_citi.csv"),
    "brent": dict(sig="signals_brentoil.csv",
                  conf="confidence_brentoil.csv",
                  ret="returns_brentoil.csv"),
    "cocacola": dict(sig="signals_cocacola.csv",
                  conf="confidence_cocacola.csv",
                  ret="returns_cocacola.csv"),   # ← new third asset
}
OUT_BASKET_NAV = "basket_nav_jan25_3assets.csv"
# --------------------------------------------------------------------------- #

def _load_col(fname: str, colname: str) -> pd.Series:
    s = (pd.read_csv(fname, parse_dates=["date"])
           .set_index("date")[colname])
    if not s.index.is_monotonic_increasing:
        s = s.sort_index()
    return s

# -------- 1) load & merge all assets’ feeds ------------------------------- #
frames = []
for asset, f in ASSETS.items():
    sig  = _load_col(f["sig"],  "signal").rename(f"{asset}_sig")
    conf = _load_col(f["conf"], "conf"  ).rename(f"{asset}_conf")
    ret  = _load_col(f["ret"],  "ret"   ).rename(f"{asset}_ret")
    frames.append(pd.concat([sig, conf, ret], axis=1))

basket_df = pd.concat(frames, axis=1)
basket_df = basket_df.loc["2025-01-01":"2025-01-31"].sort_index()

# -------- sanitize missing data ------------------------------------------- #
for a in ASSETS:
    basket_df[f"{a}_sig" ].fillna(0, inplace=True)
    basket_df[f"{a}_conf"].fillna(0, inplace=True)
    basket_df[f"{a}_ret" ].fillna(0, inplace=True)

# -------- 2) back-test loop ------------------------------------------------ #
nav_hist  = []
trade_log = []
nav       = INIT_NAV

for dt, row in basket_df.iterrows():
    active = [a for a in ASSETS if row[f"{a}_sig"] != 0]
    if not active:
        nav_hist.append({"date": dt, "nav": nav, "sig": 0})
        trade_log.append(f"{dt.date()}  |  FLAT  |  NAV stays {nav:,.2f}")
        continue

    # 2a) build weights by confidence
    confs    = {a: row[f"{a}_conf"] for a in active}
    tot_conf = sum(confs.values())
    if tot_conf <= 0 or np.isnan(tot_conf):
        weights = {a: 1/len(active) for a in active}
    else:
        weights = {a: min(confs[a]/tot_conf, MAX_WEIGHT) for a in active}
        scale   = 1/sum(weights.values())
        weights = {a: w*scale for a, w in weights.items()}

    # 2b) apply PnL
    daily_pnl = 0.0
    net_sig   = 0.0
    for a in active:
        capital_i = nav * weights[a]
        pnl_i     = capital_i * row[f"{a}_sig"] * row[f"{a}_ret"]
        daily_pnl += pnl_i
        net_sig   += weights[a] * row[f"{a}_sig"]

        trade_log.append(
            f"{dt.date()} | {a.upper():5s} | "
            f"{'LONG' if row[f'{a}_sig']>0 else 'SHORT':5s} | "
            f"{capital_i:,.2f}$ | ret {row[f'{a}_ret']*100:+.2f}% -> pnl {pnl_i:+.2f}"
        )

    nav += daily_pnl
    sig_val = np.sign(net_sig) if not np.isnan(net_sig) else 0
    nav_hist.append({"date": dt, "nav": nav, "sig": int(sig_val)})

# -------- 3) save results & print summary --------------------------------- #
nav_df = pd.DataFrame(nav_hist).set_index("date")
nav_df["cum_ret_%"] = 100*(nav_df["nav"]/INIT_NAV - 1)
nav_df.to_csv(OUT_BASKET_NAV, float_format="%.6f")

print("\n================  DAILY TRADING LOG  ================\n")
for line in trade_log:
    print(line)
final_ret = nav_df["cum_ret_%"].iloc[-1]
print("\n================  SUMMARY  ==========================")
print(f"Final NAV: {nav_df['nav'].iloc[-1]:,.2f} ({final_ret:+.2f} %) → {OUT_BASKET_NAV}")

# -------- 4) PLOT THE TWO REQUESTED DIAGRAMS ------------------------------ #
def _step_plot_core(ax, x, y, sig):
    colour = { 1:"red", -1:"blue", 0:"black" }
    for i in range(1, len(x)):
        c = colour.get(sig[i-1], "black")
        ax.plot([x[i-1], x[i]], [y[i-1], y[i-1]], color=c, lw=2)
        ax.plot([x[i],   x[i]  ], [y[i-1], y[i]  ], color=c, lw=2)

def plot_stepwise_nav_curve(navdf, title_suffix=""):
    fig, ax = plt.subplots(figsize=(14,6))
    dates = navdf.index.to_pydatetime()
    _step_plot_core(ax, dates, navdf["nav"].values, navdf["sig"].values)
    ax.set_xlabel("Date")
    ax.set_ylabel("Capital (NAV)", color="blue")
    ax.tick_params(axis="y", labelcolor="blue")
    ax.grid(True)
    legend = [
        Line2D([0],[0], color='black', lw=2, label='Flat'),
        Line2D([0],[0], color='red',   lw=2, label='Net Long'),
        Line2D([0],[0], color='blue',  lw=2, label='Net Short'),
    ]
    ax.legend(handles=legend, loc="upper left")
    ax.set_title(f"Day-by-Day Stepwise P&L Curve (Offset) {title_suffix}")
    plt.tight_layout()
    plt.show()

def plot_stepwise_pct_curve(navdf, title_suffix=""):
    fig, ax = plt.subplots(figsize=(14,6))
    dates = navdf.index.to_pydatetime()
    _step_plot_core(ax, dates, navdf["cum_ret_%"].values, navdf["sig"].values)
    ax.set_xlabel("Date")
    ax.set_ylabel("Cumulative Return (%)", color="blue")
    ax.tick_params(axis="y", labelcolor="blue")
    ax.grid(True)
    legend = [
        Line2D([0],[0], color='black', lw=2, label='Flat'),
        Line2D([0],[0], color='red',   lw=2, label='Net Long'),
        Line2D([0],[0], color='blue',  lw=2, label='Net Short'),
    ]
    ax.legend(handles=legend, loc="upper left")
    ax.set_title(f"Day-by-Day Stepwise P&L % Returns {title_suffix}")
    plt.tight_layout()
    plt.show()

plot_stepwise_nav_curve(nav_df, "of Citi + Brent + Cocacola Basket")
plot_stepwise_pct_curve(nav_df, "of Citi + Brent + Cocacola Basket")
# Out:
# ================  DAILY TRADING LOG  ================
#
# 2025-01-02  |  FLAT  |  NAV stays 10,000.00
# 2025-01-03 | CITI  | LONG  | 5,325.58$ | ret +1.52% -> pnl +80.71
# 2025-01-03 | BRENT | LONG  | 4,674.42$ | ret +0.76% -> pnl +35.71
# 2025-01-06 | BRENT | LONG  | 6,373.65$ | ret -0.27% -> pnl -17.49
# 2025-01-06 | COCACOLA | LONG  | 3,742.77$ | ret -1.52% -> pnl -56.97
# 2025-01-07 | CITI  | LONG  | 4,672.30$ | ret +1.29% -> pnl +60.38
# 2025-01-07 | BRENT | LONG  | 3,036.26$ | ret +0.98% -> pnl +29.85
# 2025-01-07 | COCACOLA | LONG  | 2,333.39$ | ret +0.05% -> pnl +1.15
# 2025-01-08 | BRENT | LONG  | 10,133.33$ | ret -1.16% -> pnl -117.05
# 2025-01-09 | BRENT | LONG  | 10,016.28$ | ret +1.00% -> pnl +99.95
# 2025-01-10 | CITI  | SHORT | 3,456.14$ | ret -2.54% -> pnl +87.75
# 2025-01-10 | BRENT | LONG  | 6,660.09$ | ret +3.69% -> pnl +245.90
# 2025-01-13 | BRENT | LONG  | 5,359.35$ | ret +1.57% -> pnl +83.99
# 2025-01-13 | COCACOLA | LONG  | 5,090.52$ | ret +0.95% -> pnl +48.35
# 2025-01-14 | COCACOLA | LONG  | 10,582.22$ | ret +0.63% -> pnl +66.94
# 2025-01-15 | CITI  | LONG  | 4,312.58$ | ret +6.49% -> pnl +279.88
# 2025-01-15 | BRENT | LONG  | 3,412.35$ | ret +2.64% -> pnl +90.09
# 2025-01-15 | COCACOLA | LONG  | 2,924.23$ | ret -0.44% -> pnl -12.73
# 2025-01-16 | CITI  | LONG  | 5,986.40$ | ret +0.31% -> pnl +18.36
# 2025-01-16 | COCACOLA | LONG  | 5,020.00$ | ret +0.78% -> pnl +39.01
# 2025-01-17 | CITI  | LONG  | 5,715.77$ | ret +1.89% -> pnl +107.75
# 2025-01-17 | COCACOLA | LONG  | 5,347.99$ | ret +0.74% -> pnl +39.52
# 2025-01-20  |  FLAT  |  NAV stays 11,211.03
# 2025-01-21 | CITI  | LONG  | 5,816.14$ | ret +2.10% -> pnl +122.15
# 2025-01-21 | COCACOLA | LONG  | 5,394.89$ | ret -0.46% -> pnl -24.95
# 2025-01-22 | CITI  | LONG  | 11,308.24$ | ret +0.02% -> pnl +2.77
# 2025-01-23 | CITI  | LONG  | 11,311.01$ | ret +0.36% -> pnl +40.15
# 2025-01-24 | CITI  | LONG  | 11,351.16$ | ret -0.61% -> pnl -69.23
# 2025-01-27 | CITI  | LONG  | 11,281.93$ | ret -0.50% -> pnl -56.77
# 2025-01-28 | BRENT | LONG  | 6,281.64$ | ret +0.53% -> pnl +33.41
# 2025-01-28 | COCACOLA | SHORT | 4,943.53$ | ret -2.36% -> pnl +116.87
# 2025-01-29  |  FLAT  |  NAV stays 11,375.45
# 2025-01-30 | BRENT | LONG  | 6,532.91$ | ret +0.38% -> pnl +24.74
# 2025-01-30 | COCACOLA | SHORT | 4,842.54$ | ret +1.94% -> pnl -94.03
# 2025-01-31 | COCACOLA | SHORT | 11,306.16$ | ret -0.89% -> pnl +100.62
#
# ================  SUMMARY  ==========================
# Final NAV: 11,406.78 (+14.07 %) → basket_nav_jan25_3assets.csv
# /tmp/ipykernel_913352/2976787327.py:49: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   basket_df[f"{a}_sig" ].fillna(0, inplace=True)
# /tmp/ipykernel_913352/2976787327.py:50: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   basket_df[f"{a}_conf"].fillna(0, inplace=True)
# /tmp/ipykernel_913352/2976787327.py:51: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   basket_df[f"{a}_ret" ].fillna(0, inplace=True)
